# %%
from utils import config, sample_utils as su
from utils import parse_midas_data, parse_patric, core_gene_utils, midas_db_utils
import numpy as np, pickle, sys
from numpy.random import choice
from collections import defaultdict

from matplotlib import pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

# %%
plot_dir = "%s/revs_genes/" % (config.analysis_directory)
ddir = config.data_directory
pdir = "%s/pickles" % ddir
sweep_type = 'full'
snp_modifications_by_site = pickle.load(open('%s/snp_modifications_by_site_%s.pkl' % (pdir, sweep_type), 'rb'))
snp_modification_genes = pickle.load(open('%s/snp_modification_genes_%s.pkl' % (pdir, sweep_type), 'rb'))
modification_gene_gains = pickle.load(open('%s/modification_gene_gains_%s.pkl' % (pdir, sweep_type), 'rb'))
modification_gene_losses = pickle.load(open('%s/modification_gene_losses_%s.pkl' % (pdir, sweep_type), 'rb'))
modification_gene_gains_present_null = pickle.load(open('%s/modification_gene_gains_present_null_%s.pkl' % (pdir, sweep_type), 'rb'))
modification_gene_losses_present_null = pickle.load(open('%s/modification_gene_losses_present_null_%s.pkl' % (pdir, sweep_type), 'rb'))

# %%
keywords={}
keywords['ABC transporter']=['ABC']
keywords['phage']=['hage']
keywords['transposon']=['onjugati','anspos']
keywords['mobilization']=['mob','obilization','obile']
keywords['integrase']=['ntegrase']
keywords['plasmid']=['plasmid']
keywords['recombinase']=['ecombinase']
keywords['tRNA']=['tRNA']
keywords['ATP']=['ATP']
keywords['excisionase']=['xcisionase']
keywords['transmembrane']=['embrane']
keywords['replication']=['eplication']
keywords['regulator']=['egulator']
keywords['transcription']=['anscription']
keywords['toxin']=['toxin']
keywords['restriction']=['estriction']
keywords['replication']=['eplication']
keywords['transferase']=['ansferase']
keywords['reductase']=['eductase']
keywords['phosphatase']=['phosphatase']
keywords['helicase']=['elicase']
keywords['kinase']=['kinase']
keywords['dehydrogenase']=['dehydrogenase']
keywords['drug']=['drug']
keywords['cell wall']=['ell wall']
keywords['primase']=['imase']
keywords['resistance']=['resistance']
keywords['hydrolase']=['ydrolase']
keywords['topoisomerase']=['opoisomerase']
keywords['hypothetical'] = ['ypothetical']

# since this is a greedy algorithm, order the more important keywords first
keyword_order=['ABC transporter','phage','transposon','mobilization','integrase', 'plasmid','recombinase','tRNA','ATP','excisionase','transmembrane','replication','regulator','transcription','toxin','restriction','replication','transferase','reductase','phosphatase','helicase','kinase','dehydrogenase','drug','cell wall','primase','topoisomerase','hypothetical']

common_genes={}

# %%
new_dict = defaultdict(int)

for keyword in keyword_order:
    for gene_name in changed_gene_name_counts_by_tp_type['AA']:
        if keyword in gene_name:
            new_dict[keyword] += changed_gene_name_counts_by_tp_type['AA'][gene_name]

# %%
new_dict
# Out:
# defaultdict(int,
#             {'ABC transporter': 27,
#              'ATP': 11,
#              'dehydrogenase': 2,
#              'drug': 2,
#              'hypothetical': 77,
#              'kinase': 6,
#              'phosphatase': 1,
#              'reductase': 2,
#              'regulator': 11,
#              'tRNA': 4,
#              'transcription': 1,
#              'transferase': 9})

# %%
tp_types = ['AA', 'II-premie', 'II-nonpremie','MM', 'MI-premie', 'MI-nonpremie']
num_gene_gains_by_tp_type = {tp_type: 0 for tp_type in tp_types}
gained_genes_by_tp_type = {tp_type: set() for tp_type in tp_types}
gained_genes_counts_by_tp_type = {tp_type: defaultdict(int) for tp_type in tp_types}
gained_genes_counts_nulls_by_tp_type = {tp_type: defaultdict(int) for tp_type in tp_types}

# Enumerate genes
for species in modification_gene_gains:
    for cohort in modification_gene_gains[species]:
        for subject in modification_gene_gains[species][cohort]:
            subdict = modification_gene_gains[species][cohort][subject]
            subdict_null = modification_gene_gains_present_null[species][cohort][subject]
            # For each sample pair in this cohort/species,
            # have a count of how many gains of a particular gene
            for tp_pair in subdict:
                tp_type = tp_pair_to_tp_type(tp_pair, cohort)
                for gene_id, gene_name in subdict[tp_pair]:
                    gene_gain_count = subdict[tp_pair][(gene_id, gene_name)]
                    gene_gain_count_null = subdict_null[tp_pair][(gene_id, gene_name)]
                    num_gene_gains_by_tp_type[tp_type] += gene_gain_count
                    gained_genes_by_tp_type[tp_type].add(gene_name)
                    gained_genes_counts_by_tp_type[tp_type][gene_name] += gene_gain_count
                    gained_genes_counts_nulls_by_tp_type[tp_type][gene_name] += gene_gain_count_null

# %%
num_gene_gains_by_tp_type
# Out:
# {'AA': 4,
#  'II-nonpremie': 3555,
#  'II-premie': 93,
#  'MI-nonpremie': 1,
#  'MI-premie': 0,
#  'MM': 0}

# %%
for tp_type in gained_genes_by_tp_type:
    count = len(gained_genes_by_tp_type[tp_type])
    print('%i %s' % (count, tp_type))
# Out:
# 1 AA
# 30 II-premie
# 0 MI-premie
# 0 MM
# 1 MI-nonpremie
# 637 II-nonpremie

# %%
for tp_type in gained_genes_counts_by_tp_type:
    print(tp_type)
    strs = []
    for gene_name in gained_genes_counts_by_tp_type[tp_type]:
        count = gained_genes_counts_by_tp_type[tp_type][gene_name]
        if count > 1:
            strs.append("%i %s" % (count, gene_name))
    for string in sorted(strs, reverse=True):
        print(string)
    print('')
# Out:
# AA
# 4 hypothetical protein
#
# II-premie
# 61 hypothetical protein
# 3 Phage protein
# 2 Doubtful CDS. No database matches
#
# MI-premie
#
# MM
#
# MI-nonpremie
#
# II-nonpremie
# 9 RNA-binding protein
# 9 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 8 Putative helicase
# 8 Integrase
# 7 Uncharacterized MFS-type transporter
# 6 cAMP-binding proteins - catabolite gene activator and regulatory subunit of cAMP-dependent protein kinases
# 6 UpdZ protein
# 6 Two-component transcriptional response regulator, LuxR family
# 6 Glycosyltransferase
# 5 SclB protein
# 5 Putative glycosyltransferase
# 5 O-acetylhomoserine sulfhydrylase (EC 2.5.1.49) @ O-succinylhomoserine sulfhydrylase (EC 2.5.1.48)
# 5 N-acetylmuramoyl-L-alanine amidase (EC 3.5.1.28)
# 5 Capsular polysaccharide transcription antitermination protein, UpxY family
# 5 ABC-type antimicrobial peptide transport system, ATPase component
# 46 RNA polymerase ECF-type sigma factor
# 4 beta-glycosyl hydrolase
# 4 [FeFe]-hydrogenase maturation protein HydF
# 4 Vitamin B12 ABC transporter, substrate-binding protein BtuF
# 4 Vitamin B12 ABC transporter, permease protein BtuC
# 4 Undecaprenyl-phosphate alpha-N-acetylglucosaminyl 1-phosphate transferase (EC 2.7.8.33)
# 4 UDP-glucose 4-epimerase (EC 5.1.3.2)
# 4 Tyrosine type site-specific recombinase
# 4 TPR-repeat-containing protein
# 4 Putative periplasmic protein
# 4 Phage integrase
# 4 Oxidoreductase, aldo/keto reductase family
# 4 Nitroreductase family protein
# 4 N-acetylglucosaminyltransferase (EC 2.4.1.-)
# 4 Monofunctional biosynthetic peptidoglycan transglycosylase
# 4 Membrane protein involved in the export of O-antigen, teichoic acid lipoteichoic acids
# 4 MBL-fold metallo-hydrolase superfamily
# 4 ISNCY family transposase
# 4 Flavoredoxin
# 4 Endonuclease
# 4 Efflux ABC transporter, permease protein
# 4 DNA ligase (NAD(+)) (EC 6.5.1.2)
# 4 CAAX amino terminal protease family protein
# 4 3-oxoacyl-[acyl-carrier protein] reductase paralog (EC 1.1.1.100)
# 3 tmRNA-binding protein SmpB
# 3 tRNA (guanine(37)-N(1))-methyltransferase (EC 2.1.1.228)
# 3 putative patatin-like phospholipase
# 3 putative integration host factor IHF alpha subunit
# 3 dTDP-4-dehydrorhamnose 3,5-epimerase (EC 5.1.3.13)
# 3 cytochrome c biogenesis protein
# 3 Zn-ribbon-containing, possibly RNA-binding protein and truncated derivatives
# 3 Xylulose kinase (EC 2.7.1.17)
# 3 Xylanase
# 3 Uronate isomerase (EC 5.3.1.12)
# 3 Uncharacterized protein YgbA
# 3 Uncharacterized protein BT4380
# 3 Uncharacterized membrane protein PA1577
# 3 UPF0126 inner membrane protein BT_1201
# 3 UPF0056 inner membrane protein MarC
# 3 Two-component transcriptional response regulator, LuxR family BT1217
# 3 Transmembrane protein
# 3 Transcriptional regulator, AsnC family
# 3 TonB family protein
# 3 Tll0814 protein
# 3 Thiol:disulfide interchange protein
# 3 Stress responsive alpha-beta barrel domain protein Dabb
# 3 Small heat shock protein
# 3 Slr1117 protein
# 3 Sirohydrochlorin cobaltochelatase CbiK (EC 4.99.1.3) @ Sirohydrochlorin ferrochelatase activity of CbiK (EC 4.99.1.4)
# 3 Sigma factor RpoE regulatory protein RseC
# 3 Serine protease
# 3 Rrf2-linked NADH-flavin reductase
# 3 RidA/YER057c/UK114 superfamily protein
# 3 Ribosylnicotinamide kinase (EC 2.7.1.22) homolog / Unknown conserved in Flavobacteria
# 3 Ribosome-associated heat shock protein implicated in the recycling of the 50S subunit (S4 paralog)
# 3 Ribosomal silencing factor RsfA
# 3 ROK family sugar kinase or transcriptional regulator
# 3 RND efflux system, inner membrane transporter
# 3 RNA methyltransferase, TrmH family
# 3 Putative thioredoxin
# 3 Putative permease
# 3 Putative outer membrane protein, probably involved in nutrient binding
# 3 Protein DUF2149, predicted transporter component
# 3 Probable iron export ATP-binding protein FetA
# 3 Probable integral membrane protein Cj1165c
# 3 Possible glyoxylase family protein (Lactoylglutathione lyase) (EC 4.4.1.5)
# 3 Possible exported heavy-metal binding protein
# 3 Phosphoribosylformimino-5-aminoimidazole carboxamide ribotide isomerase (EC 5.3.1.16)
# 3 Phosphate/pyrophosphate-specific outer membrane porin OprP/OprO
# 3 Permease of the drug/metabolite transporter (DMT) superfamily
# 3 Para-aminobenzoate synthase, aminase component (EC 2.6.1.85)
# 3 PAP2 superfamily protein
# 3 Oxidoreductase
# 3 Outer membrane protein romA
# 3 OmpA family outer membrane protein
# 3 Na+/H+-dicarboxylate symporter
# 3 N-acylneuraminate cytidylyltransferase (EC 2.7.7.43)
# 3 N(6)-L-threonylcarbamoyladenine synthase (EC 2.3.1.234)
# 3 Multidrug resistance protein
# 3 Mobile element protein
# 3 Membrane protein
# 3 Malonyl CoA-acyl carrier protein transacylase (EC 2.3.1.39)
# 3 Lipoprotein signal peptidase (EC 3.4.23.36)
# 3 Large-conductance mechanosensitive channel
# 3 Integration host factor alpha subunit
# 3 Integrase IntN1
# 3 Integral membrane protein
# 3 Inner membrane protein YhiM
# 3 Indole-3-glycerol phosphate synthase (EC 4.1.1.48)
# 3 Immunoreactive 53 kDa antigen PG123
# 3 Hypothetical Nudix-like regulator
# 3 Helicase, C-terminal:Type III restriction enzyme, res subunit:DEAD/DEAH box helicase, N-terminal
# 3 Glycosyl transferase, family 2
# 3 GTP cyclohydrolase 1 type 2 homolog YbgI @ Bsu YqfO NIF3/CutA domain
# 3 Free methionine-(R)-sulfoxide reductase, contains GAF domain
# 3 Fosmidomycin resistance protein
# 3 FIG137478: Hypothetical protein
# 3 FIG016027: protein of unknown function YeaO
# 3 FIG00490011: hypothetical protein
# 3 FIG000605: protein co-occurring with transport systems (COG1739)
# 3 Endo-1,4-beta-xylanase D
# 3 DoxX family protein
# 3 Dihydroorotate dehydrogenase (quinone) (EC 1.3.5.2)
# 3 Dihydroorotate dehydrogenase (NAD(+)), electron transfer subunit (EC 1.3.1.14)
# 3 Dihydroorotate dehydrogenase (NAD(+)), catalytic subunit (EC 1.3.1.14)
# 3 Diacylglycerol kinase (EC 2.7.1.107)
# 3 DNA-directed RNA polymerase omega subunit (EC 2.7.7.6)
# 3 DNA polymerase III delta subunit (EC 2.7.7.7)
# 3 D-alanine--poly(phosphoribitol) ligase ACP subunit (EC 6.1.1.13)
# 3 CzcABC family efflux RND transporter, outer membrane protein
# 3 Cys-tRNA(Pro) deacylase YbaK
# 3 Conserved protein YuxK
# 3 Conserved hypothetical protein 22
# 3 Co-activator of prophage gene expression IbrB
# 3 Cell division protein DivIC (FtsB), stabilizes FtsL against RasP cleavage
# 3 Aminotransferase, DegT/DnrJ/EryC1/StrS family
# 3 Aminodeoxychorismate lyase (EC 4.1.3.38)
# 3 Aerotolerance protein BatE
# 3 Aerotolerance protein BatD
# 3 Aerotolerance protein BatC
# 3 Aerotolerance protein BatB
# 3 Adenosylcobinamide kinase (EC 2.7.1.156) / Adenosylcobinamide-phosphate guanylyltransferase (EC 2.7.7.62)
# 3 Acetyltransferase, GNAT family
# 3 ATP:Cob(I)alamin adenosyltransferase (EC 2.5.1.17)
# 3 ATP-dependent RNA helicase
# 3 ATP synthase protein I
# 3 ATP synthase gamma chain (EC 3.6.3.14)
# 3 ATP synthase epsilon chain (EC 3.6.3.14)
# 3 ATP synthase F0 sector subunit c (EC 3.6.3.14)
# 3 4-hydroxy-2-oxoglutarate aldolase (EC 4.1.3.16) @ 2-dehydro-3-deoxyphosphogluconate aldolase (EC 4.1.2.14)
# 3 4-diphosphocytidyl-2-C-methyl-D-erythritol kinase (EC 2.7.1.148)
# 3 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine pyrophosphokinase (EC 2.7.6.3)
# 2262 hypothetical protein
# 2 tRNA(1)(Val) (adenine(37)-N(6))-methyltransferase (EC 2.1.1.223)
# 2 tRNA (5-methylaminomethyl-2-thiouridylate)-methyltransferase (EC 2.1.1.61)
# 2 sodium/iodide co-transporter
# 2 putative pyrogenic exotoxin B
# 2 putative lipoprotein
# 2 putative acetyltransferase
# 2 putative UndPP-QuiNAc-P-transferase
# 2 putative N-acetylmuramoyl-L-alanine amidase
# 2 probable lipoprotein YPO2292
# 2 mobilization protein B
# 2 low molecular weight phosphatase supefamily
# 2 dTDP-4-dehydrorhamnose reductase (EC 1.1.1.133)
# 2 archaeal ATPase, fused to C-terminal DUF234 domain
# 2 Ync
# 2 V-type ATP synthase subunit K (EC 3.6.3.14)
# 2 V-type ATP synthase subunit E (EC 3.6.3.14)
# 2 UspA
# 2 Uracil-DNA glycosylase, family 1 (EC 3.2.2.27)
# 2 Uracil permease @ Uracil:proton symporter UraA
# 2 Undecaprenyl-phosphate galactosephosphotransferase (EC 2.7.8.6)
# 2 Uncharacterized protein CHU_1311
# 2 UPF0324 inner membrane protein YeiH
# 2 UDP-glucuronate decarboxylase (EC 4.1.1.35)
# 2 Two-component system sensor histidine kinase/response regulator hybrid
# 2 Tryptophan synthase (indole-salvaging) (EC 4.2.1.122)
# 2 Trk potassium uptake system protein TrkH
# 2 Transposase
# 2 Transmembrane component YkoC of energizing module of thiamin-regulated ECF transporter for HydroxyMethylPyrimidine
# 2 Translation initiation factor SUI1-related protein
# 2 Translation initiation factor 3
# 2 Transglycosylase-associated protein
# 2 Transcriptional regulator, PadR family
# 2 Transcriptional regulator, AcrR family
# 2 Transcriptional regulator
# 2 Transcription termination protein NusB
# 2 Transcription regulator [contains diacylglycerol kinase catalytic domain]
# 2 Transcription accessory protein (S1 RNA-binding domain)
# 2 Thiol peroxidase, Bcp-type (EC 1.11.1.15)
# 2 Thiamin-phosphate pyrophosphorylase (EC 2.5.1.3)
# 2 Superoxide dismutase [Mn/Fe] (EC 1.15.1.1)
# 2 Sulfur carrier protein ThiS adenylyltransferase (EC 2.7.7.73)
# 2 Sugar-phosphate nucleotidyl transferase
# 2 Sortase A, LPXTG specific
# 2 Similar to conjugative transposon protein TraB
# 2 Signal recognition particle receptor FtsY
# 2 Serine/threonine kinase
# 2 Ser/Thr protein phosphatase family protein, UDP-2,3-diacylglucosamine hydrolase (EC 3.6.1.-) homolog
# 2 SanA protein
# 2 SSU ribosomal protein S20p
# 2 SSU ribosomal protein S14p (S29e) @ SSU ribosomal protein S14p (S29e), zinc-independent
# 2 SAM-dependent methyltransferase
# 2 Rubredoxin
# 2 Ribosomal protein S12p Asp88 (E. coli) methylthiotransferase (EC 2.8.4.4)
# 2 Ribose-phosphate pyrophosphokinase (EC 2.7.6.1)
# 2 Ribose-5-phosphate isomerase B (EC 5.3.1.6)
# 2 Regulatory sensor-transducer, BlaR1/MecR1 family / TonB-dependent receptor
# 2 Recombination protein RecR
# 2 Pyridoxal phosphate-containing protein YggS
# 2 Putative pre-16S rRNA nuclease YqgF
# 2 Putative phage-encoded peptidoglycan binding protein
# 2 Putative membrane-associated metal-dependent hydrolase
# 2 Putative dipeptidase
# 2 Putative calcineurin superfamily phosphohydrolase
# 2 Putative alpha-1,6-mannanase
# 2 Putative DNA-binding protein
# 2 Protein BF2544, predicted transporter component
# 2 Proline dehydrogenase (EC 1.5.5.2) / Delta-1-pyrroline-5-carboxylate dehydrogenase (EC 1.2.1.88)
# 2 Predicted dye-decolorizing peroxidase (DyP), encapsulated subgroup
# 2 Polysaccharide deacetylase-like protein
# 2 Polyribonucleotide nucleotidyltransferase (EC 2.7.7.8)
# 2 Phosphoribosylanthranilate isomerase (EC 5.3.1.24)
# 2 Phosphonopyruvate decarboxylase (EC 4.1.1.82)
# 2 Phosphate ABC transporter, substrate-binding protein PstS (TC 3.A.1.7.1)
# 2 Peroxide stress regulator; Ferric uptake regulation protein; Fe2+/Zn2+ uptake regulation proteins
# 2 Pentapeptide repeat family protein
# 2 Outer membrane assembly lipoprotein YfiO
# 2 OmpA
# 2 Oligopeptide transporter, OPT family
# 2 Na+-driven multidrug efflux pump
# 2 Na(+)-translocating NADH-quinone reductase subunit B (EC 1.6.5.8)
# 2 Murein endolytic transglycosylase MltG
# 2 Multi antimicrobial extrusion protein (Na(+)/drug antiporter), MATE family of MDR efflux pumps
# 2 Methylmalonyl-CoA epimerase (EC 5.1.99.1)
# 2 Lyzozyme M1 (1,4-beta-N-acetylmuramidase) (EC 3.2.1.17)
# 2 LysM-repeat proteins and domains
# 2 Long-chain-fatty-acid--CoA ligase (EC 6.2.1.3)
# 2 Lipopolysaccharide export system permease protein LptG
# 2 LemA protein
# 2 LSU ribosomal protein L34p
# 2 LSU ribosomal protein L33p @ LSU ribosomal protein L33p, zinc-independent
# 2 LSU ribosomal protein L28p @ LSU ribosomal protein L28p, zinc-independent
# 2 L-alanine-DL-glutamate epimerase (EC 5.1.1.n1)
# 2 Isoleucyl-tRNA synthetase (EC 6.1.1.5)
# 2 Integrase protein
# 2 Inner membrane protein YihY, formerly thought to be RNase BN
# 2 Imidazole glycerol phosphate synthase amidotransferase subunit HisH
# 2 Hemin receptor
# 2 Hcp transcriptional regulator HcpR (Crp/Fnr family)
# 2 Glyoxalase family protein
# 2 Glycosyltransferase involved in cell wall biogenesis
# 2 Glycosylase BF2339
# 2 Glycosyl transferase, group 2 family
# 2 Formate-dependent phosphoribosylglycinamide formyltransferase
# 2 Fluoride ion transporter CrcB
# 2 FIG138056: a glutathione-dependent thiol reductase
# 2 FIG00936810: hypothetical protein
# 2 FIG00491264: hypothetical protein
# 2 FIG00414141: hypothetical protein
# 2 FIG00003370: Multicopper polyphenol oxidase
# 2 FHA domain protein
# 2 Exodeoxyribonuclease VII small subunit (EC 3.1.11.6)
# 2 Electron transport complex protein RnfB
# 2 Electron transport complex protein RnfA
# 2 Efflux transport system, outer membrane factor (OMF) lipoprotein
# 2 DnaK suppressor protein, putative
# 2 Dethiobiotin synthase BioD (EC 6.3.3.3)
# 2 DNA/RNA helicases, SNF2 family
# 2 DNA-binding protein HU-beta
# 2 DNA base-flipping protein
# 2 D-glycero-alpha-D-manno-heptose 7-phosphate kinase (EC 2.7.1.168)
# 2 Cytochrome d ubiquinol oxidase subunit II (EC 1.10.3.-)
# 2 Cytidylyltransferase domain / Phosphoenolpyruvate phosphomutase (EC 5.4.2.9)
# 2 Crossover junction endodeoxyribonuclease RuvC (EC 3.1.22.4)
# 2 Conserved protein, with a weak D-galactarate dehydratase/altronate hydrolase domain
# 2 Cobalt-precorrin-7 (C5)-methyltransferase (EC 2.1.1.289) / Cobalt-precorrin-6B C15-methyltransferase [decarboxylating] (EC 2.1.1.196)
# 2 Cobalt-precorrin-2 C(20)-methyltransferase (EC 2.1.1.151)
# 2 Clostripain-related protein
# 2 Chromate transport protein
# 2 Chaperone protein HtpG
# 2 Cation efflux system protein
# 2 Carboxyl-terminal protease
# 2 Biotin carboxyl carrier protein => methylmalonyl-CoA decarboxylase
# 2 Beta-lactamase class C-like and penicillin binding proteins (PBPs) superfamily
# 2 Aspartate carbamoyltransferase regulatory chain (PyrI)
# 2 Asparagine synthetase [glutamine-hydrolyzing] (EC 6.3.5.4)
# 2 Arylsulfatase (EC 3.1.6.1)
# 2 Aminobenzoyl-glutamate transport protein
# 2 Amino acid-binding ACT
# 2 Alpha-ribazole-5'-phosphate phosphatase (EC 3.1.3.73)
# 2 Alkaline phosphatase (EC 3.1.3.1)
# 2 Agmatine deiminase (EC 3.5.3.12)
# 2 Aerotolerance protein BatA
# 2 Adenylylsulfate kinase (EC 2.7.1.25)
# 2 Adenosylcobinamide-phosphate synthase (EC 6.3.1.10)
# 2 Adenosine deaminase (EC 3.5.4.4)
# 2 ATPase RavA
# 2 ATP:Cob(I)alamin adenosyltransferase (EC 2.5.1.17) @ ATP:Cob(I)alamin adenosyltransferase (EC 2.5.1.17), cobalamin synthesis
# 2 ATP-dependent DNA helicase UvrD/PcrA (EC 3.6.4.12)
# 2 ATP-dependent DNA helicase
# 2 ATP synthase beta chain (EC 3.6.3.14)
# 2 ATP synthase alpha chain (EC 3.6.3.14)
# 2 ATP synthase F0 sector subunit a (EC 3.6.3.14)
# 2 AMP nucleosidase (EC 3.2.2.4)
# 2 6-phosphogluconolactonase (EC 3.1.1.31), eukaryotic type
# 2 6-phosphogluconate dehydrogenase, decarboxylating (EC 1.1.1.44)
# 2 5-amino-6-(5-phosphoribosylamino)uracil reductase
# 2 5'-nucleotidase (EC 3.1.3.5); 2',3'-cyclic-nucleotide 2'-phosphodiesterase (EC 3.1.4.16); Putative UDP-sugar hydrolase (EC 3.6.1.45)
# 2 4-keto-6-deoxy-N-Acetyl-D-hexosaminyl-(Lipid carrier) aminotransferase
# 2 4-hydroxy-tetrahydrodipicolinate synthase (EC 4.3.3.7)
# 2 3-deoxy-manno-octulosonate cytidylyltransferase (EC 2.7.7.38)
# 2 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase, delta subunit, ferredoxin-like 4Fe-4S binding protein (EC 1.2.7.-)
# 16 Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family
# 15 Transcriptional regulator, AraC family
# 14 Two-component system sensor histidine kinase
# 13 Thioredoxin
# 12 putative membrane protein
# 12 Putative anti-sigma factor
# 11 Acidobacterial duplicated orphan permease (function unknown)

# %%
gained_genes_counts_nulls_by_tp_type
# Out:
# {'AA': defaultdict(int, {}),
#  'II-nonpremie': defaultdict(int,
#              {'1,4-alpha-glucan (glycogen) branching enzyme, GH-13-type (EC 2.4.1.18)': 0.14,
#               "16S rRNA (cytidine(1402)-2'-O)-methyltransferase (EC 2.1.1.198)": 0.21999999999999997,
#               '2-amino-3-ketobutyrate coenzyme A ligase (EC 2.3.1.29)': 0.27999999999999997,
#               '2-amino-4-hydroxy-6-hydroxymethyldihydropteridine pyrophosphokinase (EC 2.7.6.3)': 0.41999999999999993,
#               '2-methylfumaryl-CoA hydratase (EC 4.2.1.148)': 0.25999999999999995,
#               '2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase, delta subunit, ferredoxin-like 4Fe-4S binding protein (EC 1.2.7.-)': 0.3,
#               '2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase, gamma subunit (EC 1.2.7.-)': 0.27999999999999997,
#               '3-deoxy-manno-octulosonate cytidylyltransferase (EC 2.7.7.38)': 0.23999999999999996,
#               '3-isopropylmalate dehydratase small subunit (EC 4.2.1.33)': 0.34,
#               '3-oxo-5-alpha-steroid 4-dehydrogenase': 0.3,
#               '3-oxoacyl-[acyl-carrier protein] reductase paralog (EC 1.1.1.100)': 0.45999999999999996,
#               '4-diphosphocytidyl-2-C-methyl-D-erythritol kinase (EC 2.7.1.148)': 0.32,
#               '4-hydroxy-2-oxoglutarate aldolase (EC 4.1.3.16) @ 2-dehydro-3-deoxyphosphogluconate aldolase (EC 4.1.2.14)': 0.4799999999999999,
#               '4-hydroxy-tetrahydrodipicolinate synthase (EC 4.3.3.7)': 0.36000000000000004,
#               '4-keto-6-deoxy-N-Acetyl-D-hexosaminyl-(Lipid carrier) aminotransferase': 0.18,
#               "5'-nucleotidase (EC 3.1.3.5); 2',3'-cyclic-nucleotide 2'-phosphodiesterase (EC 3.1.4.16); Putative UDP-sugar hydrolase (EC 3.6.1.45)": 0.3,
#               '5-amino-6-(5-phosphoribosylamino)uracil reductase': 0.18,
#               '6-phosphogluconate dehydrogenase, decarboxylating (EC 1.1.1.44)': 0.38,
#               '6-phosphogluconolactonase (EC 3.1.1.31), eukaryotic type': 0.27999999999999997,
#               'AAA+ superfamily protein': 0.14,
#               'ABC-type antimicrobial peptide transport system, ATPase component': 0.82,
#               'ADP-ribose pyrophosphatase of COG1058 family (EC 3.6.1.13) / Nicotinamide-nucleotide amidase (EC 3.5.1.42)': 0.21999999999999997,
#               'AMP nucleosidase (EC 3.2.2.4)': 0.18,
#               'ATP phosphoribosyltransferase (EC 2.4.2.17) => HisGl': 0.16,
#               'ATP synthase F0 sector subunit a (EC 3.6.3.14)': 0.3,
#               'ATP synthase F0 sector subunit b (EC 3.6.3.14)': 0.23999999999999996,
#               'ATP synthase F0 sector subunit c (EC 3.6.3.14)': 0.45999999999999996,
#               'ATP synthase alpha chain (EC 3.6.3.14)': 0.18,
#               'ATP synthase beta chain (EC 3.6.3.14)': 0.19999999999999998,
#               'ATP synthase epsilon chain (EC 3.6.3.14)': 0.4999999999999999,
#               'ATP synthase gamma chain (EC 3.6.3.14)': 0.54,
#               'ATP synthase protein I': 0.62,
#               'ATP-dependent DNA helicase': 0.16,
#               'ATP-dependent DNA helicase UvrD/PcrA (EC 3.6.4.12)': 0.21999999999999997,
#               'ATP-dependent RNA helicase': 0.6000000000000001,
#               'ATP-dependent RNA helicase BT1154': 0.23999999999999996,
#               'ATP:Cob(I)alamin adenosyltransferase (EC 2.5.1.17)': 0.19999999999999998,
#               'ATP:Cob(I)alamin adenosyltransferase (EC 2.5.1.17) @ ATP:Cob(I)alamin adenosyltransferase (EC 2.5.1.17), cobalamin synthesis': 0.38000000000000006,
#               'ATPase RavA': 0.33999999999999997,
#               'Acetyl esterase': 0.25999999999999995,
#               'Acetyltransferase': 0.16,
#               'Acetyltransferase, GNAT family': 0.25999999999999995,
#               'Acidobacterial duplicated orphan permease (function unknown)': 3.0399999999999996,
#               'Acyltransferase': 0.25999999999999995,
#               'Adenosine deaminase (EC 3.5.4.4)': 0.5599999999999999,
#               'Adenosylcobinamide kinase (EC 2.7.1.156) / Adenosylcobinamide-phosphate guanylyltransferase (EC 2.7.7.62)': 0.58,
#               'Adenosylcobinamide-phosphate synthase (EC 6.3.1.10)': 0.16,
#               'Adenylylsulfate kinase (EC 2.7.1.25)': 0.66,
#               'Aerotolerance protein BatA': 0.41999999999999993,
#               'Aerotolerance protein BatB': 0.43999999999999995,
#               'Aerotolerance protein BatC': 0.41999999999999993,
#               'Aerotolerance protein BatD': 0.38,
#               'Aerotolerance protein BatE': 0.68,
#               'Agmatine deiminase (EC 3.5.3.12)': 0.27999999999999997,
#               'Alkaline phosphatase (EC 3.1.3.1)': 0.34,
#               'Alpha-1,2-fucosyltransferase': 0.36000000000000004,
#               'Alpha-1,4-N-acetylgalactosamine transferase PglH (EC 2.4.1.-)': 0.25999999999999995,
#               'Alpha-N-acetylglucosaminidase (EC 3.2.1.50)': 0.18,
#               "Alpha-ribazole-5'-phosphate phosphatase (EC 3.1.3.73)": 0.16,
#               'Amino acid-binding ACT': 0.58,
#               'Aminobenzoyl-glutamate transport protein': 0.39999999999999997,
#               'Aminodeoxychorismate lyase (EC 4.1.3.38)': 0.42,
#               'Aminotransferase, DegT/DnrJ/EryC1/StrS family': 0.18,
#               'AmpG protein': 0.27999999999999997,
#               'Arabinan endo-1,5-alpha-L-arabinosidase A': 0.25999999999999995,
#               'Arylsulfatase (EC 3.1.6.1)': 0.34,
#               'Arylsulfatase regulator': 0.1,
#               'Asparagine synthetase [glutamine-hydrolyzing] (EC 6.3.5.4)': 0.23999999999999996,
#               'Aspartate carbamoyltransferase (EC 2.1.3.2)': 0.36000000000000004,
#               'Aspartate carbamoyltransferase regulatory chain (PyrI)': 0.3,
#               'Bacterial non-heme ferritin (EC 1.16.3.2)': 0.18,
#               'Bacterial ribosome SSU maturation protein RimP': 0.23999999999999996,
#               'Beta-1,3-glucosyltransferase': 0.32,
#               'Biotin carboxyl carrier protein => methylmalonyl-CoA decarboxylase': 0.21999999999999997,
#               'CAAX amino terminal protease family protein': 0.76,
#               'CRISPR-associated RecB family exonuclease Cas4': 0.21999999999999997,
#               'CRISPR-associated helicase Cas3': 0.34,
#               'CRISPR-associated negative autoregulator Cas7/Cst2': 0.3,
#               'CRISPR-associated protein Cas1': 0.21999999999999997,
#               'CRISPR-associated protein, TM1814 family': 0.38000000000000006,
#               'Capsular polysaccharide biosynthesis protein capD': 0.18,
#               'Capsular polysaccharide transcription antitermination protein UpeY': 0.18,
#               'Capsular polysaccharide transcription antitermination protein, UpxY family': 1.2200000000000002,
#               'Carbon starvation protein A': 0.21999999999999997,
#               'Carboxy-terminal processing protease': 0.23999999999999996,
#               'Carboxyl-terminal protease': 0.18,
#               'Cation efflux system protein': 0.27999999999999997,
#               'Cell division ZapA family protein': 0.21999999999999997,
#               'Cell division protein DivIC (FtsB), stabilizes FtsL against RasP cleavage': 0.4999999999999999,
#               'Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family': 4.14,
#               'Cell surface protein': 0.34,
#               'Chaperone protein DnaJ': 0.46000000000000013,
#               'Chaperone protein HtpG': 0.52,
#               'Chromate transport protein': 0.23999999999999996,
#               'Clostripain-related protein': 0.14,
#               'Co-activator of prophage gene expression IbrB': 0.56,
#               'Cobalamin synthase (EC 2.7.8.26)': 0.27999999999999997,
#               'Cobalt-precorrin-2 C(20)-methyltransferase (EC 2.1.1.151)': 0.18,
#               'Cobalt-precorrin-7 (C5)-methyltransferase (EC 2.1.1.289) / Cobalt-precorrin-6B C15-methyltransferase [decarboxylating] (EC 2.1.1.196)': 0.21999999999999997,
#               'Cobyric acid synthase (EC 6.3.5.10)': 0.32,
#               'Conjugative transposon protein TraM': 0.27999999999999997,
#               'Conserved hypothetical protein 22': 0.41999999999999993,
#               'Conserved protein YuxK': 0.62,
#               'Conserved protein, with a weak D-galactarate dehydratase/altronate hydrolase domain': 0.4400000000000001,
#               'Crossover junction endodeoxyribonuclease RuvC (EC 3.1.22.4)': 0.21999999999999997,
#               'Cys-tRNA(Pro) deacylase YbaK': 0.39999999999999997,
#               'Cystathionine beta-lyase (EC 4.4.1.8)': 0.27999999999999997,
#               'Cytidylyltransferase domain / Phosphoenolpyruvate phosphomutase (EC 5.4.2.9)': 0.25999999999999995,
#               'Cytochrome d ubiquinol oxidase subunit II (EC 1.10.3.-)': 0.21999999999999997,
#               'CzcABC family efflux RND transporter, outer membrane protein': 0.5599999999999999,
#               'D-alanine--poly(phosphoribitol) ligase ACP subunit (EC 6.1.1.13)': 0.49999999999999994,
#               'D-glycero-alpha-D-manno-heptose 7-phosphate kinase (EC 2.7.1.168)': 0.3,
#               'DNA base-flipping protein': 0.25999999999999995,
#               'DNA ligase (NAD(+)) (EC 6.5.1.2)': 0.56,
#               'DNA polymerase III delta subunit (EC 2.7.7.7)': 0.5399999999999999,
#               'DNA protection during starvation protein': 0.25999999999999995,
#               'DNA-binding protein': 0.21999999999999997,
#               'DNA-binding protein HU-beta': 0.5,
#               'DNA-directed RNA polymerase omega subunit (EC 2.7.7.6)': 0.4799999999999999,
#               'DNA/RNA helicases, SNF2 family': 0.27999999999999997,
#               'Death on curing protein, Doc toxin': 0.19999999999999998,
#               'Dephospho-CoA kinase (EC 2.7.1.24)': 0.32,
#               'Dethiobiotin synthase BioD (EC 6.3.3.3)': 0.27999999999999997,
#               'Diacylglycerol kinase (EC 2.7.1.107)': 0.66,
#               'Dihydroorotate dehydrogenase (NAD(+)), catalytic subunit (EC 1.3.1.14)': 0.41999999999999993,
#               'Dihydroorotate dehydrogenase (NAD(+)), electron transfer subunit (EC 1.3.1.14)': 0.44,
#               'Dihydroorotate dehydrogenase (quinone) (EC 1.3.5.2)': 0.4999999999999999,
#               'DnaD domain protein': 0.25999999999999995,
#               'DnaK suppressor protein, putative': 0.18,
#               'DoxX family protein': 0.44,
#               'Efflux ABC transporter, permease protein': 0.54,
#               'Efflux transport system, outer membrane factor (OMF) lipoprotein': 0.1,
#               'Efflux transport system, outer membrane factor (OMF) lipoprotein BT_0954': 0.38000000000000006,
#               'Electron transport complex protein RnfA': 0.23999999999999996,
#               'Electron transport complex protein RnfB': 0.32,
#               'Electron transport complex protein RnfG': 0.19999999999999998,
#               'Endo-1,4-beta-xylanase D': 0.16,
#               'Endonuclease': 0.56,
#               'Energy-dependent translational throttle protein EttA': 0.23999999999999996,
#               'Error-prone, lesion bypass DNA polymerase V (UmuC)': 0.36000000000000004,
#               'Exodeoxyribonuclease VII small subunit (EC 3.1.11.6)': 0.25999999999999995,
#               'FAD:protein FMN transferase (EC 2.7.1.180)': 0.23999999999999996,
#               'FHA domain protein': 0.5199999999999999,
#               'FIG00003370: Multicopper polyphenol oxidase': 0.16,
#               'FIG000605: protein co-occurring with transport systems (COG1739)': 0.5,
#               'FIG00414141: hypothetical protein': 0.25999999999999995,
#               'FIG00490011: hypothetical protein': 0.4999999999999999,
#               'FIG00491264: hypothetical protein': 0.32,
#               'FIG00936810: hypothetical protein': 0.39999999999999997,
#               'FIG01416087: hypothetical protein': 0.16,
#               'FIG015287: Zinc protease': 0.16,
#               'FIG016027: protein of unknown function YeaO': 0.58,
#               'FIG137478: Hypothetical protein': 0.56,
#               'FIG138056: a glutathione-dependent thiol reductase': 0.4200000000000001,
#               'FKBP-type peptidyl-prolyl cis-trans isomerase FkpA precursor (EC 5.2.1.8)': 0.4000000000000001,
#               'Ferredoxin': 0.23999999999999996,
#               'Ferredoxin domain containing protein': 0.32,
#               'Flavodoxin': 0.25999999999999995,
#               'Flavoredoxin': 0.41999999999999993,
#               'Fluoride ion transporter CrcB': 0.25999999999999995,
#               'Formate--tetrahydrofolate ligase (EC 6.3.4.3)': 0.25999999999999995,
#               'Formate-dependent phosphoribosylglycinamide formyltransferase': 0.34,
#               'Fosmidomycin resistance protein': 0.5800000000000001,
#               'Free methionine-(R)-sulfoxide reductase, contains GAF domain': 0.68,
#               'Fructose-1,6-bisphosphatase, Bacillus type (EC 3.1.3.11)': 0.21999999999999997,
#               'GTP cyclohydrolase 1 type 2 homolog YbgI @ Bsu YqfO NIF3/CutA domain': 0.43999999999999995,
#               'GTP-binding protein EngB': 0.18,
#               'GldB': 0.3,
#               'Gll2767 protein': 0.32,
#               'Glucosamine-1-phosphate guanylyltransferase': 0.23999999999999996,
#               'Glycerophosphoryl diester phosphodiesterase (EC 3.1.4.46)': 0.34,
#               'Glycosyl transferase, family 2': 0.34,
#               'Glycosyl transferase, group 1': 0.32,
#               'Glycosyl transferase, group 1 family protein': 0.32,
#               'Glycosyl transferase, group 2 family': 0.27999999999999997,
#               'Glycosylase BF2339': 0.41999999999999993,
#               'Glycosyltransferase': 0.8999999999999999,
#               'Glycosyltransferase involved in cell wall biogenesis': 0.62,
#               'Glyoxalase family protein': 0.27999999999999997,
#               'Guanine deaminase (EC 3.5.4.3)': 0.32,
#               'Hcp transcriptional regulator HcpR (Crp/Fnr family)': 0.19999999999999998,
#               'Heat shock protein GrpE': 0.19999999999999998,
#               'Heat shock protein HtpX': 0.38000000000000006,
#               'Helicase': 0.36000000000000004,
#               'Helicase, C-terminal:Type III restriction enzyme, res subunit:DEAD/DEAH box helicase, N-terminal': 0.6599999999999999,
#               'Hemin receptor': 0.36000000000000004,
#               'Huntingtin interacting protein E-like protein': 0.32,
#               'Hydroxylamine reductase (EC 1.7.99.1)': 0.3,
#               'Hydroxymethylpyrimidine phosphate kinase ThiD (EC 2.7.4.7)': 0.19999999999999998,
#               'Hypothetical Nudix-like regulator': 0.39999999999999997,
#               'ISNCY family transposase': 1.2000000000000002,
#               'Imidazole glycerol phosphate synthase amidotransferase subunit HisH': 0.5199999999999999,
#               'Imidazole glycerol phosphate synthase cyclase subunit': 0.21999999999999997,
#               'Immunoreactive 53 kDa antigen PG123': 0.45999999999999996,
#               'Indole-3-glycerol phosphate synthase (EC 4.1.1.48)': 0.39999999999999997,
#               'Inner membrane protein RclC associated with response to reactive chlorine species': 0.36000000000000004,
#               'Inner membrane protein YhiM': 0.5399999999999999,
#               'Inner membrane protein YihY, formerly thought to be RNase BN': 0.21999999999999997,
#               'Inorganic pyrophospatase PpaX': 0.23999999999999996,
#               'Integral membrane protein': 0.6,
#               'Integrase': 1.66,
#               'Integrase IntN1': 0.19999999999999998,
#               'Integrase protein': 0.18,
#               'Integration host factor alpha subunit': 0.54,
#               'Integration host factor beta subunit': 0.25999999999999995,
#               'Intracellular protease': 0.21999999999999997,
#               'Iron-sulfur flavoprotein': 0.3,
#               'Isoleucyl-tRNA synthetase (EC 6.1.1.5)': 0.21999999999999997,
#               'Keratan-sulfate endo-1,4-beta-galactosidase (EC 3.2.1.103)': 0.3,
#               'L-alanine-DL-glutamate epimerase (EC 5.1.1.n1)': 0.14,
#               'L-fucose kinase (EC 2.7.1.52)': 0.23999999999999996,
#               'L-fucose mutarotase (EC 5.1.3.29)': 0.27999999999999997,
#               'LSU ribosomal protein L24p (L26e)': 0.27999999999999997,
#               'LSU ribosomal protein L28p @ LSU ribosomal protein L28p, zinc-independent': 0.27999999999999997,
#               'LSU ribosomal protein L29p (L35e)': 0.12000000000000001,
#               'LSU ribosomal protein L33p @ LSU ribosomal protein L33p, zinc-independent': 0.25999999999999995,
#               'LSU ribosomal protein L34p': 0.12000000000000001,
#               'Lactaldehyde reductase (EC 1.1.1.77)': 0.4000000000000001,
#               'Large-conductance mechanosensitive channel': 0.7000000000000001,
#               'LemA protein': 0.38000000000000006,
#               'Lipid-A-disaccharide synthase (EC 2.4.1.182)': 0.19999999999999998,
#               'Lipopolysaccharide export system permease protein LptG': 0.45999999999999996,
#               'Lipoprotein signal peptidase (EC 3.4.23.36)': 0.4799999999999999,
#               'Long tail fiber protein p37': 0.18,
#               'Long-chain-fatty-acid--CoA ligase (EC 6.2.1.3)': 0.36,
#               'LysM-repeat proteins and domains': 0.27999999999999997,
#               'Lyzozyme M1 (1,4-beta-N-acetylmuramidase) (EC 3.2.1.17)': 0.27999999999999997,
#               'MBL-fold metallo-hydrolase superfamily': 0.49999999999999994,
#               'Malonyl CoA-acyl carrier protein transacylase (EC 2.3.1.39)': 0.39999999999999997,
#               'Mannan endo-1,4-beta-mannosidase': 0.18,
#               'Mannose-1-phosphate guanylyltransferase (EC 2.7.7.13)': 0.46000000000000013,
#               'Membrane protein': 0.66,
#               'Membrane protein involved in the export of O-antigen, teichoic acid lipoteichoic acids': 0.19999999999999998,
#               'Metal-dependent hydrolase YbeY, involved in rRNA and/or ribosome maturation and assembly': 0.25999999999999995,
#               'Methylmalonyl-CoA epimerase (EC 5.1.99.1)': 0.32,
#               'Monofunctional biosynthetic peptidoglycan transglycosylase': 0.8800000000000001,
#               'Multi antimicrobial extrusion protein (Na(+)/drug antiporter), MATE family of MDR efflux pumps': 0.23999999999999996,
#               'Multidrug resistance protein': 0.4799999999999999,
#               'Murein endolytic transglycosylase MltG': 0.6,
#               'MutT/Nudix family protein': 0.27999999999999997,
#               'N(6)-L-threonylcarbamoyladenine synthase (EC 2.3.1.234)': 0.5,
#               'N-acetylgalactosamine-6-sulfatase': 0.27999999999999997,
#               'N-acetylglucosaminyltransferase (EC 2.4.1.-)': 0.43999999999999995,
#               'N-acetylmuramoyl-L-alanine amidase (EC 3.5.1.28)': 0.72,
#               'N-acetylneuraminate lyase (EC 4.1.3.3)': 0.16,
#               'N-acetylneuraminate synthase (EC 2.5.1.56)': 0.4200000000000001,
#               'N-acylneuraminate cytidylyltransferase (EC 2.7.7.43)': 0.7799999999999999,
#               'N-carbamoylputrescine amidase (EC 3.5.1.53)': 0.18,
#               'N-carbamoylputrescine amidase (EC 3.5.1.53) @ Aliphatic amidase AmiE (EC 3.5.1.4)': 0.18,
#               'Na(+)-translocating NADH-quinone reductase subunit B (EC 1.6.5.8)': 0.25999999999999995,
#               'Na+-driven multidrug efflux pump': 0.21999999999999997,
#               'Na+/H+-dicarboxylate symporter': 0.56,
#               'Nitrogen regulation protein NtrY (EC 2.7.3.-)': 0.25999999999999995,
#               'Nitroreductase family protein': 0.5599999999999999,
#               'O-acetylhomoserine sulfhydrylase (EC 2.5.1.49) @ O-succinylhomoserine sulfhydrylase (EC 2.5.1.48)': 0.6,
#               'Oligopeptide transporter, OPT family': 0.27999999999999997,
#               'OmpA': 0.25999999999999995,
#               'OmpA family outer membrane protein': 0.68,
#               'Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family': 2.3200000000000003,
#               'Outer membrane assembly lipoprotein YfiO': 0.5800000000000002,
#               'Outer membrane protein romA': 0.45999999999999996,
#               'Outer membrane receptor for Fe3+-dicitrate': 0.23999999999999996,
#               'Oxaloacetate decarboxylase Na(+) pump, gamma chain (EC 4.1.1.3)': 0.21999999999999997,
#               'Oxidoreductase': 0.5800000000000001,
#               'Oxidoreductase, aldo/keto reductase family': 0.8200000000000001,
#               'PAP2 superfamily protein': 0.52,
#               'Pantoate--beta-alanine ligase (EC 6.3.2.1)': 0.19999999999999998,
#               'Para-aminobenzoate synthase, aminase component (EC 2.6.1.85)': 0.45999999999999996,
#               'Pentapeptide repeat family protein': 0.32,
#               'Peptidase, S41 family': 0.25999999999999995,
#               'Peptide deformylase (EC 3.5.1.88)': 0.34,
#               'Permease of the drug/metabolite transporter (DMT) superfamily': 0.96,
#               'Peroxide stress regulator; Ferric uptake regulation protein; Fe2+/Zn2+ uptake regulation proteins': 0.34,
#               'Phage integrase': 0.58,
#               'Phage protein': 0.27999999999999997,
#               'Phosphate ABC transporter, substrate-binding protein PstS (TC 3.A.1.7.1)': 0.16,
#               'Phosphate/pyrophosphate-specific outer membrane porin OprP/OprO': 0.7200000000000001,
#               'Phosphonopyruvate decarboxylase (EC 4.1.1.82)': 0.19999999999999998,
#               'Phosphoribosylanthranilate isomerase (EC 5.3.1.24)': 0.18,
#               'Phosphoribosylformimino-5-aminoimidazole carboxamide ribotide isomerase (EC 5.3.1.16)': 0.6,
#               'Pirin': 0.18,
#               'Polysaccharide deacetylase': 0.23999999999999996,
#               'Polysaccharide deacetylase-like protein': 0.3,
#               'Possible exported heavy-metal binding protein': 0.6200000000000001,
#               'Possible glyoxylase family protein (Lactoylglutathione lyase) (EC 4.4.1.5)': 0.43999999999999995,
#               'Possible restriction /modification enzyme': 0.23999999999999996,
#               'Predicted cobalt transporter in Bacteroides_Porphyromonas': 0.16,
#               'Predicted dye-decolorizing peroxidase (DyP), encapsulated subgroup': 0.38000000000000006,
#               'Predicted transcriptional regulator': 0.21999999999999997,
#               'Probable integral membrane protein Cj1165c': 0.62,
#               'Probable integral membrane protein Cj1166c': 0.23999999999999996,
#               'Probable iron export ATP-binding protein FetA': 0.5399999999999999,
#               'Proline dehydrogenase (EC 1.5.5.2) / Delta-1-pyrroline-5-carboxylate dehydrogenase (EC 1.2.1.88)': 0.25999999999999995,
#               'Prolyl oligopeptidase family protein': 0.34,
#               'Protein BF2544, predicted transporter component': 0.56,
#               'Protein DUF2149, predicted transporter component': 0.18,
#               'Protein of unknown function UPF0060': 0.21999999999999997,
#               'Protein translocase membrane subunit SecG': 0.34,
#               'Protein translocase subunit YajC': 0.23999999999999996,
#               'Putative ATP-binding protein': 0.4200000000000001,
#               'Putative DNA-binding protein': 0.38,
#               'Putative Na+/H+ exchange protein': 0.21999999999999997,
#               'Putative alpha-1,6-mannanase': 0.25999999999999995,
#               'Putative aminotransferase BF2110': 0.32,
#               'Putative anti-sigma factor': 2.6999999999999997,
#               'Putative calcineurin superfamily phosphohydrolase': 0.34,
#               'Putative dipeptidase': 0.16,
#               'Putative glycosyltransferase': 0.9399999999999997,
#               'Putative helicase': 1.14,
#               'Putative lipopolysaccharide biosynthesis protein': 0.27999999999999997,
#               'Putative manganese efflux pump MntP': 0.16,
#               'Putative membrane-associated metal-dependent hydrolase': 0.19999999999999998,
#               'Putative molybdenum transport ATP-binding protein modF': 0.3,
#               'Putative outer membrane protein, probably involved in nutrient binding': 0.5800000000000001,
#               'Putative periplasmic protein': 0.39999999999999997,
#               'Putative permease': 0.36,
#               'Putative phage-encoded peptidoglycan binding protein': 0.25999999999999995,
#               'Putative phosphatidylinositol-4-phosphate 5-kinase': 0.19999999999999998,
#               'Putative pre-16S rRNA nuclease YqgF': 0.39999999999999997,
#               'Putative preQ0 transporter YhhQ': 0.36000000000000004,
#               'Putative secreted polysaccharide polymerase': 0.23999999999999996,
#               'Putative sodium-dependent transporter': 0.19999999999999998,
#               'Putative thioredoxin': 0.45999999999999996,
#               'Pyridoxal phosphate-containing protein YggS': 0.34,
#               'Pyruvate formate-lyase activating enzyme (EC 1.97.1.4)': 0.3,
#               'Pyruvate:Oxaloacetate transcarboxylase domain protein / Biotin carboxyl carrier protein': 0.21999999999999997,
#               'Quinolinate synthetase (EC 2.5.1.72)': 0.21999999999999997,
#               'RNA methyltransferase, TrmH family': 0.36,
#               'RNA polymerase ECF-type sigma factor': 9.079999999999998,
#               'RNA-binding protein': 1.6400000000000001,
#               'RND efflux system, inner membrane transporter': 0.3,
#               'ROK family sugar kinase or transcriptional regulator': 0.68,
#               'Recombination protein RecR': 0.6,
#               'Regulatory sensor-transducer, BlaR1/MecR1 family / TonB-dependent receptor': 0.25999999999999995,
#               'Related to F420H2-dehydrogenase, beta subunit': 0.19999999999999998,
#               'Ribonuclease G': 0.21999999999999997,
#               'Ribonucleotide reductase of class Ia (aerobic), beta subunit (EC 1.17.4.1)': 0.23999999999999996,
#               'Ribose-5-phosphate isomerase B (EC 5.3.1.6)': 0.32,
#               'Ribose-phosphate pyrophosphokinase (EC 2.7.6.1)': 0.34,
#               'Ribosomal protein S12p Asp88 (E. coli) methylthiotransferase (EC 2.8.4.4)': 0.46,
#               'Ribosomal silencing factor RsfA': 0.62,
#               'Ribosomal-protein-S5p-alanine acetyltransferase (EC 2.3.1.128)': 0.23999999999999996,
#               'Ribosome hibernation promoting factor Hpf': 0.21999999999999997,
#               'Ribosome-associated heat shock protein implicated in the recycling of the 50S subunit (S4 paralog)': 0.45999999999999996,
#               'Ribosylnicotinamide kinase (EC 2.7.1.22) homolog / Unknown conserved in Flavobacteria': 0.45999999999999996,
#               'RidA/YER057c/UK114 superfamily protein': 0.48,
#               'Rod shape-determining protein MreD': 0.34,
#               'Rrf2-linked NADH-flavin reductase': 0.45999999999999996,
#               'Rubredoxin': 0.27999999999999997,
#               'SAM-dependent methyltransferase': 0.25999999999999995,
#               'SSU ribosomal protein S14p (S29e) @ SSU ribosomal protein S14p (S29e), zinc-independent': 0.16,
#               'SSU ribosomal protein S20p': 0.22,
#               'SSU ribosomal protein S6p': 0.21999999999999997,
#               'SanA protein': 0.43999999999999995,
#               'SclB protein': 0.94,
#               'Ser-tRNA(Ala) deacylase @ Gly-tRNA(Ala) deacylase': 0.18,
#               'Ser/Thr protein phosphatase family protein, UDP-2,3-diacylglucosamine hydrolase (EC 3.6.1.-) homolog': 0.42,
#               'Serine hydroxymethyltransferase (EC 2.1.2.1)': 0.18,
#               'Serine palmitoyltransferase (EC 2.3.1.50)': 0.34,
#               'Serine protease': 0.54,
#               'Serine/threonine kinase': 0.14,
#               'Sigma factor RpoE regulatory protein RseC': 0.4999999999999999,
#               'Signal recognition particle receptor FtsY': 0.21999999999999997,
#               'Similar to conjugative transposon protein TraB': 0.4200000000000001,
#               'Sirohydrochlorin cobaltochelatase CbiK (EC 4.99.1.3) @ Sirohydrochlorin ferrochelatase activity of CbiK (EC 4.99.1.4)': 0.5800000000000001,
#               'Slr1117 protein': 0.49999999999999994,
#               'Small heat shock protein': 0.68,
#               'Sodium/proline symporter': 0.27999999999999997,
#               'Stress responsive alpha-beta barrel domain protein Dabb': 0.6,
#               'Succinyl-CoA ligase [ADP-forming] alpha chain (EC 6.2.1.5)': 0.23999999999999996,
#               'Succinyl-CoA ligase [ADP-forming] beta chain (EC 6.2.1.5)': 0.23999999999999996,
#               'Sugar-phosphate nucleotidyl transferase': 0.18,
#               'Sulfur carrier protein ThiS': 0.21999999999999997,
#               'Sulfur carrier protein ThiS adenylyltransferase (EC 2.7.7.73)': 0.23999999999999996,
#               'Superfamily I DNA and RNA helicases and helicase subunits': 0.3,
#               'Superfamily I DNA/RNA helicase protein': 0.32,
#               'Superoxide dismutase [Mn/Fe] (EC 1.15.1.1)': 0.32,
#               'T6SS PAAR-repeat protein / RhaS protein': 0.14,
#               'TPR domain protein': 0.25999999999999995,
#               'TPR repeat precursor': 0.3,
#               'TPR repeat:TPR repeat precursor': 0.38000000000000006,
#               'TPR-repeat-containing protein': 0.5399999999999999,
#               'Tetracenomycin polyketide synthesis O-methyltransferase TcmP': 0.32,
#               'Thiamin-phosphate pyrophosphorylase (EC 2.5.1.3)': 0.34,
#               'Thiol peroxidase, Bcp-type (EC 1.11.1.15)': 0.68,
#               'Thiol peroxidase, Tpx-type (EC 1.11.1.15)': 0.36000000000000004,
#               'Thiol:disulfide interchange protein': 0.48,
#               'Thiol:disulfide interchange protein tlpA': 0.4400000000000001,
#               'Thioredoxin': 1.9799999999999998,
#               'Thioredoxin domain-containing protein BT1583': 0.21999999999999997,
#               'Tll0814 protein': 0.45999999999999996,
#               'Tn5520-like integrase': 0.27999999999999997,
#               'TonB family protein': 0.5,
#               'TonB-dependent receptor': 0.21999999999999997,
#               'Transcription accessory protein (S1 RNA-binding domain)': 0.19999999999999998,
#               'Transcription regulator [contains diacylglycerol kinase catalytic domain]': 0.32,
#               'Transcription termination protein NusB': 0.38,
#               'Transcriptional regulator': 0.38000000000000006,
#               'Transcriptional regulator YeiE, LysR family': 0.1,
#               'Transcriptional regulator of fucose utilization, GntR family': 0.18,
#               'Transcriptional regulator, AcrR family': 0.52,
#               'Transcriptional regulator, AraC family': 2.9800000000000004,
#               'Transcriptional regulator, AsnC family': 0.5,
#               'Transcriptional regulator, LuxR family': 0.14,
#               'Transcriptional regulator, MarR family': 0.34,
#               'Transcriptional regulator, PadR family': 0.21999999999999997,
#               'Transcriptional repressor, BlaI/MecI family': 0.21999999999999997,
#               'Transglycosylase-associated protein': 0.45999999999999996,
#               'Translation initiation factor 3': 0.54,
#               'Translation initiation factor SUI1-related protein': 0.36,
#               'Transmembrane protein': 0.5199999999999999,
#               'Transporter, LysE family': 0.3,
#               'Transposase': 0.44,
#               'Trk potassium uptake system protein TrkH': 0.14,
#               'Tryptophan synthase (indole-salvaging) (EC 4.2.1.122)': 0.33999999999999997,
#               'Twin-arginine translocation protein TatA': 0.38000000000000006,
#               'Two-component system sensor histidine kinase': 2.44,
#               'Two-component system sensor histidine kinase/response regulator hybrid': 0.18,
#               'Two-component transcriptional response regulator, LuxR family': 1.1,
#               'Two-component transcriptional response regulator, LuxR family BT1217': 0.5800000000000001,
#               'Two-component transcriptional response regulator, OmpR family': 0.3,
#               'Tyrosine type site-specific recombinase': 0.56,
#               'Tyrosine-protein kinase EpsD (EC 2.7.10.2)': 0.21999999999999997,
#               'UDP-N-acetylglucosamine 2-epimerase (EC 5.1.3.14)': 0.32,
#               'UDP-galactose-lipid carrier transferase (EC 2.-.-.-)': 0.19999999999999998,
#               'UDP-glucose 4-epimerase (EC 5.1.3.2)': 0.6199999999999999,
#               'UDP-glucuronate decarboxylase (EC 4.1.1.35)': 0.41999999999999993,
#               'UPF0056 inner membrane protein MarC': 0.48,
#               'UPF0126 inner membrane protein BT_1201': 0.5,
#               'UPF0145 protein YbjQ': 0.3,
#               'UPF0246 protein YaaA': 0.25999999999999995,
#               'UPF0301 protein YqgE': 0.21999999999999997,
#               'UPF0324 inner membrane protein YeiH': 0.19999999999999998,
#               'Uncharacterized MFS-type transporter': 1.7400000000000002,
#               'Uncharacterized membrane protein PA1577': 0.62,
#               'Uncharacterized membrane protein YsdA': 0.32,
#               'Uncharacterized protein BT1741': 0.21999999999999997,
#               'Uncharacterized protein BT4380': 0.37999999999999995,
#               'Uncharacterized protein BT_4646': 0.19999999999999998,
#               'Uncharacterized protein CHU_1311': 0.18,
#               'Uncharacterized protein TTC1240': 0.21999999999999997,
#               'Uncharacterized protein YgbA': 0.68,
#               'Undecaprenyl-phosphate alpha-N-acetylglucosaminyl 1-phosphate transferase (EC 2.7.8.33)': 0.6799999999999999,
#               'Undecaprenyl-phosphate galactosephosphotransferase (EC 2.7.8.6)': 0.27999999999999997,
#               'UpdZ protein': 0.41999999999999993,
#               'Uracil permease @ Uracil:proton symporter UraA': 0.21999999999999997,
#               'Uracil-DNA glycosylase, family 1 (EC 3.2.2.27)': 0.19999999999999998,
#               'Uronate isomerase (EC 5.3.1.12)': 0.43999999999999995,
#               'UspA': 0.5399999999999999,
#               'V-type ATP synthase subunit C (EC 3.6.3.14)': 0.32,
#               'V-type ATP synthase subunit D (EC 3.6.3.14)': 0.32,
#               'V-type ATP synthase subunit E (EC 3.6.3.14)': 0.52,
#               'V-type ATP synthase subunit K (EC 3.6.3.14)': 0.19999999999999998,
#               'Vitamin B12 ABC transporter, permease protein BtuC': 0.58,
#               'Vitamin B12 ABC transporter, substrate-binding protein BtuF': 1.1199999999999999,
#               'Voltage-gated H(+)/2Cl(-) exchange transporter ClcA': 0.3,
#               'Xanthine phosphoribosyltransferase (EC 2.4.2.22)': 0.19999999999999998,
#               'Xylanase': 0.56,
#               'Xylulose kinase (EC 2.7.1.17)': 0.18,
#               'Ync': 0.5599999999999999,
#               'Zn-ribbon-containing, possibly RNA-binding protein and truncated derivatives': 0.45999999999999996,
#               '[FeFe]-hydrogenase maturation protein HydF': 0.4799999999999999,
#               'alpha-L-fucosidase (EC 3.2.1.51)': 0.25999999999999995,
#               'archaeal ATPase, fused to C-terminal DUF234 domain': 0.52,
#               'beta-N-acetylglucosaminidase (EC 3.2.1.52)': 0.3,
#               'beta-galactosidase (EC 3.2.1.23)': 0.25999999999999995,
#               'beta-glucosidase (EC 3.2.1.21)': 0.25999999999999995,
#               'beta-glycosyl hydrolase': 0.56,
#               'cAMP-binding proteins - catabolite gene activator and regulatory subunit of cAMP-dependent protein kinases': 1.24,
#               'cytochrome c biogenesis protein': 0.52,
#               'dTDP-4-dehydrorhamnose 3,5-epimerase (EC 5.1.3.13)': 0.41999999999999993,
#               'dTDP-4-dehydrorhamnose reductase (EC 1.1.1.133)': 0.52,
#               'galactosamine-containing minor teichoic acid biosynthesis protein': 0.25999999999999995,
#               'hypothetical domain / Cold shock protein of CSP family': 0.21999999999999997,
#               'hypothetical protein': 360.3799999999995,
#               'hypothetical protein; Some similarities with the C-terminal region of hemagglutinin/hemolysin-related protein and with purine NTPase': 0.23999999999999996,
#               'low molecular weight phosphatase supefamily': 0.19999999999999998,
#               'mobilization protein B': 0.5599999999999999,
#               'probable lipoprotein YPO2292': 0.18,
#               'putative DNA mismatch repair protein': 0.25999999999999995,
#               'putative N-acetylmuramoyl-L-alanine amidase': 0.19999999999999998,
#               'putative TonB-dependent outer membrane protein': 0.16,
#               'putative UndPP-QuiNAc-P-transferase': 0.54,
#               'putative acetyltransferase': 0.27999999999999997,
#               'putative capsule polysaccharide export protein': 0.32,
#               'putative integration host factor IHF alpha subunit': 0.49999999999999994,
#               'putative lipoprotein': 0.7000000000000001,
#               'putative membrane protein': 1.72,
#               'putative patatin-like phospholipase': 0.45999999999999996,
#               'putative phosphatase/phosphohexomutase': 0.21999999999999997,
#               'putative protease I': 0.27999999999999997,
#               'putative protein involved in capsular polysaccharide biosynthesis': 0.21999999999999997,
#               'putative pyrogenic exotoxin B': 0.21999999999999997,
#               'sodium/iodide co-transporter': 0.32,
#               'tRNA (5-methylaminomethyl-2-thiouridylate)-methyltransferase (EC 2.1.1.61)': 0.43999999999999995,
#               'tRNA (guanine(37)-N(1))-methyltransferase (EC 2.1.1.228)': 0.68,
#               'tRNA dimethylallyltransferase (EC 2.5.1.75)': 0.12000000000000001,
#               'tRNA(1)(Val) (adenine(37)-N(6))-methyltransferase (EC 2.1.1.223)': 0.3,
#               'tmRNA-binding protein SmpB': 0.6}),
#  'II-premie': defaultdict(int,
#              {'Aminoglycoside 6-nucleotidyltransferase (EC 2.7.7.-) => ANT(6)-I': 0,
#               'Mobilization protein MobA @ Conjugal transfer protein TraA': 0,
#               'TnpY-like protein': 0,
#               'hypothetical protein': 0}),
#  'MI-nonpremie': defaultdict(int, {}),
#  'MI-premie': defaultdict(int, {}),
#  'MM': defaultdict(int, {})}

# %%
tp_types = ['AA', 'II-premie', 'II-nonpremie','MM', 'MI-premie', 'MI-nonpremie']
num_gene_losses_by_tp_type = {tp_type: 0 for tp_type in tp_types}
lost_genes_by_tp_type = {tp_type: set() for tp_type in tp_types}
lost_genes_counts_by_tp_type = {tp_type: defaultdict(int) for tp_type in tp_types}
lost_genes_counts_nulls_by_tp_type = {tp_type: defaultdict(int) for tp_type in tp_types}

# Enumerate genes
for species in modification_gene_losses:
    for cohort in modification_gene_losses[species]:
        for subject in modification_gene_losses[species][cohort]:
            subdict = modification_gene_losses[species][cohort][subject]
            subdict_null = modification_gene_losses_present_null[species][cohort][subject]
            # For each sample pair in this cohort/species,
            # have a count of how many gains of a particular gene
            for tp_pair in subdict:
                tp_type = tp_pair_to_tp_type(tp_pair, cohort)
                for gene_id, gene_name in subdict[tp_pair]:
                    gene_loss_count = subdict[tp_pair][(gene_id, gene_name)]
                    gene_loss_count_null = subdict_null[tp_pair][(gene_id, gene_name)]
                    num_gene_losses_by_tp_type[tp_type] += gene_gain_count
                    lost_genes_by_tp_type[tp_type].add(gene_name)
                    lost_genes_counts_by_tp_type[tp_type][gene_name] += gene_gain_count
                    lost_genes_counts_nulls_by_tp_type[tp_type][gene_name] += gene_gain_count_null

# %%
num_gene_losses_by_tp_type
# Out:
# {'AA': 17,
#  'II-nonpremie': 60,
#  'II-premie': 6,
#  'MI-nonpremie': 1792,
#  'MI-premie': 0,
#  'MM': 0}

# %%
for tp_type in lost_genes_by_tp_type:
    count = len(lost_genes_by_tp_type[tp_type])
    print('%i %s' % (count, tp_type))
# Out:
# 7 AA
# 5 II-premie
# 0 MI-premie
# 0 MM
# 407 MI-nonpremie
# 24 II-nonpremie

# %%
for tp_type in lost_genes_counts_by_tp_type:
    print(tp_type)
    strs = []
    for gene_name in lost_genes_counts_by_tp_type[tp_type]:
        count = lost_genes_counts_by_tp_type[tp_type][gene_name]
        if count > 1:
            strs.append("%i %s" % (count, gene_name))
    for string in sorted(strs, reverse=True):
        print(string)
    print('')
# Out:
# AA
# 11 hypothetical protein
#
# II-premie
# 2 hypothetical protein
#
# MI-premie
#
# MM
#
# MI-nonpremie
# 8 Transcriptional regulator, AraC family
# 7 putative membrane protein
# 7 Two-component system sensor histidine kinase
# 7 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 7 Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family
# 6 Glycosyltransferase
# 5 cAMP-binding proteins - catabolite gene activator and regulatory subunit of cAMP-dependent protein kinases
# 5 Thioredoxin
# 5 Putative anti-sigma factor
# 4 Uncharacterized MFS-type transporter
# 4 RNA-binding protein
# 4 Putative helicase
# 3 putative TonB-dependent receptor
# 3 UpdZ protein
# 3 Two-component transcriptional response regulator, LuxR family
# 3 Transcriptional regulator, AcrR family
# 3 Permease of the drug/metabolite transporter (DMT) superfamily
# 3 O-acetylhomoserine sulfhydrylase (EC 2.5.1.49) @ O-succinylhomoserine sulfhydrylase (EC 2.5.1.48)
# 3 N-acetylmuramoyl-L-alanine amidase (EC 3.5.1.28)
# 3 Membrane protein involved in the export of O-antigen, teichoic acid lipoteichoic acids
# 3 Lipopolysaccharide biosynthesis protein
# 3 Efflux ABC transporter, permease protein
# 3 Conserved protein, with a weak D-galactarate dehydratase/altronate hydrolase domain
# 3 Acidobacterial duplicated orphan permease (function unknown)
# 3 Acetyltransferase, GNAT family
# 3 ABC-type antimicrobial peptide transport system, ATPase component
# 2 tRNA (guanine(37)-N(1))-methyltransferase (EC 2.1.1.228)
# 2 dTDP-4-dehydrorhamnose 3,5-epimerase (EC 5.1.3.13)
# 2 [FeFe]-hydrogenase maturation protein HydF
# 2 UDP-glucose 4-epimerase (EC 5.1.3.2)
# 2 UDP-N-acetylglucosamine 2-epimerase (EC 5.1.3.14)
# 2 Transcriptional regulatory protein rprY
# 2 Transamidase GatB domain protein
# 2 Tll0814 protein
# 2 SclB protein
# 2 SAM-dependent methyltransferase
# 2 RidA/YER057c/UK114 superfamily protein
# 2 Ribosome-associated heat shock protein implicated in the recycling of the 50S subunit (S4 paralog)
# 2 Regulatory sensor-transducer, BlaR1/MecR1 family / TonB-dependent receptor
# 2 Putative pre-16S rRNA nuclease YqgF
# 2 Putative phosphohydrolase, Icc family
# 2 Putative permease
# 2 Putative periplasmic protein
# 2 Putative membrane protease YugP
# 2 Protein DUF2149, predicted transporter component
# 2 Prolipoprotein diacylglyceryl transferase
# 2 Periplasmic ligand-binding sensor domain COG3292 / BaeS-type histidine kinase / OmpR-type DNA-binding response regulator
# 2 Oxaloacetate decarboxylase Na(+) pump, gamma chain (EC 4.1.1.3)
# 2 Nitroreductase family protein
# 2 N5-carboxyaminoimidazole ribonucleotide mutase (EC 5.4.99.18)
# 2 N-acetylmuramoyl-L-alanine amidase
# 2 Multidrug resistance protein
# 2 Multi antimicrobial extrusion protein (Na(+)/drug antiporter), MATE family of MDR efflux pumps
# 2 Mannan endo-1,4-beta-mannosidase
# 2 Lipoprotein signal peptidase (EC 3.4.23.36)
# 2 Large-conductance mechanosensitive channel
# 2 Integrase
# 2 Helicase conserved C-terminal domain protein
# 2 Glycosyl transferase, group 2 family
# 2 Glycosyl transferase, group 1
# 2 Glycosyl transferase, family 2
# 2 FIG000605: protein co-occurring with transport systems (COG1739)
# 2 Electron transport complex protein RnfB
# 2 DnaD domain protein
# 2 Diacylglycerol kinase (EC 2.7.1.107)
# 2 D-alanyl-D-alanine carboxypeptidase (EC 3.4.16.4)
# 2 Cytidylate kinase (EC 2.7.4.25)
# 2 Cell division protein DivIC (FtsB), stabilizes FtsL against RasP cleavage
# 2 Cell division ZapA family protein
# 2 Cation efflux system protein
# 2 Bacterial non-heme ferritin (EC 1.16.3.2)
# 2 Aminotransferase, DegT/DnrJ/EryC1/StrS family
# 2 ATP synthase F0 sector subunit c (EC 3.6.3.14)
# 2 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase, delta subunit, ferredoxin-like 4Fe-4S binding protein (EC 1.2.7.-)
# 2 2-amino-4-hydroxy-6-hydroxymethyldihydropteridine pyrophosphokinase (EC 2.7.6.3)
# 15 RNA polymerase ECF-type sigma factor
# 1238 hypothetical protein
#
# II-nonpremie
# 34 hypothetical protein
# 3 Mobile element protein
# 2 Similar to carbon monoxide dehydrogenase CooS subunit

# %%
gene_change_counts_by_tp_type = {}
gene_change_null_counts_by_tp_type = {}

for tp_type in lost_genes_counts_by_tp_type:
    gene_change_counts_by_tp_type[tp_type] = {}
    gene_change_null_counts_by_tp_type[tp_type] = {}
    
    for gene in set(lost_genes_counts_by_tp_type[tp_type].keys() + gained_genes_counts_by_tp_type[tp_type].keys()):
        num_losses = 0 if gene not in lost_genes_counts_by_tp_type[tp_type] else lost_genes_counts_by_tp_type[tp_type][gene]        
        num_gains = 0 if gene not in gained_genes_counts_by_tp_type[tp_type] else gained_genes_counts_by_tp_type[tp_type][gene]
        gene_change_counts_by_tp_type[tp_type][gene] = num_losses + num_gains
        
        num_losses_null = 0 if gene not in lost_genes_counts_nulls_by_tp_type[tp_type] else lost_genes_counts_nulls_by_tp_type[tp_type][gene]        
        num_gains_null = 0 if gene not in gained_genes_counts_nulls_by_tp_type[tp_type] else gained_genes_counts_nulls_by_tp_type[tp_type][gene]        
        gene_change_null_counts_by_tp_type[tp_type][gene] = num_losses_null + num_gains_null

# %%
for tp_type in gene_change_counts_by_tp_type:
    print(sorted(gene_change_counts_by_tp_type[tp_type].items(), key=lambda x: x[1], reverse=True))
# Out:
# [('hypothetical protein', 15), ('helicase, UvrD/Rep family', 1), ('Glycosyl transferase, family 2', 1), ('Glycosyltransferase', 1), ('LtrC-like protein', 1), ('FIG00897069: hypothetical protein', 1), ('Holin', 1)]
# [('hypothetical protein', 63), ('Phage protein', 3), ('Doubtful CDS. No database matches', 2), ('N-acetylglutamate kinase (EC 2.7.2.8)', 1), ('UPF0358 protein YlaN', 1), ('Biotin carboxyl carrier protein associated with SAR1687-8', 1), ('Lambdoid phage Rac integrase', 1), ('Uncharacterized protein YebG', 1), ('hypothetical protein within a prophage', 1), ('[Genomic island nu Sa beta2]', 1), ('Mobile element protein', 1), ('Bacterial non-heme ferritin (EC 1.16.3.2)', 1), ('EsaC protein within ESAT-6 gene cluster (S.aureus type)', 1), ('Membrane protein insertion efficiency factor YidD', 1), ('Choline dehydrogenase (EC 1.1.99.1)', 1), ('ORF058', 1), ('Hypothetical protein SAV2259', 1), ('Copper/silver efflux RND transporter, transmembrane protein CusA', 1), ('Copper/silver efflux RND transporter, membrane fusion protein CusB', 1), ('putative membrane protein', 1), ('Exodeoxyribonuclease VII small subunit (EC 3.1.11.6)', 1), ('Repetitive hypothetical protein in ESAT cluster, COG4495', 1), ('Aminoglycoside 6-nucleotidyltransferase (EC 2.7.7.-) => ANT(6)-I', 1), ('Uncharacterized sodium-dependent transporter YocS', 1), ('Mobilization protein MobA @ Conjugal transfer protein TraA', 1), ('FIG00630611: hypothetical protein', 1), ('LSU ribosomal protein L31p @ LSU ribosomal protein L31p, zinc-independent', 1), ('DNA-directed RNA polymerase omega subunit (EC 2.7.7.6)', 1), ('Extracellular adherence protein of broad specificity Eap/Map', 1), ('TnpY-like protein', 1), ('FIG010063: hypothetical protein', 1), ('Hypothetical protein SAV2286', 1), ('PTS system, galactitol-specific IIB component (EC 2.7.1.200)', 1), ('hypothetical protein transposon-related', 1)]
# []
# []
# [('hypothetical protein', 1239), ('RNA polymerase ECF-type sigma factor', 15), ('Transcriptional regulator, AraC family', 8), ('Two-component system sensor histidine kinase', 7), ('putative membrane protein', 7), ('Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family', 7), ('Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family', 7), ('Glycosyltransferase', 6), ('Putative anti-sigma factor', 5), ('cAMP-binding proteins - catabolite gene activator and regulatory subunit of cAMP-dependent protein kinases', 5), ('Thioredoxin', 5), ('RNA-binding protein', 4), ('Uncharacterized MFS-type transporter', 4), ('Putative helicase', 4), ('Lipopolysaccharide biosynthesis protein', 3), ('Conserved protein, with a weak D-galactarate dehydratase/altronate hydrolase domain', 3), ('N-acetylmuramoyl-L-alanine amidase (EC 3.5.1.28)', 3), ('Acidobacterial duplicated orphan permease (function unknown)', 3), ('Membrane protein involved in the export of O-antigen, teichoic acid lipoteichoic acids', 3), ('Two-component transcriptional response regulator, LuxR family', 3), ('UpdZ protein', 3), ('Permease of the drug/metabolite transporter (DMT) superfamily', 3), ('Acetyltransferase, GNAT family', 3), ('ABC-type antimicrobial peptide transport system, ATPase component', 3), ('Transcriptional regulator, AcrR family', 3), ('O-acetylhomoserine sulfhydrylase (EC 2.5.1.49) @ O-succinylhomoserine sulfhydrylase (EC 2.5.1.48)', 3), ('Efflux ABC transporter, permease protein', 3), ('putative TonB-dependent receptor', 3), ('tRNA (guanine(37)-N(1))-methyltransferase (EC 2.1.1.228)', 2), ('Protein DUF2149, predicted transporter component', 2), ('Bacterial non-heme ferritin (EC 1.16.3.2)', 2), ('D-alanyl-D-alanine carboxypeptidase (EC 3.4.16.4)', 2), ('Diacylglycerol kinase (EC 2.7.1.107)', 2), ('N-acetylmuramoyl-L-alanine amidase', 2), ('ATP synthase F0 sector subunit c (EC 3.6.3.14)', 2), ('Regulatory sensor-transducer, BlaR1/MecR1 family / TonB-dependent receptor', 2), ('Nitroreductase family protein', 2), ('2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase, delta subunit, ferredoxin-like 4Fe-4S binding protein (EC 1.2.7.-)', 2), ('N5-carboxyaminoimidazole ribonucleotide mutase (EC 5.4.99.18)', 2), ('Multi antimicrobial extrusion protein (Na(+)/drug antiporter), MATE family of MDR efflux pumps', 2), ('Putative membrane protease YugP', 2), ('Large-conductance mechanosensitive channel', 2), ('Multidrug resistance protein', 2), ('Ribosome-associated heat shock protein implicated in the recycling of the 50S subunit (S4 paralog)', 2), ('RidA/YER057c/UK114 superfamily protein', 2), ('Oxaloacetate decarboxylase Na(+) pump, gamma chain (EC 4.1.1.3)', 2), ('Prolipoprotein diacylglyceryl transferase', 2), ('dTDP-4-dehydrorhamnose 3,5-epimerase (EC 5.1.3.13)', 2), ('Electron transport complex protein RnfB', 2), ('Putative permease', 2), ('UDP-N-acetylglucosamine 2-epimerase (EC 5.1.3.14)', 2), ('SclB protein', 2), ('2-amino-4-hydroxy-6-hydroxymethyldihydropteridine pyrophosphokinase (EC 2.7.6.3)', 2), ('Lipoprotein signal peptidase (EC 3.4.23.36)', 2), ('SAM-dependent methyltransferase', 2), ('Putative periplasmic protein', 2), ('Integrase', 2), ('Tll0814 protein', 2), ('Glycosyl transferase, group 1', 2), ('DnaD domain protein', 2), ('Putative pre-16S rRNA nuclease YqgF', 2), ('Aminotransferase, DegT/DnrJ/EryC1/StrS family', 2), ('Glycosyl transferase, family 2', 2), ('Cell division ZapA family protein', 2), ('Cell division protein DivIC (FtsB), stabilizes FtsL against RasP cleavage', 2), ('Transcriptional regulatory protein rprY', 2), ('Cytidylate kinase (EC 2.7.4.25)', 2), ('Helicase conserved C-terminal domain protein', 2), ('[FeFe]-hydrogenase maturation protein HydF', 2), ('Mannan endo-1,4-beta-mannosidase', 2), ('Cation efflux system protein', 2), ('Putative phosphohydrolase, Icc family', 2), ('UDP-glucose 4-epimerase (EC 5.1.3.2)', 2), ('FIG000605: p ...
# [('hypothetical protein', 2296), ('RNA polymerase ECF-type sigma factor', 46), ('Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family', 16), ('Transcriptional regulator, AraC family', 15), ('Two-component system sensor histidine kinase', 14), ('Thioredoxin', 13), ('Putative anti-sigma factor', 12), ('putative membrane protein', 12), ('Acidobacterial duplicated orphan permease (function unknown)', 11), ('RNA-binding protein', 9), ('Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family', 9), ('Integrase', 8), ('Putative helicase', 8), ('Uncharacterized MFS-type transporter', 7), ('Two-component transcriptional response regulator, LuxR family', 6), ('Glycosyltransferase', 6), ('UpdZ protein', 6), ('cAMP-binding proteins - catabolite gene activator and regulatory subunit of cAMP-dependent protein kinases', 6), ('Mobile element protein', 6), ('N-acetylmuramoyl-L-alanine amidase (EC 3.5.1.28)', 5), ('Capsular polysaccharide transcription antitermination protein, UpxY family', 5), ('SclB protein', 5), ('O-acetylhomoserine sulfhydrylase (EC 2.5.1.49) @ O-succinylhomoserine sulfhydrylase (EC 2.5.1.48)', 5), ('Putative glycosyltransferase', 5), ('ABC-type antimicrobial peptide transport system, ATPase component', 5), ('UDP-glucose 4-epimerase (EC 5.1.3.2)', 4), ('Endonuclease', 4), ('Nitroreductase family protein', 4), ('MBL-fold metallo-hydrolase superfamily', 4), ('beta-glycosyl hydrolase', 4), ('Phage integrase', 4), ('Monofunctional biosynthetic peptidoglycan transglycosylase', 4), ('3-oxoacyl-[acyl-carrier protein] reductase paralog (EC 1.1.1.100)', 4), ('CAAX amino terminal protease family protein', 4), ('TPR-repeat-containing protein', 4), ('N-acetylglucosaminyltransferase (EC 2.4.1.-)', 4), ('Putative periplasmic protein', 4), ('Oxidoreductase, aldo/keto reductase family', 4), ('Membrane protein involved in the export of O-antigen, teichoic acid lipoteichoic acids', 4), ('ISNCY family transposase', 4), ('DNA ligase (NAD(+)) (EC 6.5.1.2)', 4), ('Vitamin B12 ABC transporter, substrate-binding protein BtuF', 4), ('[FeFe]-hydrogenase maturation protein HydF', 4), ('Undecaprenyl-phosphate alpha-N-acetylglucosaminyl 1-phosphate transferase (EC 2.7.8.33)', 4), ('Flavoredoxin', 4), ('Efflux ABC transporter, permease protein', 4), ('Malonyl CoA-acyl carrier protein transacylase (EC 2.3.1.39)', 4), ('Tyrosine type site-specific recombinase', 4), ('Vitamin B12 ABC transporter, permease protein BtuC', 4), ('Zn-ribbon-containing, possibly RNA-binding protein and truncated derivatives', 3), ('tRNA (guanine(37)-N(1))-methyltransferase (EC 2.1.1.228)', 3), ('Protein DUF2149, predicted transporter component', 3), ('Xylanase', 3), ('ATP synthase epsilon chain (EC 3.6.3.14)', 3), ('Immunoreactive 53 kDa antigen PG123', 3), ('Na+/H+-dicarboxylate symporter', 3), ('Co-activator of prophage gene expression IbrB', 3), ('Diacylglycerol kinase (EC 2.7.1.107)', 3), ('4-hydroxy-2-oxoglutarate aldolase (EC 4.1.3.16) @ 2-dehydro-3-deoxyphosphogluconate aldolase (EC 4.1.2.14)', 3), ('PAP2 superfamily protein', 3), ('Dihydroorotate dehydrogenase (NAD(+)), electron transfer subunit (EC 1.3.1.14)', 3), ('ATP synthase F0 sector subunit c (EC 3.6.3.14)', 3), ('FIG016027: protein of unknown function YeaO', 3), ('ATP synthase gamma chain (EC 3.6.3.14)', 3), ('N-acylneuraminate cytidylyltransferase (EC 2.7.7.43)', 3), ('Probable integral membrane protein Cj1165c', 3), ('Inner membrane protein YhiM', 3), ('tmRNA-binding protein SmpB', 3), ('Aminodeoxychorismate lyase (EC 4.1.3.38)', 3), ('Ribosome-associated heat shock protein implicated in the recycling of the 50S subunit (S4 paralog)', 3), ('UPF0126 inner membrane protein BT_1201', 3), ('Small heat shock protein', 3), ('Large-conductance mechanosensitive channel', 3), ('Conserved hypothetical protein 22', 3), ('Possible glyoxylase family protein (Lactoylglutathione lyase) (EC 4.4.1.5)', 3), ('Multidr ...

# %%
for tp_type in gene_change_null_counts_by_tp_type:
    print(sorted(gene_change_null_counts_by_tp_type[tp_type].items(), key=lambda x: x[1], reverse=True))
# Out:
# [('helicase, UvrD/Rep family', 0), ('Glycosyl transferase, family 2', 0), ('Glycosyltransferase', 0), ('LtrC-like protein', 0), ('FIG00897069: hypothetical protein', 0), ('Holin', 0), ('hypothetical protein', 0)]
# [('hypothetical protein', 0.9400000000000004), ('Phage protein', 0.08), ('hypothetical protein transposon-related', 0.08), ('LSU ribosomal protein L31p @ LSU ribosomal protein L31p, zinc-independent', 0.06), ('UPF0358 protein YlaN', 0.04), ('EsaC protein within ESAT-6 gene cluster (S.aureus type)', 0.04), ('Hypothetical protein SAV2259', 0.04), ('Hypothetical protein SAV2286', 0.04), ('PTS system, galactitol-specific IIB component (EC 2.7.1.200)', 0.04), ('N-acetylglutamate kinase (EC 2.7.2.8)', 0.02), ('Biotin carboxyl carrier protein associated with SAR1687-8', 0.02), ('Uncharacterized protein YebG', 0.02), ('hypothetical protein within a prophage', 0.02), ('Choline dehydrogenase (EC 1.1.99.1)', 0.02), ('ORF058', 0.02), ('Repetitive hypothetical protein in ESAT cluster, COG4495', 0.02), ('Uncharacterized sodium-dependent transporter YocS', 0.02), ('DNA-directed RNA polymerase omega subunit (EC 2.7.7.6)', 0.02), ('FIG010063: hypothetical protein', 0.02), ('Lambdoid phage Rac integrase', 0), ('[Genomic island nu Sa beta2]', 0), ('Mobile element protein', 0), ('Bacterial non-heme ferritin (EC 1.16.3.2)', 0), ('Membrane protein insertion efficiency factor YidD', 0), ('Copper/silver efflux RND transporter, transmembrane protein CusA', 0), ('Copper/silver efflux RND transporter, membrane fusion protein CusB', 0), ('putative membrane protein', 0), ('Exodeoxyribonuclease VII small subunit (EC 3.1.11.6)', 0), ('Aminoglycoside 6-nucleotidyltransferase (EC 2.7.7.-) => ANT(6)-I', 0), ('Doubtful CDS. No database matches', 0), ('Mobilization protein MobA @ Conjugal transfer protein TraA', 0), ('FIG00630611: hypothetical protein', 0), ('Extracellular adherence protein of broad specificity Eap/Map', 0), ('TnpY-like protein', 0)]
# []
# []
# [('tRNA (guanine(37)-N(1))-methyltransferase (EC 2.1.1.228)', 0), ("5'-nucleotidase (EC 3.1.3.5); 2',3'-cyclic-nucleotide 2'-phosphodiesterase (EC 3.1.4.16); Putative UDP-sugar hydrolase (EC 3.6.1.45)", 0), ('Protein DUF2149, predicted transporter component', 0), ('Na+-driven multidrug efflux pump', 0), ('Phospholipid ABC transporter ATP-binding protein MlaF', 0), ('Xanthine phosphoribosyltransferase (EC 2.4.2.22)', 0), ('Xylanase', 0), ('Ser/Thr protein phosphatase family protein, UDP-2,3-diacylglucosamine hydrolase (EC 3.6.1.-) homolog', 0), ('ATP synthase epsilon chain (EC 3.6.3.14)', 0), ('CzcABC family efflux RND transporter, outer membrane protein', 0), ('dTDP-glucose 4,6-dehydratase (EC 4.2.1.46)', 0), ('probable DNA alkylation repair enzyme', 0), ('Phosphomethylpyrimidine synthase ThiC (EC 4.1.99.17)', 0), ('Beta-lactamase class C-like and penicillin binding proteins (PBPs) superfamily', 0), ('Low molecular weight protein tyrosine phosphatase (EC 3.1.3.48)', 0), ('Transglycosylase-associated protein', 0), ('RNA-binding protein', 0), ('Carboxynorspermidine synthase (EC 1.5.1.43)', 0), ('Na+/H+-dicarboxylate symporter', 0), ('Type I restriction-modification system, DNA-methyltransferase subunit M (EC 2.1.1.72)', 0), ('Bacterial non-heme ferritin (EC 1.16.3.2)', 0), ('D-alanyl-D-alanine carboxypeptidase (EC 3.4.16.4)', 0), ('Diacylglycerol kinase (EC 2.7.1.107)', 0), ('4-hydroxy-2-oxoglutarate aldolase (EC 4.1.3.16) @ 2-dehydro-3-deoxyphosphogluconate aldolase (EC 4.1.2.14)', 0), ('PAP2 superfamily protein', 0), ('FIG015287: Zinc protease', 0), ('N-acetylmuramoyl-L-alanine amidase', 0), ('Arginyl-tRNA synthetase (EC 6.1.1.19)', 0), ('Exodeoxyribonuclease III (EC 3.1.11.2)', 0), ('Na(+)-translocating NADH-quinone reductase subunit B (EC 1.6.5.8)', 0), ('LemA protein', 0), ('Dihydroorotate dehydrogenase (NAD(+)), electron transfer subunit (EC 1.3.1.14)', 0), ('Lipopolysaccharide biosynthesis protein', 0), ('23S rRNA (pseudouridine(1915)-N(3))-methyltransferase (EC 2.1.1.177)', 0), ('alpha-L-fucosidase (EC 3.2.1.51)', 0), ('ATP synthase F0 sector subunit c (EC 3.6.3.14)', 0), ('Endonuclease', 0), ('Regulatory sensor-transducer, BlaR1/MecR1 family / TonB-dependent receptor', 0), ('4-keto-6-deoxy-N-Acetyl-D-hexosaminyl-(Lipid carrier) aminotransferase', 0), ('Imidazole glycerol phosphate synthase amidotransferase subunit HisH', 0), ('Nitroreductase family protein', 0), ('hypothetical transporter PduT for various metalloporphyrins', 0), ('LSU ribosomal protein L33p @ LSU ribosomal protein L33p, zinc-independent', 0), ('beta-glycosyl hydrolase', 0), ('Conserved protein, with a weak D-galactarate dehydratase/altronate hydrolase domain', 0), ('FIG016027: protein of unknown function YeaO', 0), ('Uncharacterized protease YdcP', 0), ('ATP synthase gamma chain (EC 3.6.3.14)', 0), ('Translation initiation factor 3', 0), ('FIG00936810: hypothetical protein', 0), ('N-acylneuraminate cytidylyltransferase (EC 2.7.7.43)', 0), ('Phage integrase', 0), ('2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase, delta subunit, ferredoxin-like 4Fe-4S binding protein (EC 1.2.7.-)', 0), ('SSU ribosomal protein S14p (S29e) @ SSU ribosomal protein S14p (S29e), zinc-independent', 0), ('2-dehydro-3-deoxy-D-gluconate 5-dehydrogenase (EC 1.1.1.127) @ 2-deoxy-D-gluconate 3-dehydrogenase (EC 1.1.1.125)', 0), ('FKBP-type peptidyl-prolyl cis-trans isomerase FkpA precursor (EC 5.2.1.8)', 0), ('Phosphate ABC transporter, substrate-binding protein PstS (TC 3.A.1.7.1)', 0), ('Fluoride ion transporter CrcB', 0), ('Trk potassium uptake system protein TrkH', 0), ('N-acetylmuramoyl-L-alanine amidase (EC 3.5.1.28)', 0), ('Probable integral membrane protein Cj1165c', 0), ('FIG01197961: hypothetical protein', 0), ('Nucleotidyltransferase domain protein, Caur_2868 group', 0), ('Signal recognition particle receptor FtsY', 0), ('LSU ribosomal protein L32p @ LSU ribosomal protein L32p, zinc-dependent', 0), ('Inner membrane protein YhiM', 0), ('Acidobacterial duplicated orphan p ...
# [('hypothetical protein', 555.1799999999995), ('RNA polymerase ECF-type sigma factor', 11.68), ('Two-component system sensor histidine kinase', 4.079999999999999), ('Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family', 3.88), ('Transcriptional regulator, AraC family', 3.84), ('Thioredoxin', 3.3799999999999994), ('putative membrane protein', 3.1999999999999997), ('Putative anti-sigma factor', 2.78), ('RNA-binding protein', 2.54), ('Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family', 2.5), ('Acidobacterial duplicated orphan permease (function unknown)', 2.4), ('Putative helicase', 1.96), ('cAMP-binding proteins - catabolite gene activator and regulatory subunit of cAMP-dependent protein kinases', 1.6800000000000002), ('Two-component transcriptional response regulator, LuxR family', 1.6400000000000001), ('Integrase', 1.64), ('UpdZ protein', 1.62), ('Uncharacterized MFS-type transporter', 1.5399999999999998), ('Glycosyltransferase', 1.46), ('O-acetylhomoserine sulfhydrylase (EC 2.5.1.49) @ O-succinylhomoserine sulfhydrylase (EC 2.5.1.48)', 1.44), ('Capsular polysaccharide transcription antitermination protein, UpxY family', 1.34), ('N-acetylmuramoyl-L-alanine amidase (EC 3.5.1.28)', 1.2799999999999998), ('Putative glycosyltransferase', 1.2599999999999998), ('ABC-type antimicrobial peptide transport system, ATPase component', 1.24), ('Flavoredoxin', 1.1800000000000002), ('Possible exported heavy-metal binding protein', 1.1400000000000001), ('ISNCY family transposase', 1.1400000000000001), ('Oxidoreductase, aldo/keto reductase family', 1.12), ('UDP-glucose 4-epimerase (EC 5.1.3.2)', 1.1), ('Putative periplasmic protein', 1.0999999999999999), ('Undecaprenyl-phosphate alpha-N-acetylglucosaminyl 1-phosphate transferase (EC 2.7.8.33)', 1.0799999999999998), ('OmpA family outer membrane protein', 1.0600000000000003), ('TPR-repeat-containing protein', 1.06), ('Two-component transcriptional response regulator, LuxR family BT1217', 1.04), ('Monofunctional biosynthetic peptidoglycan transglycosylase', 1.0399999999999998), ('MBL-fold metallo-hydrolase superfamily', 1.02), ('SclB protein', 1.02), ('Membrane protein involved in the export of O-antigen, teichoic acid lipoteichoic acids', 1.02), ('Vitamin B12 ABC transporter, permease protein BtuC', 1.02), ('3-oxoacyl-[acyl-carrier protein] reductase paralog (EC 1.1.1.100)', 1.0199999999999998), ('beta-glycosyl hydrolase', 1.0), ('Zn-ribbon-containing, possibly RNA-binding protein and truncated derivatives', 0.98), ('Conserved protein YuxK', 0.98), ('Cys-tRNA(Pro) deacylase YbaK', 0.9600000000000001), ('Aerotolerance protein BatC', 0.96), ('Endonuclease', 0.94), ('Nitroreductase family protein', 0.9199999999999999), ('Large-conductance mechanosensitive channel', 0.9199999999999999), ('Vitamin B12 ABC transporter, substrate-binding protein BtuF', 0.9199999999999999), ('Efflux ABC transporter, permease protein', 0.9199999999999999), ('Phosphoribosylformimino-5-aminoimidazole carboxamide ribotide isomerase (EC 5.3.1.16)', 0.9199999999999999), ('DoxX family protein', 0.9000000000000001), ('Sigma factor RpoE regulatory protein RseC', 0.8999999999999999), ('UPF0056 inner membrane protein MarC', 0.8999999999999999), ('FIG00490011: hypothetical protein', 0.8800000000000001), ('N-acetylglucosaminyltransferase (EC 2.4.1.-)', 0.88), ('Dihydroorotate dehydrogenase (quinone) (EC 1.3.5.2)', 0.88), ('Transmembrane protein', 0.8600000000000001), ('Malonyl CoA-acyl carrier protein transacylase (EC 2.3.1.39)', 0.8600000000000001), ('Adenosylcobinamide kinase (EC 2.7.1.156) / Adenosylcobinamide-phosphate guanylyltransferase (EC 2.7.7.62)', 0.86), ('Uncharacterized protein BT4380', 0.86), ('putative integration host factor IHF alpha subunit', 0.8400000000000001), ('Rrf2-linked NADH-flavin reductase', 0.8400000000000001), ('Conserved hypothetical protein 22', 0.84), ('2-amino-4-hydroxy-6-hydroxyme ...

# %%
for tp_type in gene_change_counts_by_tp_type:
    output = open('%s/gene_changes_%s.tsv' % (config.analysis_directory, tp_type), 'w')
    output.write('\t'.join(['gene_name', 'num_changes', 'num_changes_null', 'num_gains', 'num_gains_null', 'num_losses', 'num_losses_null']) + '\n')
    for gene in gene_change_counts_by_tp_type[tp_type]:
        num_changes = gene_change_counts_by_tp_type[tp_type][gene]
        num_losses = 0 if gene not in lost_genes_counts_by_tp_type[tp_type] else lost_genes_counts_by_tp_type[tp_type][gene]
        num_gains = 0 if gene not in gained_genes_counts_by_tp_type[tp_type] else gained_genes_counts_by_tp_type[tp_type][gene]
        num_changes_null = gene_change_null_counts_by_tp_type[tp_type][gene]
        num_losses_null = 0 if gene not in lost_genes_counts_nulls_by_tp_type[tp_type] else lost_genes_counts_nulls_by_tp_type[tp_type][gene]        
        num_gains_null = 0 if gene not in gained_genes_counts_nulls_by_tp_type[tp_type] else gained_genes_counts_nulls_by_tp_type[tp_type][gene]
        output.write('\t'.join([str(item) for item in [gene, num_changes, num_changes_null, num_gains, num_gains_null, num_losses, num_losses_null]]) + '\n')
    output.close()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-4-e537997e2aea> in <module>()
# ----> 1 for tp_type in gene_change_counts_by_tp_type:
#       2     output = open('%s/gene_changes_%s.tsv' % (config.analysis_directory, tp_type), 'w')
#       3     output.write('\t'.join(['gene_name', 'num_changes', 'num_changes_null', 'num_gains', 'num_gains_null', 'num_losses', 'num_losses_null']) + '\n')
#       4     for gene in gene_change_counts_by_tp_type[tp_type]:
#       5         num_changes = gene_change_counts_by_tp_type[tp_type][gene]
#
# NameError: name 'gene_change_counts_by_tp_type' is not defined

# %%
# Returns two arrays, one of ordered timepoints
# and other of corresponding values
def order_by_tp(tp_dict):
    items = tp_dict.items()
    mother_items = filter(lambda x: x[0][0] == 'M', items)
    mother_sorted = sorted(mother_items, key=lambda x: int(x[0][1:]))
    infant_items = filter(lambda x: x[0][0] == 'I', items)
    infant_sorted = sorted(infant_items, key=lambda x: int(x[0][1:]))
    comb_sorted = mother_sorted + infant_sorted
    return comb_sorted if comb_sorted != [] else sorted(items, key=lambda x: int(x[0][1:]))

# %%
# Returns True if one value is below lower_threshold
# and the other value is above upper_threshold
def is_diff(val1, val2, lower_threshold, upper_threshold):
    return (val1 <= lower_threshold and val2 >= upper_threshold) or (val1 >= upper_threshold and val2 <= lower_threshold)

# %%
# Determines if list of values has reversion
def has_reversion(vals, lower_threshold, upper_threshold):
    ref_val = vals[0]
    one_change = False
    for val in vals[1:]:
        # While first change has yet to occur
        if one_change == False:
            if is_diff(val, ref_val, lower_threshold, upper_threshold):
                # If first change detected, set ref_val to new value
                # and set one_change to True
                ref_val = val
                one_change = True
        # First change has already occurred with ref_val reset
        elif one_change == True:
            if is_diff(val, ref_val, lower_threshold, upper_threshold):
                # Second change (must be in opp. direction) detected
                return True
    return False

# %%
reversions = []
lower_threshold = 0.2
upper_threshold = 0.8

# Enumerate reversions
for species in snp_modifications_by_site:
    
    # Also prepare gene information
    if sum([len(snp_modifications_by_site[species][cohort].keys()) for cohort in snp_modifications_by_site[species]]) != 0:
        print("Getting gene info for %s..." % species)
        genome_ids = midas_db_utils.get_ref_genome_ids(species)
        non_shared_genes = core_gene_utils.parse_non_shared_pangenome_genes(species)
        gene_desc = parse_patric.load_patric_gene_descriptions(genome_ids, non_shared_genes)
    
    for cohort in snp_modifications_by_site[species]:
        subdict = snp_modifications_by_site[species][cohort]
        for subject in subdict:
            for site in subdict[subject]:
                if len(subdict[subject][site]) > 1:
                    tp_freq_dict = {} # freq info only
                    for snp_change in subdict[subject][site]:
                        tp_pair, gene_id, var_type, A1, D1, A2, D2 = snp_change
                        tp1, tp2 = tp_pair
                        tp_freq_dict[tp1] = (A1/float(D1))
                        tp_freq_dict[tp2] = (A2/float(D2))
                    ordered_tp_freqs = order_by_tp(tp_freq_dict)
                    gene_name = gene_desc[gene_id] if gene_id in gene_desc else 'No name'
                    if has_reversion([freq for tp, freq in ordered_tp_freqs], lower_threshold, upper_threshold):
                        reversions.append((species, cohort, subject, site, gene_id, gene_name, var_type, ordered_tp_freqs))
# Out:
# Getting gene info for Bacteroides_intestinalis_61596...
# Getting gene info for Bacteroides_uniformis_57318...
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-8-1950530fe417> in <module>()
#      11         genome_ids = midas_db_utils.get_ref_genome_ids(species)
#      12         non_shared_genes = core_gene_utils.parse_non_shared_pangenome_genes(species)
# ---> 13         gene_desc = parse_patric.load_patric_gene_descriptions(genome_ids, non_shared_genes)
#      14
#      15     for cohort in snp_modifications_by_site[species]:
#
# /u/project/ngarud/daisyche/mother_infant/scripts/utils/parse_patric.pyc in load_patric_gene_descriptions(genome_ids, allowed_genes)
#     119                                         print("PATRIC file for " + genome_id + " not found!")
#     120                                         continue
# --> 121                                 file.readline() #header
#     122                                 for line in file:
#     123                                                 items = line.strip().split("\t")
#
# /u/local/apps/python/2.7.13/lib/python2.7/gzip.pyc in readline(self, size)
#     462         bufs = []
#     463         while size != 0:
# --> 464             c = self.read(readsize)
#     465             i = c.find('\n')
#     466
#
# /u/local/apps/python/2.7.13/lib/python2.7/gzip.pyc in read(self, size)
#     266             try:
#     267                 while size > self.extrasize:
# --> 268                     self._read(readsize)
#     269                     readsize = min(self.max_read_chunk, readsize * 2)
#     270             except EOFError:
#
# /u/local/apps/python/2.7.13/lib/python2.7/gzip.pyc in _read(self, size)
#     294             # if so, it's time to stop; no more members to read.
#     295             pos = self.fileobj.tell()   # Save current position
# --> 296             self.fileobj.seek(0, 2)     # Seek to end of file
#     297             if pos == self.fileobj.tell():
#     298                 raise EOFError, "Reached EOF"
#
# KeyboardInterrupt:

# %%
# revised to differentiate premie and nonpremie
def tp_pair_to_tp_type(tp_pair, cohort):
    tpa, tpb = tp_pair
    tp_type = tpa[0] + tpb[0]
    if tp_type == 'IM':
        tp_type = 'MI'
    if tp_type in ['II', 'MI']:
        if cohort == 'olm':
            tp_type += '-premie'
        else:
            tp_type += '-nonpremie'
    return tp_type

# %%
cohorts = ['backhed', 'yassour', 'ferretti', 'hmp', 'shao', 'olm']

# %%
num_snp_change_by_cohort = {cohort: 0 for cohort in cohorts}
changed_gene_ids_by_cohort = {cohort: set() for cohort in cohorts}
changed_gene_names_by_cohort = {cohort: set() for cohort in cohorts}
changed_gene_name_counts_by_cohort = {cohort: defaultdict(int) for cohort in cohorts}

tp_types = ['AA', 'II-premie', 'II-nonpremie','MM', 'MI-premie', 'MI-nonpremie']
num_snp_change_by_tp_type = {tp_type: 0 for tp_type in tp_types}
changed_gene_names_by_tp_type = {tp_type: set() for tp_type in tp_types}
changed_gene_name_counts_by_tp_type = {tp_type: defaultdict(int) for tp_type in tp_types}

# Enumerate genes
for species in snp_modification_genes:
    for cohort in snp_modification_genes[species]:
        for subject in snp_modification_genes[species][cohort]:
            subdict = snp_modification_genes[species][cohort][subject]
            # For each sample pair in this cohort/species,
            # have a count of how many SNP changes are
            # in a particular gene
            for tp_pair in subdict:
                tp_type = tp_pair_to_tp_type(tp_pair, cohort)
                for gene_id, gene_name in subdict[tp_pair]:
                    snp_change_count = subdict[tp_pair][(gene_id, gene_name)]

                    num_snp_change_by_cohort[cohort] += snp_change_count
                    changed_gene_ids_by_cohort[cohort].add(gene_id)
                    changed_gene_names_by_cohort[cohort].add(gene_name)
                    changed_gene_name_counts_by_cohort[cohort][gene_name] += snp_change_count

                    num_snp_change_by_tp_type[tp_type] += snp_change_count
                    changed_gene_names_by_tp_type[tp_type].add(gene_name)
                    changed_gene_name_counts_by_tp_type[tp_type][gene_name] += snp_change_count

# %%
num_snp_change_by_tp_type
# Out:
# {'AA': 259,
#  'II-nonpremie': 276,
#  'II-premie': 38,
#  'MI-nonpremie': 101,
#  'MI-premie': 0,
#  'MM': 33}

# %%
for tp_type in changed_gene_names_by_tp_type:
    print("%s: %i" % (tp_type,len(changed_gene_names_by_tp_type[tp_type])))
# Out:
# AA: 114
# II-premie: 28
# MI-premie: 0
# MM: 27
# MI-nonpremie: 54
# II-nonpremie: 107

# %%
for tp_type in changed_gene_name_counts_by_tp_type:
    subdict = changed_gene_name_counts_by_tp_type[tp_type]
    print(tp_type)
    for gene_name, count in sorted(subdict.items(), key=lambda x: x[1], reverse=True):
        if count > 1:
            print("%i %s" % (count, gene_name))
    print('')
# Out:
# AA
# 76 hypothetical protein
# 14 Oligopeptide ABC transporter, permease protein OppC (TC 3.A.1.5.1)
# 12 Biotin synthase (EC 2.8.1.6)
# 10 HAD-superfamily hydrolase, subfamily IA, variant 3
# 6 RND efflux system, inner membrane transporter
# 6 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 5 Outer membrane protein oprM
# 5 Oligopeptide ABC transporter, permease protein OppB (TC 3.A.1.5.1)
# 5 Vitamin B12 ABC transporter, ATP-binding protein BtuD
# 4 Ribonuclease J2 (endoribonuclease in RNA processing)
# 3 Sensory box/GGDEF family protein
# 3 N/A
# 3 DNA gyrase subunit A (EC 5.99.1.3)
# 2 Two-component system sensor histidine kinase
# 2 Vitamin B12 ABC transporter, substrate-binding protein BtuF
# 2 ATP:Cob(I)alamin adenosyltransferase (EC 2.5.1.17)
# 2 Argininosuccinate lyase (EC 4.3.2.1)
# 2 Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family
# 2 DNA-directed RNA polymerase beta subunit (EC 2.7.7.6)
#
# II-premie
# 5 N/A
# 3 Putative glutathione transporter, permease component; Dipeptide ABC transporter, permease protein DppC (TC 3.A.1.5.2)
# 3 hypothetical protein
# 2 Uncharacterized transporter YbxG
# 2 Transcriptional regulator pfoR
#
# MI-premie
#
# MM
# 7 hypothetical protein
#
# MI-nonpremie
# 19 hypothetical protein
# 13 N/A
# 5 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 4 beta-glucosidase (EC 3.2.1.21)
# 4 Electron transport complex protein RnfE
# 3 putative TonB-dependent receptor
# 2 Two-component system sensor histidine kinase/response regulator hybrid
# 2 Two-component system sensor histidine kinase
# 2 ThiF family protein, ubiquitin-activating enzyme
# 2 Tyrosine-protein kinase (EC 2.7.10.2)
# 2 RND efflux system, membrane fusion protein
#
# II-nonpremie
# 39 hypothetical protein
# 37 Transcription termination factor Rho
# 25 Protoporphyrinogen oxidase
# 22 Ribonucleotide reductase of class Ib (aerobic), alpha subunit (EC 1.17.4.1)
# 16 FIG000875: Thioredoxin domain-containing protein EC-YbbN
# 8 narrowly conserved hypothetical protein
# 5 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 4 Periplasmic ligand-binding sensor domain COG3292 / BaeS-type histidine kinase / OmpR-type DNA-binding response regulator
# 4 DNA gyrase subunit B (EC 5.99.1.3)
# 3 Tn916, NLP/P60 family protein
# 3 Glycogen phosphorylase (EC 2.4.1.1)
# 3 Aspartate ammonia-lyase (EC 4.3.1.1)
# 3 Serine/threonine-protein kinase PknB (EC 2.7.11.1)
# 2 RidA/YER057c/UK114 superfamily protein
# 2 Sialidase (EC 3.2.1.18)
# 2 ABC transporter, substrate-binding protein (cluster 1, maltose/g3p/polyamine/iron)
# 2 beta-galactosidase (EC 3.2.1.23)
# 2 Sporulation transcription regulator WhiA
# 2 RND efflux system, membrane fusion protein
# 2 DNA-directed RNA polymerase beta subunit (EC 2.7.7.6)
# 2 Hypothetical, related to broad specificity phosphatases COG0406
# 2 Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family
# 2 large transmembrane protein possibly involved in transport

# %%
num_snp_change_by_cohort
# Out:
# {'backhed': 166,
#  'ferretti': 34,
#  'hmp': 259,
#  'olm': 38,
#  'shao': 153,
#  'yassour': 57}

# %%
for cohort in changed_gene_ids_by_cohort:
    print("%s: %i" % (cohort,len(changed_gene_ids_by_cohort[cohort])))
# Out:
# hmp: 176
# olm: 31
# yassour: 48
# backhed: 114
# ferretti: 13
# shao: 68

# %%
for cohort in changed_gene_names_by_cohort:
    print("%s: %i" % (cohort,len(changed_gene_names_by_cohort[cohort])))
# Out:
# hmp: 114
# olm: 28
# yassour: 38
# backhed: 81
# ferretti: 12
# shao: 51

# %%
for cohort in changed_gene_name_counts_by_cohort:
    subdict = changed_gene_name_counts_by_cohort[cohort]
    print(cohort)
    for gene_name, count in sorted(subdict.items(), key=lambda x: x[1], reverse=True):
        if count > 1:
            print("%i %s" % (count, gene_name))
    print('')
# Out:
# hmp
# 76 hypothetical protein
# 14 Oligopeptide ABC transporter, permease protein OppC (TC 3.A.1.5.1)
# 12 Biotin synthase (EC 2.8.1.6)
# 10 HAD-superfamily hydrolase, subfamily IA, variant 3
# 6 RND efflux system, inner membrane transporter
# 6 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 5 Outer membrane protein oprM
# 5 Oligopeptide ABC transporter, permease protein OppB (TC 3.A.1.5.1)
# 5 Vitamin B12 ABC transporter, ATP-binding protein BtuD
# 4 Ribonuclease J2 (endoribonuclease in RNA processing)
# 3 Sensory box/GGDEF family protein
# 3 N/A
# 3 DNA gyrase subunit A (EC 5.99.1.3)
# 2 Two-component system sensor histidine kinase
# 2 Vitamin B12 ABC transporter, substrate-binding protein BtuF
# 2 ATP:Cob(I)alamin adenosyltransferase (EC 2.5.1.17)
# 2 Argininosuccinate lyase (EC 4.3.2.1)
# 2 Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family
# 2 DNA-directed RNA polymerase beta subunit (EC 2.7.7.6)
#
# olm
# 5 N/A
# 3 Putative glutathione transporter, permease component; Dipeptide ABC transporter, permease protein DppC (TC 3.A.1.5.2)
# 3 hypothetical protein
# 2 Uncharacterized transporter YbxG
# 2 Transcriptional regulator pfoR
#
# yassour
# 10 hypothetical protein
# 4 beta-glucosidase (EC 3.2.1.21)
# 4 Electron transport complex protein RnfE
# 3 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 2 Two-component system sensor histidine kinase/response regulator hybrid
# 2 Tyrosine-protein kinase (EC 2.7.10.2)
#
# backhed
# 29 hypothetical protein
# 16 FIG000875: Thioredoxin domain-containing protein EC-YbbN
# 8 narrowly conserved hypothetical protein
# 5 N/A
# 5 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 4 RND efflux system, membrane fusion protein
# 3 Two-component system sensor histidine kinase
# 3 Aspartate ammonia-lyase (EC 4.3.1.1)
# 3 putative TonB-dependent receptor
# 3 Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family
# 3 beta-galactosidase (EC 3.2.1.23)
# 2 large transmembrane protein possibly involved in transport
# 2 Malate dehydrogenase (EC 1.1.1.37)
# 2 Esterase/lipase
# 2 Lactose and galactose permease, GPH translocator family
# 2 Periplasmic ligand-binding sensor domain COG3292 / BaeS-type histidine kinase / OmpR-type DNA-binding response regulator
# 2 RidA/YER057c/UK114 superfamily protein
# 2 ABC transporter, substrate-binding protein (cluster 1, maltose/g3p/polyamine/iron)
# 2 Cell division initiation protein DivIVA
# 2 putative protein involved in capsular polysaccharide biosynthesis
# 2 putative two-component system sensor but no kinase domain
# 2 Sialidase (EC 3.2.1.18)
# 2 Nitrogen regulatory protein P-II
# 2 L-serine dehydratase, beta subunit (EC 4.3.1.17) / L-serine dehydratase, alpha subunit (EC 4.3.1.17)
# 2 Putative polysaccharide deacetylase
#
# ferretti
# 21 Ribonucleotide reductase of class Ib (aerobic), alpha subunit (EC 1.17.4.1)
# 2 ThiF family protein, ubiquitin-activating enzyme
# 2 hypothetical protein
#
# shao
# 37 Transcription termination factor Rho
# 25 Protoporphyrinogen oxidase
# 24 hypothetical protein
# 9 N/A
# 4 DNA gyrase subunit B (EC 5.99.1.3)
# 3 Tn916, NLP/P60 family protein
# 3 Serine/threonine-protein kinase PknB (EC 2.7.11.1)
# 2 DNA-directed RNA polymerase beta subunit (EC 2.7.7.6)
# 2 Hypothetical, related to broad specificity phosphatases COG0406
# 2 Glycogen phosphorylase (EC 2.4.1.1)
# 2 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family

# %%
grouped_cohorts = {'hmp': ['hmp'], 'non-premie': ['backhed', 'yassour', 'ferretti', 'shao'], 'premie': ['olm'], 'infant': ['backhed', 'yassour', 'ferretti', 'shao', 'olm']}
changed_gene_name_counts_by_grouped_cohort = {grouped_cohort: defaultdict(int) for grouped_cohort in grouped_cohorts.keys()}

# Group by premie and non-premie
for cohort in changed_gene_name_counts_by_cohort:
    subdict = changed_gene_name_counts_by_cohort[cohort]
    for grouped_cohort in grouped_cohorts:
        if cohort in grouped_cohorts[grouped_cohort]:
            for gene_name in subdict:
                changed_gene_name_counts_by_grouped_cohort[grouped_cohort][gene_name] += subdict[gene_name]

# %%
for grouped_cohort in changed_gene_name_counts_by_grouped_cohort:
    subdict = changed_gene_name_counts_by_grouped_cohort[grouped_cohort]
    print(grouped_cohort)
    for gene_name, count in sorted(subdict.items(), key=lambda x: x[1], reverse=True):
        if count > 1:
            print("%i %s" % (count, gene_name))
    print('')
# Out:
# hmp
# 76 hypothetical protein
# 14 Oligopeptide ABC transporter, permease protein OppC (TC 3.A.1.5.1)
# 12 Biotin synthase (EC 2.8.1.6)
# 10 HAD-superfamily hydrolase, subfamily IA, variant 3
# 6 RND efflux system, inner membrane transporter
# 6 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 5 Outer membrane protein oprM
# 5 Oligopeptide ABC transporter, permease protein OppB (TC 3.A.1.5.1)
# 5 Vitamin B12 ABC transporter, ATP-binding protein BtuD
# 4 Ribonuclease J2 (endoribonuclease in RNA processing)
# 3 Sensory box/GGDEF family protein
# 3 N/A
# 3 DNA gyrase subunit A (EC 5.99.1.3)
# 2 Two-component system sensor histidine kinase
# 2 Vitamin B12 ABC transporter, substrate-binding protein BtuF
# 2 ATP:Cob(I)alamin adenosyltransferase (EC 2.5.1.17)
# 2 Argininosuccinate lyase (EC 4.3.2.1)
# 2 DNA-directed RNA polymerase beta subunit (EC 2.7.7.6)
# 2 Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family
#
# infant
# 68 hypothetical protein
# 37 Transcription termination factor Rho
# 25 Protoporphyrinogen oxidase
# 22 Ribonucleotide reductase of class Ib (aerobic), alpha subunit (EC 1.17.4.1)
# 20 N/A
# 16 FIG000875: Thioredoxin domain-containing protein EC-YbbN
# 11 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 8 narrowly conserved hypothetical protein
# 5 beta-glucosidase (EC 3.2.1.21)
# 5 Periplasmic ligand-binding sensor domain COG3292 / BaeS-type histidine kinase / OmpR-type DNA-binding response regulator
# 4 Electron transport complex protein RnfE
# 4 beta-galactosidase (EC 3.2.1.23)
# 4 RND efflux system, membrane fusion protein
# 4 DNA gyrase subunit B (EC 5.99.1.3)
# 3 Two-component system sensor histidine kinase
# 3 Tn916, NLP/P60 family protein
# 3 Putative glutathione transporter, permease component; Dipeptide ABC transporter, permease protein DppC (TC 3.A.1.5.2)
# 3 Glycogen phosphorylase (EC 2.4.1.1)
# 3 putative TonB-dependent receptor
# 3 Aspartate ammonia-lyase (EC 4.3.1.1)
# 3 Serine/threonine-protein kinase PknB (EC 2.7.11.1)
# 3 Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family
# 2 putative protein involved in capsular polysaccharide biosynthesis
# 2 RidA/YER057c/UK114 superfamily protein
# 2 L-serine dehydratase, beta subunit (EC 4.3.1.17) / L-serine dehydratase, alpha subunit (EC 4.3.1.17)
# 2 Sialidase (EC 3.2.1.18)
# 2 DNA-directed RNA polymerase beta subunit (EC 2.7.7.6)
# 2 ABC transporter, substrate-binding protein (cluster 1, maltose/g3p/polyamine/iron)
# 2 Two-component system sensor histidine kinase/response regulator hybrid
# 2 Esterase/lipase
# 2 Tyrosine-protein kinase (EC 2.7.10.2)
# 2 Lactose and galactose permease, GPH translocator family
# 2 Putative polysaccharide deacetylase
# 2 ThiF family protein, ubiquitin-activating enzyme
# 2 Sporulation transcription regulator WhiA
# 2 Nitrogen regulatory protein P-II
# 2 Phosphate regulon sensor protein PhoR (SphS) (EC 2.7.13.3)
# 2 Uncharacterized transporter YbxG
# 2 Cell division initiation protein DivIVA
# 2 Malate dehydrogenase (EC 1.1.1.37)
# 2 Transcriptional regulator pfoR
# 2 Glycosyl transferase, family 2
# 2 Hypothetical, related to broad specificity phosphatases COG0406
# 2 large transmembrane protein possibly involved in transport
# 2 putative two-component system sensor but no kinase domain
#
# premie
# 5 N/A
# 3 Putative glutathione transporter, permease component; Dipeptide ABC transporter, permease protein DppC (TC 3.A.1.5.2)
# 3 hypothetical protein
# 2 Uncharacterized transporter YbxG
# 2 Transcriptional regulator pfoR
#
# non-premie
# 65 hypothetical protein
# 37 Transcription termination factor Rho
# 25 Protoporphyrinogen oxidase
# 22 Ribonucleotide reductase of class Ib (aerobic), alpha subunit (EC 1.17.4.1)
# 16 FIG000875: Thioredoxin domain-containing protein EC-YbbN
# 15 N/A
# 11 Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 8 narrowly conserved hypothetical protein
# 5 beta-glucosidase (EC 3.2.1.21)
# 5 Periplasmic ligand-binding sensor domain COG3292 / BaeS-type histidine kinase / OmpR-type DNA-binding response regulator
# 4 Electron transport complex protein RnfE
# 4 beta-galactosidase (EC 3.2.1.23)
# 4 RND efflux system, membrane fusion protein
# 4 DNA gyrase subunit B (EC 5.99.1.3)
# 3 Two-component system sensor histidine kinase
# 3 Tn916, NLP/P60 family protein
# 3 Glycogen phosphorylase (EC 2.4.1.1)
# 3 putative TonB-dependent receptor
# 3 Aspartate ammonia-lyase (EC 4.3.1.1)
# 3 Serine/threonine-protein kinase PknB (EC 2.7.11.1)
# 3 Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family
# 2 putative protein involved in capsular polysaccharide biosynthesis
# 2 RidA/YER057c/UK114 superfamily protein
# 2 Cell division initiation protein DivIVA
# 2 L-serine dehydratase, beta subunit (EC 4.3.1.17) / L-serine dehydratase, alpha subunit (EC 4.3.1.17)
# 2 Sialidase (EC 3.2.1.18)
# 2 ABC transporter, substrate-binding protein (cluster 1, maltose/g3p/polyamine/iron)
# 2 Two-component system sensor histidine kinase/response regulator hybrid
# 2 Esterase/lipase
# 2 Tyrosine-protein kinase (EC 2.7.10.2)
# 2 Putative polysaccharide deacetylase
# 2 ThiF family protein, ubiquitin-activating enzyme
# 2 Lactose and galactose permease, GPH translocator family
# 2 Sporulation transcription regulator WhiA
# 2 Nitrogen regulatory protein P-II
# 2 DNA-directed RNA polymerase beta subunit (EC 2.7.7.6)
# 2 large transmembrane protein possibly involved in transport
# 2 Phosphate regulon sensor protein PhoR (SphS) (EC 2.7.13.3)
# 2 Malate dehydrogenase (EC 1.1.1.37)
# 2 Glycosyl transferase, family 2
# 2 Hypothetical, related to broad specificity phosphatases COG0406
# 2 putative two-component system sensor but no kinase domain

# %%
changed_gene_name_counts_by_cohort['backhed']
# Out:
# defaultdict(int,
#             {'1-acyl-sn-glycerol-3-phosphate acyltransferase': 1,
#              '16S rRNA (cytosine(1402)-N(4))-methyltransferase (EC 2.1.1.199)': 1,
#              'ABC transporter, ATP-binding protein (cluster 1, maltose/g3p/polyamine/iron); ABC transporter, ATP-binding protein (cluster 10, nitrate/sulfonate/bicarbonate)': 1,
#              'ABC transporter, permease protein 1 (cluster 1, maltose/g3p/polyamine/iron)': 1,
#              'ABC transporter, substrate-binding protein (cluster 1, maltose/g3p/polyamine/iron)': 2,
#              'ATP-dependent DNA helicase RecQ': 1,
#              'Acetylornithine deacetylase/Succinyl-diaminopimelate desuccinylase and related deacylases': 1,
#              'Acidobacterial duplicated orphan permease (function unknown)': 1,
#              'Acyl-[acyl-carrier-protein]--UDP-N-acetylglucosamine O-acyltransferase (EC 2.3.1.129)': 1,
#              'Alpha-1,2-mannosidase': 1,
#              'Aminopeptidase C (EC 3.4.22.40)': 1,
#              'Aminotransferase, DegT/DnrJ/EryC1/StrS family': 1,
#              'Anthranilate phosphoribosyltransferase (EC 2.4.2.18)': 1,
#              'Arabinan endo-1,5-alpha-L-arabinosidase (EC 3.2.1.99)': 1,
#              'Asparagine synthetase [glutamine-hydrolyzing] (EC 6.3.5.4) AsnB': 1,
#              'Aspartate ammonia-lyase (EC 4.3.1.1)': 3,
#              'Biotin carboxylase of acetyl-CoA carboxylase (EC 6.3.4.14)': 1,
#              'Cell division initiation protein DivIVA': 2,
#              'Cell division protein FtsL': 1,
#              'Cell surface glycan-binding lipoprotein, utilization system for glycans and polysaccharides (PUL), SusD family': 3,
#              'Chitinase (EC 3.2.1.14)': 1,
#              'Chromate transport protein': 1,
#              'Citrate/H+ symporter of CitMHS family': 1,
#              'Cobalt-zinc-cadmium resistance protein': 1,
#              'DNA ligase (NAD(+)) (EC 6.5.1.2)': 1,
#              'DNA-binding transcriptional activator DecR, AsnC family': 1,
#              'Di-tripeptide/cation symporter': 1,
#              'DnaD domain protein': 1,
#              'Esterase/lipase': 2,
#              'Excinuclease ABC subunit B': 1,
#              'FIG000875: Thioredoxin domain-containing protein EC-YbbN': 16,
#              'Glutaminyl-tRNA synthetase (EC 6.1.1.18)': 1,
#              'Glycerol-3-phosphate dehydrogenase [NAD(P)+] (EC 1.1.1.94)': 1,
#              'Glycogen phosphorylase (EC 2.4.1.1)': 1,
#              'Glycosyl transferase, family 2': 1,
#              'L-serine dehydratase, beta subunit (EC 4.3.1.17) / L-serine dehydratase, alpha subunit (EC 4.3.1.17)': 2,
#              'Lactose and galactose permease, GPH translocator family': 2,
#              'Malate dehydrogenase (EC 1.1.1.37)': 2,
#              'Methylated-DNA--protein-cysteine methyltransferase (EC 2.1.1.63)': 1,
#              'Multi antimicrobial extrusion protein (Na(+)/drug antiporter), MATE family of MDR efflux pumps': 1,
#              'N/A': 5,
#              'NifU-related domain containing protein': 1,
#              'Nitrogen regulatory protein P-II': 2,
#              'O-antigen chain length determinant protein WzzB': 1,
#              'OmpA family protein': 1,
#              'Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family': 5,
#              'Oxidoreductase, Gfo/Idh/MocA family': 1,
#              'Periplasmic ligand-binding sensor domain COG3292 / BaeS-type histidine kinase / OmpR-type DNA-binding response regulator': 2,
#              'Phosphate regulon sensor protein PhoR (SphS) (EC 2.7.13.3)': 1,
#              'Phosphotransferase involved in threonylcarbamoyladenosine t(6)A37 formation in tRNA': 1,
#              'Probable outer membrane receptor protein': 1,
#              'Putative NADH-dependent dehydrogenase': 1,
#              'Putative TonB-dependent receptor': 1,
#              'Putative helicase': 1,
#              'Putative large secreted protein SCO0341': 1,
#              'Putative outer membrane protein, probably involved in nutrient binding': 1,
#              'Putative polysaccharide deacetylase': 2,
#              'Putative sulfatase': 1,
#              'RND efflux system, membrane fusion protein': 4,
#              'RidA/YER057c/UK114 superfamily protein': 2,
#              'Sialidase (EC 3.2.1.18)': 2,
#              'Spermidine/putrescine import ABC transporter substrate-binding protein PotD (TC 3.A.1.11.1)': 1,
#              'Sporulation transcription regulator WhiA': 1,
#              'Tetratricopeptide repeat family protein': 1,
#              'ThiJ/PfpI family': 1,
#              'Transcriptional regulator': 1,
#              'Transcriptional regulator, AcrR family': 1,
#              'Transcriptional regulator, AraC family': 1,
#              'Two-component system sensor histidine kinase': 3,
#              'Two-component transcriptional response regulator, LuxR family': 1,
#              'UDP-glucose 6-dehydrogenase (EC 1.1.1.22)': 1,
#              'Valyl-tRNA synthetase (EC 6.1.1.9)': 1,
#              'alpha-L-fucosidase (EC 3.2.1.51)': 1,
#              'beta-galactosidase (EC 3.2.1.23)': 3,
#              'beta-glucosidase (EC 3.2.1.21)': 1,
#              'hypothetical protein': 29,
#              'large transmembrane protein possibly involved in transport': 2,
#              'narrowly conserved hypothetical protein': 8,
#              'putative TonB-dependent receptor': 3,
#              'putative protein involved in capsular polysaccharide biosynthesis': 2,
#              'putative two-component system sensor but no kinase domain': 2})

# %%
genes_cohort = {cohort: set() for cohort in cohorts}

for cohort in genes_tp_pairs:
    for gene_tuple in genes_tp_pairs[cohort]:
        for tp_pair in genes_tp_pairs[cohort][gene_tuple]:
            tpa, tpb = tp_pair
            tp_type = tpa[0] + tpb[0]
            if tp_type == 'II':
                genes_cohort[cohort].add(gene_tuple)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-20-ba4a14aba8bd> in <module>()
#       1 genes_cohort = {cohort: set() for cohort in cohorts}
#       2
# ----> 3 for cohort in genes_tp_pairs:
#       4     for gene_tuple in genes_tp_pairs[cohort]:
#       5         for tp_pair in genes_tp_pairs[cohort][gene_tuple]:
#
# NameError: name 'genes_tp_pairs' is not defined

# %%
genes_cohort
# Out:
# {'backhed': set(),
#  'ferretti': set(),
#  'hmp': set(),
#  'olm': set(),
#  'shao': set(),
#  'yassour': set()}

# %%
# Formatted printing of reversions
for species, cohort, subject, site, gene_id, gene_name, var_type, ordered_tp_freqs in reversions:
    
    print(species + ' | ' + cohort + ' | Subject: ' + subject)
    print("Gene id: " + gene_id + ' | Variant type: ' + var_type)
    print("Gene name: " + gene_name)
    for tp, freq in ordered_tp_freqs:
        print('\t' + tp + ': %.03f' % freq)
    print('')
# Out:
# Enterococcus_faecalis_56297 | olm | Subject: N1_018
# Gene id: 1158976.3.peg.771 | Variant type: 4D
# Gene name: hypothetical protein
# 	I18: 0.826
# 	I19: 0.074
# 	I20: 0.074
# 	I24: 0.801
# 	I37: 0.118
#
# Klebsiella_pneumoniae_54788 | olm | Subject: N1_023
# Gene id: 1328400.3.peg.232 | Variant type: 1D
# Gene name: No name
# 	I15: 0.026
# 	I17: 0.897
# 	I18: 0.818
# 	I19: 0.088
# 	I21: 0.911
# 	I29: 0.172
#
# Citrobacter_freundii_56148 | olm | Subject: N1_009
# Gene id: 1114920.3.peg.2929 | Variant type: 4D
# Gene name: Phosphoenolpyruvate-dihydroxyacetone phosphotransferase operon regulatory protein DhaR
# 	I10: 0.870
# 	I13: 0.164
# 	I15: 0.091
# 	I16: 0.191
# 	I17: 0.944
#
# Bacteroides_vulgatus_57955 | olm | Subject: N4_097
# Gene id: 435590.9.peg.1561 | Variant type: 4D
# Gene name: Uncharacterized protein BT3327
# 	I12: 0.112
# 	I27: 0.826
# 	I34: 0.115
#
# Bacteroides_vulgatus_57955 | yassour | Subject: M1098-M
# Gene id: 435590.9.peg.52 | Variant type: 1D
# Gene name: DNA internalization-related competence protein ComEC/Rec2
# 	M1: 1.000
# 	I2: 0.176
# 	I3: 0.176
# 	I4: 1.000
# 	I5: 0.962
#
# Bacteroides_vulgatus_57955 | yassour | Subject: M1098-M
# Gene id: 435590.9.peg.543 | Variant type: 2D
# Gene name: Translation elongation factor P
# 	M1: 0.979
# 	I2: 0.154
# 	I3: 0.154
# 	I4: 1.000
# 	I5: 1.000
#
# Bacteroides_vulgatus_57955 | yassour | Subject: M0808-M
# Gene id: 435590.9.peg.47 | Variant type: 4D
# Gene name: Keratan-sulfate endo-1,4-beta-galactosidase (EC 3.2.1.103)
# 	M1: 0.000
# 	M2: 0.885
# 	M3: 0.885
# 	I4: 0.094
#
# Bacteroides_vulgatus_57955 | yassour | Subject: M0808-M
# Gene id: 435590.9.peg.1738 | Variant type: 1D
# Gene name: Transcriptional regulator, AraC family
# 	M1: 0.000
# 	M2: 0.941
# 	M3: 0.941
# 	I4: 0.020
#
# Bacteroides_vulgatus_57955 | yassour | Subject: M0808-M
# Gene id: 435590.9.peg.2142 | Variant type: 2D
# Gene name: ATP-dependent DNA helicase RecS (RecQ family)
# 	M1: 0.011
# 	M2: 0.964
# 	M3: 0.964
# 	I4: 0.022
#
# Bacteroides_vulgatus_57955 | yassour | Subject: M0808-M
# Gene id: 435590.9.peg.2509 | Variant type: 4D
# Gene name: Outer membrane TonB-dependent transporter, utilization system for glycans and polysaccharides (PUL), SusC family
# 	M1: 0.000
# 	M2: 0.919
# 	M3: 0.919
# 	I4: 0.000
#
# Enterobacter_aerogenes_55704 | olm | Subject: N1_011
# Gene id: 1400143.3.peg.1706 | Variant type: 2D
# Gene name: Anaerobic dimethyl sulfoxide reductase chain B (EC 1.8.5.3), iron-sulfur binding subunit
# 	I11: 0.164
# 	I13: 0.958
# 	I15: 0.146
# 	I20: 0.976
# 	I21: 0.095
# 	I23: 0.980
# 	I33: 0.877
# 	I37: 0.936
# 	I46: 0.097
# 	I62: 0.140
# 	I69: 0.859
