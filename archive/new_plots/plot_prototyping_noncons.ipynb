# %%
from utils import config, parse_midas_data, sample_utils as su, temporal_changes_utils, stats_utils, midas_db_utils, parse_patric
from collections import defaultdict
import numpy as np
import pickle
import sys
import random
from math import log10,ceil,log,exp

import matplotlib.cm as cmx
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.colors as mcolors
import matplotlib.patheffects as pe

# Cohort list
cohorts = ['backhed', 'ferretti', 'yassour', 'shao', 'olm', 'hmp']

# Plot directory
plot_dir = "%s/" % (config.analysis_directory)

# Species list
good_species_list = parse_midas_data.load_pickled_good_species_list()

# Sample-subject-order maps
sys.stderr.write("Loading sample metadata...\n")
subject_sample_map = su.parse_subject_sample_map()
sample_order_map = su.parse_sample_order_map()
sample_subject_map = su.parse_sample_subject_map()
sys.stderr.write("Done!\n")

# Timepoint pair types
tp_pair_names = ['MM', 'MI', 'II', 'AA']

# Cohorts
cohorts = ['backhed', 'ferretti', 'yassour', 'shao', 'hmp']
mi_cohorts = ['backhed', 'ferretti', 'yassour', 'shao']

# Samples for each cohort
samples = {cohort: su.get_sample_names(cohort) for cohort in cohorts}
hmp_samples = su.get_sample_names('hmp')
mother_samples = su.get_sample_names('mother')
infant_samples = su.get_sample_names('infant')
olm_samples = su.get_sample_names('olm')
infant_samples_no_olm = [sample for sample in infant_samples if sample not in olm_samples]
mi_samples_no_olm = [sample for sample in (mother_samples + infant_samples) if sample not in olm_samples]

# Sample-cohort map
sample_cohort_map = su.parse_sample_cohort_map()

# Sample-timepoint map
mi_sample_day_dict = su.get_mi_sample_day_dict(exclude_cohorts=['olm'])
mi_tp_sample_dict = su.get_mi_tp_sample_dict(exclude_cohorts=['olm']) # no binning
mi_tp_sample_dict_binned, mi_tp_binned_labels = su.get_mi_tp_sample_dict(exclude_cohorts=['olm'], binned=True)
# Out:
# Loading sample metadata...
# Done!

# %%
# ======================================================================
# Load pickled data
# ======================================================================

# Parameters
sweep_type = 'full' # assume full for now
pp_prev_cohort = 'all'
min_coverage = 0

ddir = config.data_directory
pdir = "%s/pickles/cov%i_prev_%s/nonconsecutive" % (ddir, min_coverage, pp_prev_cohort)

snp_changes = pickle.load(open('%s/big_snp_changes_%s.pkl' % (pdir, sweep_type), 'rb'))
gene_changes = pickle.load(open('%s/big_gene_changes_%s.pkl' % (pdir, sweep_type), 'rb'))
snp_change_freqs = pickle.load(open('%s/snp_change_freqs_%s.pkl' % (pdir, sweep_type), 'rb'))
snp_change_freqs_with_opps = pickle.load(open('%s/snp_change_freqs_with_opps_full.pkl' % (pdir), 'rb'))
snp_change_null_freqs = pickle.load(open('%s/snp_change_null_freqs_%s.pkl' % (pdir, sweep_type), 'rb'))
gene_gain_freqs = pickle.load(open('%s/gene_gain_freqs_%s.pkl' % (pdir, sweep_type), 'rb'))
gene_loss_freqs = pickle.load(open('%s/gene_loss_freqs_%s.pkl' % (pdir, sweep_type), 'rb'))
gene_loss_null_freqs = pickle.load(open('%s/gene_loss_null_freqs_%s.pkl' % (pdir, sweep_type), 'rb'))
between_snp_change_counts = pickle.load(open('%s/between_snp_change_counts_%s.pkl' % (pdir, sweep_type), 'rb'))
between_gene_change_counts = pickle.load(open('%s/between_gene_change_counts_%s.pkl' % (pdir, sweep_type), 'rb'))
snp_change_present_gene_null = pickle.load(open('%s/snp_change_present_gene_null' % pdir, 'rb'))
snp_change_between_host_null = pickle.load(open('%s/snp_change_between_host_null' % pdir, 'rb'))
snp_change_pangenome_null = pickle.load(open('%s/snp_change_pangenome_null' % pdir, 'rb'))
dnds_info = pickle.load(open('%s/dnds_info.pkl' % (pdir), 'rb'))

# %%
# Consecutive data

# Parameters
sweep_type = 'full' # assume full for now
pp_prev_cohort = 'all'
min_coverage = 0

ddir = config.data_directory
pdir = "%s/pickles/cov%i_prev_%s" % (ddir, min_coverage, pp_prev_cohort)

snp_changes_consecutive = pickle.load(open('%s/big_snp_changes_%s.pkl' % (pdir, sweep_type), 'rb'))

# %%
# Calculate number of days for a timpeoint pair

mi_sample_day_dict = su.get_mi_sample_day_dict()

def sample_pair_to_days(sample1, sample2):
    days = mi_sample_day_dict[sample2] - mi_sample_day_dict[sample1]
    if days < 0:
        return np.abs(days)
    return days

def tp_pair_to_days(tp_pair):
    tpa, tpb = tp_pair
    o1 = float(tpa[1:])
    o2 = float(tpb[1:])
    return np.abs(o1-o2)

# Rough approximation of HMP time intervals
def adult_tp_pair_to_days(tp_pair):
    tpa, tpb = tp_pair
    return np.abs(int(tpa[-1:]) - int(tpb[-1:]))*183

def tp_pair_to_tp_type(tp_pair):
    tpa, tpb = tp_pair
    tp_type = tpa[0] + tpb[0]
    if tp_type == 'IM':
        tp_type = 'MI'
    return tp_type

# %%
# Settings for prevalence plots

modification_difference_threshold = config.modification_difference_threshold
replacement_difference_threshold = config.replacement_difference_threshold
default_num_bootstraps = 10000
min_sample_size = 3
min_haploid_sample_size = 10

variant_types = ['1D','4D']
within_host_type = 'consecutive' # consecutive timepoints (vs. longest)

num_bootstraps = 10 # for gene change prevalence null

# For partitioning SNVs according to prevalence
derived_freq_bins = np.array([-1,0,0.01,0.1,0.5,0.9,0.99,1,2])
derived_virtual_freqs = np.arange(0,len(derived_freq_bins)-1)
derived_virtual_xticks = list(derived_virtual_freqs[:-1]+0.5)
derived_virtual_xticklabels = ['0','.01','.1','.5','.9','.99','1']

# For partitioning genes into different prevalence classes
gene_freq_bins = np.array([-1,0.1,0.5,0.9,2])
gene_freq_xticks = [-4, -3, -2, -1, 0, 1, 2, 3, 4]
gene_freq_xticklabels = ['0','0.1','0.5', '0.9','1','0.9','0.5', '0.1','0']
gene_gain_virtual_freqs = np.array([3.5,2.5,1.5,0.5])
gene_loss_virtual_freqs = np.array([-3.5,-2.5,-1.5,-0.5])

# Function
def get_f_idx(f):
    return ((f>derived_freq_bins[:-1])*
            (f<=derived_freq_bins[1:])).argmax()

# %%
# Do suspected de novo mutations in infants revert within hosts?

# subject -> species -> (day1, day2) -> list of SNP change tuples OR 'replacement'
host_snp_changes = defaultdict(dict)
# subject -> species -> (day1, day2) -> list of (vartype, fdict) tuples OR 'replacement
host_snp_changes_freqs = defaultdict(dict)

for species in snp_changes:
    for sample_i, sample_j in snp_changes[species]:
        
        tp_pair = su.sample_pair_to_tp_pair(sample_i, sample_j, sample_order_map, hmp_samples, mother_samples)
        tp_type = tp_pair_to_tp_type(tp_pair)
        if tp_type != 'MI' and tp_type != 'II': # Only look at mother-infant or infant-infant
            continue
        
        subject = sample_subject_map[sample_j][:-2] # Combine mother and infant subjects!
        day1, day2 = mi_sample_day_dict[sample_i], mi_sample_day_dict[sample_j]
        
        pdicts = snp_change_freqs_with_opps[species][(sample_i, sample_j)] # list of (vartype, freq_dict, opp_dict tuples)
        npdict = snp_change_null_freqs[species][(sample_i, sample_j)] # dict: prev_cohort > list of (freq, weight) tuples
        
        snp_change_val = snp_changes[species][(sample_i, sample_j)]
        
        nonsyn_diffs, nonsyn_opps, syn_diffs, syn_opps = dnds_info[species][(sample_i, sample_j)]
        
        if type(snp_change_val) == type(1): # Replacement
            try:
                host_snp_changes[subject][species][(day1, day2, tp_type)] = 'replacement'
                host_snp_changes_freqs[subject][species][(day1, day2, tp_type)] = 'replacement'
            except:
                host_snp_changes[subject][species] = {(day1, day2, tp_type): 'replacement'}
                host_snp_changes_freqs[subject][species] = {(day1, day2, tp_type): 'replacement'}
        else:
            try:
                host_snp_changes[subject][species][(day1, day2, tp_type)] = snp_changes[species][(sample_i, sample_j)]
                host_snp_changes_freqs[subject][species][(day1, day2, tp_type)] = pdicts
            except:
                host_snp_changes[subject][species] = {(day1, day2, tp_type): snp_changes[species][(sample_i, sample_j)]}
                host_snp_changes_freqs[subject][species] = {(day1, day2, tp_type): pdicts}

# %%
num_host_species_pairs = 0
desired_host_species_sites = []

for subject in host_snp_changes:
    for species in host_snp_changes[subject]:        
        if len(host_snp_changes[subject][species].keys()) > 1:
            num_host_species_pairs += 1
            print("Subject: %s, Species: %s" % (subject, species))
            sites = []
            for day1, day2, tp_type in sorted(host_snp_changes[subject][species].keys(), key=lambda x: x[0]):
                print('\n%s Day %i to day %i' % (tp_type, day1, day2))
                snp_change_list = host_snp_changes[subject][species][(day1, day2, tp_type)]
                snp_change_freqs_list = host_snp_changes_freqs[subject][species][(day1, day2, tp_type)]
                for snp_change, x_snp_change_freqs in zip(snp_change_list, snp_change_freqs_list):
                    gene_id, contig, location, vartype, a1, d1, a2, d2 = snp_change
                    vartype2, freq_dict, opp_dict = x_snp_change_freqs
                    if vartype != vartype2:
                        print("Weird")
                    sites.append((gene_id, contig, location))
                    print("Site: %s,%s,%s\t| Vartype: %s" % (gene_id, contig, location, vartype))
                    print("\t%i %i %i %i | %.02f -> %.02f" % (a1, d1, a2, d2, float(a1)/d1, float(a2)/d2))
                    print("\tInfant prev: %.02f | HMP prev: %.02f | Mother prev: %.02f" % (freq_dict['nonpremie'], freq_dict['hmp'], freq_dict['mother']))
            desired_host_species_sites.append(([subject], species, sites))
            print("\n=============================================================================")

# %%
# Get a sense of available timepoints per host
# so I filter out MI appropriately
# Wait... should I not be restricting to modifications?
# Including any nonconsecutive timepoint pair, calculation seems correct

num_only_infant = 0
num_have_mother = 0

for subject in host_snp_changes:
    for species in host_snp_changes[subject]:
        m_days = set()
        i_days = set()
        for day1, day2, tp_type in sorted(host_snp_changes[subject][species].keys(), key=lambda x: x[0]):
            if tp_type == 'MI':
                m_days.add(day1)
                i_days.add(day2)
            elif tp_type == 'II':
                i_days.add(day1)
                i_days.add(day2)
        
        if len(m_days) > 0:
            num_have_mother += 1
            print("Subject: %s, Species: %s" % (subject, species))
            print("Mother: %s" % str(sorted(list(m_days))))
            print("Infant: %s" % str(sorted(list(i_days))))
            print("Pairs: %s" % str(host_snp_changes[subject][species].keys()))
            print('')
        else:
            num_only_infant += 1
# Out:
# Subject: M0305, Species: Bacteroides_uniformis_57318
# Mother: [0, 92]
# Infant: [14, 30]
# Pairs: [(0, 30, 'MI'), (14, 30, 'II'), (92, 30, 'MI'), (92, 14, 'MI'), (0, 14, 'MI')]
#
# Subject: A01805, Species: Bifidobacterium_adolescentis_56815
# Mother: [1]
# Infant: [4]
# Pairs: [(1, 4, 'MI')]
#
# Subject: C01758, Species: Escherichia_coli_58110
# Mother: [1]
# Infant: [21, 311]
# Pairs: [(1, 21, 'MI'), (21, 311, 'II'), (1, 311, 'MI')]
#
# Subject: C01758, Species: Bacteroides_vulgatus_57955
# Mother: [1]
# Infant: [311]
# Pairs: [(1, 311, 'MI')]
#
# Subject: C01930, Species: Enterococcus_faecium_56947
# Mother: [1]
# Infant: [7]
# Pairs: [(1, 7, 'MI')]
#
# Subject: C01930, Species: Bacteroides_uniformis_57318
# Mother: [1]
# Infant: [271]
# Pairs: [(1, 271, 'MI')]
#
# Subject: 100, Species: Bifidobacterium_bifidum_55065
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 100, Species: Blautia_wexlerae_56130
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 39, Species: Bacteroides_caccae_53434
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 39, Species: Bacteroides_fragilis_54507
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 33, Species: Alistipes_putredinis_61533
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 35, Species: Eubacterium_rectale_56927
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 35, Species: Roseburia_intestinalis_56239
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 35, Species: Bacteroides_eggerthii_54457
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: B01771, Species: Bacteroides_uniformis_57318
# Mother: [1]
# Infant: [7]
# Pairs: [(1, 7, 'MI')]
#
# Subject: CA_C10055, Species: Alistipes_putredinis_61533
# Mother: [1]
# Infant: [0]
# Pairs: [(1, 0, 'MI')]
#
# Subject: 98, Species: Bacteroides_cellulosilyticus_58046
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 98, Species: Parabacteroides_distasonis_56985
# Mother: [2]
# Infant: [122, 366]
# Pairs: [(2, 122, 'MI'), (122, 366, 'II'), (2, 366, 'MI')]
#
# Subject: 91, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 90, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 93, Species: Alistipes_finegoldii_56071
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 93, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 93, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 92, Species: Escherichia_coli_58110
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 94, Species: Bacteroides_stercoris_56735
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 94, Species: Parabacteroides_distasonis_56985
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 94, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [122, 366]
# Pairs: [(2, 122, 'MI'), (122, 366, 'II'), (2, 366, 'MI')]
#
# Subject: 97, Species: Prevotella_copri_61740
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 97, Species: Alistipes_putredinis_61533
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 96, Species: Bacteroides_ovatus_58035
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: B01194, Species: Bifidobacterium_bifidum_55065
# Mother: [1]
# Infant: [4, 7, 21]
# Pairs: [(1, 4, 'MI'), (7, 21, 'II'), (4, 7, 'II'), (4, 21, 'II'), (1, 7, 'MI'), (1, 21, 'MI')]
#
# Subject: B01194, Species: Bifidobacterium_catenulatum_58257
# Mother: [1]
# Infant: [4, 7, 21]
# Pairs: [(1, 4, 'MI'), (7, 21, 'II'), (4, 7, 'II'), (4, 21, 'II'), (1, 7, 'MI'), (1, 21, 'MI')]
#
# Subject: 604136, Species: Bifidobacterium_bifidum_55065
# Mother: [1]
# Infant: [7, 10, 11, 14]
# Pairs: [(10, 11, 'II'), (7, 11, 'II'), (10, 14, 'II'), (11, 14, 'II'), (1, 11, 'MI'), (7, 10, 'II'), (7, 14, 'II'), (1, 7, 'MI'), (1, 10, 'MI'), (1, 14, 'MI')]
#
# Subject: C02143, Species: Bifidobacterium_bifidum_55065
# Mother: [1]
# Infant: [7, 237]
# Pairs: [(1, 237, 'MI'), (1, 7, 'MI'), (7, 237, 'II')]
#
# Subject: B00139, Species: Bifidobacterium_longum_57796
# Mother: [1]
# Infant: [21]
# Pairs: [(1, 21, 'MI')]
#
# Subject: C01840, Species: Bacteroides_vulgatus_57955
# Mother: [1]
# Infant: [4, 7, 21, 289]
# Pairs: [(1, 4, 'MI'), (7, 21, 'II'), (1, 289, 'MI'), (7, 289, 'II'), (4, 7, 'II'), (4, 21, 'II'), (1, 7, 'MI'), (21, 289, 'II'), (1, 21, 'MI'), (4, 289, 'II')]
#
# Subject: 27, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [3, 122]
# Pairs: [(3, 122, 'II'), (2, 3, 'MI'), (2, 122, 'MI')]
#
# Subject: 20, Species: Parabacteroides_distasonis_56985
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 20, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [3, 122, 366]
# Pairs: [(2, 3, 'MI'), (122, 366, 'II'), (3, 366, 'II'), (2, 366, 'MI'), (3, 122, 'II'), (2, 122, 'MI')]
#
# Subject: 28, Species: Alistipes_finegoldii_56071
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 29, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 29, Species: Escherichia_coli_58110
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: CA_C10009, Species: Dialister_invisus_61905
# Mother: [30]
# Infant: [0]
# Pairs: [(30, 0, 'MI')]
#
# Subject: CA_C10009, Species: Alistipes_putredinis_61533
# Mother: [30]
# Infant: [0]
# Pairs: [(30, 0, 'MI')]
#
# Subject: CA_C10007, Species: Bacteroides_ovatus_58035
# Mother: [0]
# Infant: [122]
# Pairs: [(0, 122, 'MI')]
#
# Subject: 88, Species: Bacteroides_fragilis_54507
# Mother: [2]
# Infant: [3, 366]
# Pairs: [(2, 3, 'MI'), (3, 366, 'II'), (2, 366, 'MI')]
#
# Subject: 88, Species: Parabacteroides_distasonis_56985
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 88, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: A02110, Species: Bacteroides_cellulosilyticus_58046
# Mother: [1]
# Infant: [211]
# Pairs: [(1, 211, 'MI')]
#
# Subject: 82, Species: Bacteroides_thetaiotaomicron_56941
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 82, Species: Bacteroides_cellulosilyticus_58046
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 82, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 80, Species: Bacteroides_ovatus_58035
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 81, Species: Bacteroides_stercoris_56735
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 81, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [122, 366]
# Pairs: [(122, 366, 'II'), (2, 122, 'MI'), (2, 366, 'MI')]
#
# Subject: 87, Species: Akkermansia_muciniphila_55290
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 87, Species: Alistipes_putredinis_61533
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: M1098, Species: Bacteroides_vulgatus_57955
# Mother: [-92, 0]
# Infant: [0, 14, 30, 61, 92]
# Pairs: [(0, 14, 'MI'), (0, 92, 'MI'), (14, 61, 'II'), (14, 30, 'II'), (-92, 14, 'MI'), (0, 14, 'II'), (0, 61, 'MI'), (30, 92, 'II'), (0, 0, 'MI'), (61, 92, 'II'), (0, 30, 'MI'), (30, 61, 'II'), (-92, 61, 'MI'), (-92, 92, 'MI'), (0, 92, 'II'), (0, 30, 'II'), (-92, 0, 'MI'), (14, 92, 'II'), (0, 61, 'II'), (-92, 30, 'MI')]
#
# Subject: 7, Species: Bacteroides_ovatus_58035
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 7, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: B02243, Species: Bifidobacterium_bifidum_55065
# Mother: [1]
# Infant: [221]
# Pairs: [(1, 221, 'MI')]
#
# Subject: B00040, Species: Escherichia_coli_58110
# Mother: [1]
# Infant: [4]
# Pairs: [(1, 4, 'MI')]
#
# Subject: M0074, Species: Bacteroides_stercoris_56735
# Mother: [92]
# Infant: [0]
# Pairs: [(92, 0, 'MI')]
#
# Subject: M0074, Species: Bacteroides_uniformis_57318
# Mother: [-92, 0, 92]
# Infant: [14]
# Pairs: [(0, 14, 'MI'), (92, 14, 'MI'), (-92, 14, 'MI')]
#
# Subject: M0074, Species: Bacteroides_vulgatus_57955
# Mother: [-92, 92]
# Infant: [0]
# Pairs: [(92, 0, 'MI'), (-92, 0, 'MI')]
#
# Subject: M0073, Species: Bacteroides_vulgatus_57955
# Mother: [0]
# Infant: [14, 30, 61, 92]
# Pairs: [(0, 14, 'MI'), (14, 61, 'II'), (0, 61, 'MI'), (30, 92, 'II'), (14, 30, 'II'), (61, 92, 'II'), (0, 30, 'MI'), (30, 61, 'II'), (0, 92, 'MI'), (14, 92, 'II')]
#
# Subject: C01075, Species: Prevotella_copri_61740
# Mother: [1]
# Infant: [4]
# Pairs: [(1, 4, 'MI')]
#
# Subject: 13, Species: Alistipes_putredinis_61533
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 13, Species: Bacteroides_cellulosilyticus_58046
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 13, Species: Escherichia_coli_58110
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 13, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 15, Species: Ruminococcus_bromii_62047
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 15, Species: Bacteroides_caccae_53434
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 14, Species: Alistipes_putredinis_61533
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 19, Species: Bacteroides_stercoris_56735
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 19, Species: Parabacteroides_distasonis_56985
# Mother: [2]
# Infant: [3, 122, 366]
# Pairs: [(2, 3, 'MI'), (122, 366, 'II'), (3, 366, 'II'), (2, 366, 'MI'), (3, 122, 'II'), (2, 122, 'MI')]
#
# Subject: 19, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 18, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 18, Species: Bacteroides_fragilis_54507
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 18, Species: Parabacteroides_distasonis_56985
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 18, Species: Bacteroides_stercoris_56735
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 18, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: M0327, Species: Bacteroides_caccae_53434
# Mother: [0]
# Infant: [30, 92]
# Pairs: [(0, 30, 'MI'), (0, 92, 'MI'), (30, 92, 'II')]
#
# Subject: M0450, Species: Bifidobacterium_adolescentis_56815
# Mother: [92]
# Infant: [61]
# Pairs: [(92, 61, 'MI')]
#
# Subject: C01696, Species: Citrobacter_freundii_56148
# Mother: [1]
# Infant: [7]
# Pairs: [(1, 7, 'MI')]
#
# Subject: B01234, Species: Bacteroides_uniformis_57318
# Mother: [1]
# Infant: [383]
# Pairs: [(1, 383, 'MI')]
#
# Subject: C01917, Species: Faecalibacterium_cf_62236
# Mother: [1]
# Infant: [311]
# Pairs: [(1, 311, 'MI')]
#
# Subject: C01917, Species: Escherichia_coli_58110
# Mother: [1]
# Infant: [4, 7]
# Pairs: [(1, 4, 'MI'), (4, 7, 'II'), (1, 7, 'MI')]
#
# Subject: 75, Species: Bifidobacterium_bifidum_55065
# Mother: [2]
# Infant: [3, 122]
# Pairs: [(3, 122, 'II'), (2, 3, 'MI'), (2, 122, 'MI')]
#
# Subject: 75, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 75, Species: Bifidobacterium_longum_57796
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 75, Species: Bifidobacterium_pseudocatenulatum_57754
# Mother: [2]
# Infant: [3, 122]
# Pairs: [(3, 122, 'II'), (2, 3, 'MI'), (2, 122, 'MI')]
#
# Subject: 74, Species: Bacteroides_eggerthii_54457
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 73, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 11, Species: Bifidobacterium_longum_57796
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 11, Species: Bacteroides_fragilis_54507
# Mother: [2]
# Infant: [3, 122, 366]
# Pairs: [(2, 3, 'MI'), (122, 366, 'II'), (3, 366, 'II'), (2, 366, 'MI'), (3, 122, 'II'), (2, 122, 'MI')]
#
# Subject: 10, Species: Bacteroides_xylanisolvens_57185
# Mother: [2]
# Infant: [3, 366]
# Pairs: [(2, 3, 'MI'), (3, 366, 'II'), (2, 366, 'MI')]
#
# Subject: 12, Species: Alistipes_putredinis_61533
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: M0369, Species: Akkermansia_muciniphila_55290
# Mother: [-92]
# Infant: [61, 92]
# Pairs: [(61, 92, 'II'), (-92, 61, 'MI'), (-92, 92, 'MI')]
#
# Subject: BBS0067, Species: Bacteroides_vulgatus_57955
# Mother: [1]
# Infant: [7]
# Pairs: [(1, 7, 'MI')]
#
# Subject: 3, Species: Bacteroides_stercoris_56735
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: CA_C10039, Species: Bacteroides_caccae_53434
# Mother: [0]
# Infant: [7]
# Pairs: [(0, 7, 'MI')]
#
# Subject: CA_C10035, Species: Bacteroides_vulgatus_57955
# Mother: [3]
# Infant: [0]
# Pairs: [(3, 0, 'MI')]
#
# Subject: M0764, Species: Bacteroides_uniformis_57318
# Mother: [0]
# Infant: [30, 61, 92]
# Pairs: [(0, 61, 'MI'), (30, 92, 'II'), (61, 92, 'II'), (0, 30, 'MI'), (30, 61, 'II'), (0, 92, 'MI')]
#
# Subject: M0402, Species: Bifidobacterium_pseudocatenulatum_57754
# Mother: [92]
# Infant: [92]
# Pairs: [(92, 92, 'MI')]
#
# Subject: M0402, Species: Alistipes_onderdonkii_55464
# Mother: [-92, 92]
# Infant: [14]
# Pairs: [(-92, 14, 'MI'), (92, 14, 'MI')]
#
# Subject: M0402, Species: Bacteroides_stercoris_56735
# Mother: [-92, 92]
# Infant: [14]
# Pairs: [(-92, 14, 'MI'), (92, 14, 'MI')]
#
# Subject: B01409, Species: Bifidobacterium_longum_57796
# Mother: [1]
# Infant: [4, 7, 21]
# Pairs: [(1, 4, 'MI'), (7, 21, 'II'), (4, 7, 'II'), (4, 21, 'II'), (1, 7, 'MI'), (1, 21, 'MI')]
#
# Subject: 61, Species: Bacteroides_stercoris_56735
# Mother: [2]
# Infant: [122, 366]
# Pairs: [(2, 122, 'MI'), (122, 366, 'II'), (2, 366, 'MI')]
#
# Subject: 61, Species: Parabacteroides_merdae_56972
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 61, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [122, 366]
# Pairs: [(2, 122, 'MI'), (2, 366, 'MI')]
#
# Subject: 67, Species: Bifidobacterium_longum_57796
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 68, Species: Bacteroides_ovatus_58035
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 68, Species: Bacteroides_fragilis_54507
# Mother: [2]
# Infant: [122, 366]
# Pairs: [(122, 366, 'II'), (2, 122, 'MI'), (2, 366, 'MI')]
#
# Subject: 68, Species: Parabacteroides_distasonis_56985
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 68, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [3, 366]
# Pairs: [(2, 3, 'MI'), (3, 366, 'II'), (2, 366, 'MI')]
#
# Subject: 69, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [3, 366]
# Pairs: [(2, 3, 'MI'), (3, 366, 'II'), (2, 366, 'MI')]
#
# Subject: 515126, Species: Bacteroides_plebeius_61623
# Mother: [1]
# Infant: [4, 7, 10, 11, 21]
# Pairs: [(10, 21, 'II'), (10, 11, 'II'), (7, 21, 'II'), (4, 11, 'II'), (7, 11, 'II'), (1, 11, 'MI'), (7, 10, 'II'), (4, 7, 'II'), (4, 21, 'II'), (1, 7, 'MI'), (1, 10, 'MI'), (1, 21, 'MI'), (1, 4, 'MI'), (4, 10, 'II'), (11, 21, 'II')]
#
# Subject: M0201, Species: Bifidobacterium_longum_57796
# Mother: [-92]
# Infant: [14, 61, 92]
# Pairs: [(14, 61, 'II'), (-92, 92, 'MI'), (61, 92, 'II'), (-92, 14, 'MI'), (14, 92, 'II'), (-92, 61, 'MI')]
#
# Subject: M0201, Species: Bacteroides_uniformis_57318
# Mother: [-92, 92]
# Infant: [61, 92]
# Pairs: [(61, 92, 'II'), (92, 92, 'MI'), (92, 61, 'MI'), (-92, 61, 'MI'), (-92, 92, 'MI')]
#
# Subject: 34, Species: Escherichia_coli_58110
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: M0297, Species: Escherichia_coli_58110
# Mother: [0]
# Infant: [0, 14, 61, 92]
# Pairs: [(0, 14, 'MI'), (14, 61, 'II'), (0, 61, 'MI'), (0, 0, 'MI'), (61, 92, 'II'), (0, 14, 'II'), (0, 92, 'II'), (0, 92, 'MI'), (14, 92, 'II'), (0, 61, 'II')]
#
# Subject: 1, Species: Ruminococcus_bicirculans_59300
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 1, Species: Alistipes_onderdonkii_55464
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 1, Species: Escherichia_coli_58110
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 1, Species: Bacteroides_fragilis_54507
# Mother: [2]
# Infant: [3, 122, 366]
# Pairs: [(2, 3, 'MI'), (122, 366, 'II'), (3, 366, 'II'), (2, 366, 'MI'), (3, 122, 'II'), (2, 122, 'MI')]
#
# Subject: C01994, Species: Bacteroides_fragilis_54507
# Mother: [1]
# Infant: [4, 21, 285]
# Pairs: [(21, 285, 'II'), (4, 285, 'II'), (1, 4, 'MI'), (1, 285, 'MI'), (4, 21, 'II'), (1, 21, 'MI')]
#
# Subject: 4, Species: Bacteroides_cellulosilyticus_58046
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: A00942, Species: Bacteroides_massiliensis_44749
# Mother: [1]
# Infant: [4]
# Pairs: [(1, 4, 'MI')]
#
# Subject: 59, Species: Bifidobacterium_adolescentis_56815
# Mother: [2]
# Infant: [3, 122, 366]
# Pairs: [(2, 3, 'MI'), (122, 366, 'II'), (3, 366, 'II'), (2, 366, 'MI'), (3, 122, 'II'), (2, 122, 'MI')]
#
# Subject: 59, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 58, Species: Bacteroides_caccae_53434
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 55, Species: Bifidobacterium_bifidum_55065
# Mother: [2]
# Infant: [3, 122]
# Pairs: [(3, 122, 'II'), (2, 3, 'MI'), (2, 122, 'MI')]
#
# Subject: 54, Species: Bacteroides_faecis_58503
# Mother: [2]
# Infant: [122, 366]
# Pairs: [(122, 366, 'II'), (2, 122, 'MI'), (2, 366, 'MI')]
#
# Subject: 57, Species: Escherichia_coli_58110
# Mother: [2]
# Infant: [3, 122]
# Pairs: [(3, 122, 'II'), (2, 3, 'MI'), (2, 122, 'MI')]
#
# Subject: 56, Species: Bacteroides_ovatus_58035
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 51, Species: Ruminococcus_bromii_62047
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 50, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 53, Species: Bacteroides_ovatus_58035
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 53, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 53, Species: Parabacteroides_distasonis_56985
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 53, Species: Bacteroides_caccae_53434
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: 53, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [122, 366]
# Pairs: [(122, 366, 'II'), (2, 122, 'MI'), (2, 366, 'MI')]
#
# Subject: 52, Species: Escherichia_coli_58110
# Mother: [2]
# Infant: [3]
# Pairs: [(2, 3, 'MI')]
#
# Subject: B01948, Species: Bacteroides_vulgatus_57955
# Mother: [1]
# Infant: [7]
# Pairs: [(1, 7, 'MI')]
#
# Subject: M0808, Species: Bacteroides_vulgatus_57955
# Mother: [-92, 0, 92]
# Infant: [14, 61]
# Pairs: [(0, 14, 'MI'), (14, 61, 'II'), (92, 61, 'MI'), (0, 61, 'MI'), (-92, 14, 'MI'), (92, 14, 'MI'), (-92, 61, 'MI')]
#
# Subject: BBS0014, Species: Bacteroides_uniformis_57318
# Mother: [1]
# Infant: [11]
# Pairs: [(1, 11, 'MI')]
#
# Subject: M0792, Species: Parabacteroides_merdae_56972
# Mother: [92]
# Infant: [61]
# Pairs: [(92, 61, 'MI')]
#
# Subject: M0792, Species: Parabacteroides_distasonis_56985
# Mother: [92]
# Infant: [14, 30, 61, 92]
# Pairs: [(14, 61, 'II'), (92, 61, 'MI'), (30, 92, 'II'), (92, 14, 'MI'), (61, 92, 'II'), (30, 61, 'II'), (92, 92, 'MI'), (14, 30, 'II'), (14, 92, 'II'), (92, 30, 'MI')]
#
# Subject: M0792, Species: Bacteroides_vulgatus_57955
# Mother: [-92]
# Infant: [92]
# Pairs: [(-92, 92, 'MI')]
#
# Subject: CA_C10023, Species: Bacteroides_uniformis_57318
# Mother: [0]
# Infant: [30]
# Pairs: [(0, 30, 'MI')]
#
# Subject: CA_C10029, Species: Bacteroides_plebeius_61623
# Mother: [0]
# Infant: [7]
# Pairs: [(0, 7, 'MI')]
#
# Subject: CA_C10029, Species: Bacteroides_uniformis_57318
# Mother: [3]
# Infant: [0]
# Pairs: [(3, 0, 'MI')]
#
# Subject: 78, Species: Bacteroides_ovatus_58035
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 78, Species: Sutterella_wadsworthensis_56828
# Mother: [2]
# Infant: [122, 366]
# Pairs: [(2, 122, 'MI'), (122, 366, 'II'), (2, 366, 'MI')]
#
# Subject: 78, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: B01261, Species: Bifidobacterium_longum_57796
# Mother: [1]
# Infant: [4, 7, 21]
# Pairs: [(1, 4, 'MI'), (7, 21, 'II'), (4, 7, 'II'), (4, 21, 'II'), (1, 7, 'MI'), (1, 21, 'MI')]
#
# Subject: C01960, Species: Bifidobacterium_longum_57796
# Mother: [1]
# Infant: [266]
# Pairs: [(1, 266, 'MI')]
#
# Subject: 48, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 48, Species: Eubacterium_eligens_61678
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 48, Species: Bacteroides_cellulosilyticus_58046
# Mother: [2]
# Infant: [366]
# Pairs: [(2, 366, 'MI')]
#
# Subject: 48, Species: Bacteroides_vulgatus_57955
# Mother: [2]
# Infant: [3, 122]
# Pairs: [(3, 122, 'II'), (2, 3, 'MI'), (2, 122, 'MI')]
#
# Subject: 49, Species: Bacteroides_uniformis_57318
# Mother: [2]
# Infant: [122, 366]
# Pairs: [(2, 366, 'MI'), (122, 366, 'II'), (2, 122, 'MI')]
#
# Subject: 44, Species: Bacteroides_caccae_53434
# Mother: [2]
# Infant: [122]
# Pairs: [(2, 122, 'MI')]
#
# Subject: 5, Species: Bacteroides_fragilis_54507
# Mother: [2]
# Infant: [3, 122, 366]
# Pairs: [(3, 122, 'II'), (2, 3, 'MI'), (2, 122, 'MI'), (3, 366, 'II'), (2, 366, 'MI')]

# %%
num_only_infant
# Out:
# 145

# %%
num_host_species_pairs = 0
num_host_species_pairs_by_cohort = defaultdict(int)
num_host_species_pairs_by_species = defaultdict(int)

for subject in host_snp_changes:
    
    # Really hacky way to get cohort of this subject
    for possible_subject in [subject+'IS',subject+'-I',subject+'-C']:
        if possible_subject in subject_sample_map:
            for sample in subject_sample_map[possible_subject]:
                if sample in sample_cohort_map:
                    cohort = sample_cohort_map[sample]
    
    for species in host_snp_changes[subject]:        
        if len(host_snp_changes[subject][species].keys()) > 1:
            
            # Check if there is at least one infant-infant modification for this host
            # AND mother information
            # If not, skip/not interested
            has_modification = False
            has_mother = False
            for day1, day2, tp_type in host_snp_changes[subject][species]:
                val = host_snp_changes[subject][species][(day1, day2, tp_type)]
                if val != 'replacement' and len(val) > 0 and tp_type == 'II':
                    has_modification = True
                if tp_type == 'MI':
                    has_mother = True
            
            if has_modification == False or has_mother == False:
                continue
            
            num_host_species_pairs += 1
            num_host_species_pairs_by_cohort[cohort] += 1
            num_host_species_pairs_by_species[species] += 1
            
            print("Subject: %s, Species: %s" % (subject, species))
            
            for day1, day2, tp_type in sorted(host_snp_changes[subject][species].keys(), key=lambda x: x[0]):
                print('\n%s Day %i to day %i' % (tp_type, day1, day2))
                val = host_snp_changes[subject][species][(day1, day2, tp_type)]
                if val == 'replacement':
                    print("REPLACEMENT")
                elif len(val) == 0:
                    print("NO CHANGE")
                else:
                    snp_change_list = val                    
                    snp_change_freqs_list = host_snp_changes_freqs[subject][species][(day1, day2, tp_type)]
                    for snp_change, x_snp_change_freqs in zip(snp_change_list, snp_change_freqs_list):
                        gene_id, contig, location, vartype, a1, d1, a2, d2 = snp_change
                        vartype2, freq_dict, opp_dict = x_snp_change_freqs
                        if vartype != vartype2:
                            print("Weird")
                        print("Site: %s,%s,%s\t| Vartype: %s" % (gene_id, contig, location, vartype))
                        print("\t%i %i %i %i | %.02f -> %.02f" % (a1, d1, a2, d2, float(a1)/d1, float(a2)/d2))
                        print("\tInfant prev: %.02f | HMP prev: %.02f | Mother prev: %.02f" % (freq_dict['nonpremie'], freq_dict['hmp'], freq_dict['mother']))
            print("\n=============================================================================")
# Out:
# Subject: 98, Species: Parabacteroides_distasonis_56985
#
# MI Day 2 to day 122
# Site: 658663.3.peg.45,ACUD01000001,46292	| Vartype: 1D
# 	0 51 264 264 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 658663.3.peg.4287,ACUD01000012,72506	| Vartype: 2D
# 	3 27 134 134 | 0.11 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 658663.3.peg.2184,ACUD01000004,144184	| Vartype: 1D
# 	0 25 106 106 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# MI Day 2 to day 366
# Site: 658663.3.peg.45,ACUD01000001,46292	| Vartype: 1D
# 	0 51 47 47 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 658663.3.peg.2024,ACUD01000003,296362	| Vartype: 1D
# 	0 49 54 61 | 0.00 -> 0.89
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 658663.3.peg.2311,ACUD01000004,294606	| Vartype: 1D
# 	0 37 33 40 | 0.00 -> 0.82
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 658663.3.peg.4435,ACUD01000013,52774	| Vartype: 1D
# 	0 54 45 56 | 0.00 -> 0.80
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 658663.3.peg.4287,ACUD01000012,72506	| Vartype: 2D
# 	3 27 22 22 | 0.11 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 658663.3.peg.1731,ACUD01000002,1644232	| Vartype: 1D
# 	0 29 18 21 | 0.00 -> 0.86
# 	Infant prev: 0.02 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 658663.3.peg.2184,ACUD01000004,144184	| Vartype: 1D
# 	0 25 20 20 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 658663.3.peg.3032,ACUD01000005,59806	| Vartype: 1D
# 	0 40 40 45 | 0.00 -> 0.89
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# II Day 122 to day 366
# Site: 658663.3.peg.2024,ACUD01000003,296362	| Vartype: 1D
# 	0 284 54 61 | 0.00 -> 0.89
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 658663.3.peg.4435,ACUD01000013,52774	| Vartype: 1D
# 	5 197 45 56 | 0.03 -> 0.80
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 658663.3.peg.3032,ACUD01000005,59806	| Vartype: 1D
# 	0 239 40 45 | 0.00 -> 0.89
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# =============================================================================
# Subject: 94, Species: Bacteroides_vulgatus_57955
#
# MI Day 2 to day 122
# Site: 435590.9.peg.1463,NC_009614,1876991	| Vartype: 2D
# 	33 252 400 400 | 0.13 -> 1.00
# 	Infant prev: 0.01 | HMP prev: 0.01 | Mother prev: 0.02
# Site: 435590.9.peg.2517,NC_009614,3131479	| Vartype: 1D
# 	19 149 193 193 | 0.13 -> 1.00
# 	Infant prev: 0.00 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.546,NC_009614,749817	| Vartype: 4D
# 	22 173 252 252 | 0.13 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.1324,NC_009614,1712073	| Vartype: 1D
# 	30 186 351 351 | 0.16 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.2465,NC_009614,3068361	| Vartype: 1D
# 	40 257 485 485 | 0.16 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# MI Day 2 to day 366
# Site: 435590.9.peg.1463,NC_009614,1876991	| Vartype: 2D
# 	33 252 99 99 | 0.13 -> 1.00
# 	Infant prev: 0.01 | HMP prev: 0.01 | Mother prev: 0.02
# Site: 435590.9.peg.2517,NC_009614,3131479	| Vartype: 1D
# 	19 149 58 58 | 0.13 -> 1.00
# 	Infant prev: 0.00 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.546,NC_009614,749817	| Vartype: 4D
# 	22 173 72 72 | 0.13 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.1324,NC_009614,1712073	| Vartype: 1D
# 	30 186 87 87 | 0.16 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.3058,NC_009614,3760793	| Vartype: 1D
# 	0 129 50 50 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.3988,NC_009614,4789805	| Vartype: 2D
# 	5 82 20 20 | 0.06 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.2465,NC_009614,3068361	| Vartype: 1D
# 	40 257 148 148 | 0.16 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# II Day 122 to day 366
# Site: 435590.9.peg.3058,NC_009614,3760793	| Vartype: 1D
# 	0 195 50 50 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# =============================================================================
# Subject: C02143, Species: Bifidobacterium_bifidum_55065
#
# MI Day 1 to day 237
# Site: 500634.3.peg.1861,AWSW01000054,37945	| Vartype: 1D
# 	0 28 127 145 | 0.00 -> 0.88
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# MI Day 1 to day 7
# Site: 500634.3.peg.945,AWSW01000030,35925	| Vartype: 4D
# 	0 40 50 56 | 0.00 -> 0.89
# 	Infant prev: 0.00 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 500634.3.peg.1636,AWSW01000046,21960	| Vartype: 3D
# 	0 19 32 38 | 0.00 -> 0.84
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 500634.3.peg.875,AWSW01000027,7916	| Vartype: 1D
# 	32 32 1 57 | 1.00 -> 0.02
# 	Infant prev: 1.00 | HMP prev: 1.50 | Mother prev: 0.97
# Site: 500634.3.peg.952,AWSW01000030,45351	| Vartype: 1D
# 	34 34 4 79 | 1.00 -> 0.05
# 	Infant prev: 1.00 | HMP prev: 1.50 | Mother prev: 0.97
# Site: 500634.3.peg.1619,AWSW01000046,4226	| Vartype: 1D
# 	33 33 2 53 | 1.00 -> 0.04
# 	Infant prev: 1.00 | HMP prev: 1.50 | Mother prev: 0.97
#
# II Day 7 to day 237
# Site: 500634.3.peg.875,AWSW01000027,7916	| Vartype: 1D
# 	1 57 125 145 | 0.02 -> 0.86
# 	Infant prev: 0.00 | HMP prev: -0.50 | Mother prev: 0.03
# Site: 500634.3.peg.1861,AWSW01000054,37945	| Vartype: 1D
# 	1 50 127 145 | 0.02 -> 0.88
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 500634.3.peg.952,AWSW01000030,45351	| Vartype: 1D
# 	4 79 152 171 | 0.05 -> 0.89
# 	Infant prev: 0.00 | HMP prev: -0.50 | Mother prev: 0.03
# Site: 500634.3.peg.1619,AWSW01000046,4226	| Vartype: 1D
# 	2 53 115 137 | 0.04 -> 0.84
# 	Infant prev: 0.00 | HMP prev: -0.50 | Mother prev: 0.03
# Site: 500634.3.peg.1636,AWSW01000046,21960	| Vartype: 3D
# 	32 38 14 135 | 0.84 -> 0.10
# 	Infant prev: 1.50 | HMP prev: 1.50 | Mother prev: 1.50
#
# =============================================================================
# Subject: C01840, Species: Bacteroides_vulgatus_57955
#
# MI Day 1 to day 4
# NO CHANGE
#
# MI Day 1 to day 289
# Site: 435590.9.peg.3037,NC_009614,3742405	| Vartype: 1D
# 	0 38 45 53 | 0.00 -> 0.85
# 	Infant prev: 0.31 | HMP prev: 0.43 | Mother prev: 0.22
#
# MI Day 1 to day 7
# NO CHANGE
#
# MI Day 1 to day 21
# NO CHANGE
#
# II Day 4 to day 7
# Site: 435590.9.peg.1813,NC_009614,2242607	| Vartype: 1D
# 	28 155 69 83 | 0.18 -> 0.83
# 	Infant prev: 0.01 | HMP prev: -0.50 | Mother prev: 0.00
# Site: 435590.9.peg.3172,NC_009614,3888045	| Vartype: 1D
# 	20 105 42 48 | 0.19 -> 0.88
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.1932,NC_009614,2435682	| Vartype: 2D
# 	25 147 52 57 | 0.17 -> 0.91
# 	Infant prev: 0.39 | HMP prev: 0.15 | Mother prev: 0.28
#
# II Day 4 to day 21
# Site: 435590.9.peg.1813,NC_009614,2242607	| Vartype: 1D
# 	28 155 31 31 | 0.18 -> 1.00
# 	Infant prev: 0.01 | HMP prev: -0.50 | Mother prev: 0.00
# Site: 435590.9.peg.3172,NC_009614,3888045	| Vartype: 1D
# 	20 105 13 13 | 0.19 -> 1.00
# 	Infant prev: 1.50 | HMP prev: 1.50 | Mother prev: 1.50
# Site: 435590.9.peg.1932,NC_009614,2435682	| Vartype: 2D
# 	25 147 30 30 | 0.17 -> 1.00
# 	Infant prev: 0.39 | HMP prev: 0.15 | Mother prev: 0.28
#
# II Day 4 to day 289
# Site: 435590.9.peg.1813,NC_009614,2242607	| Vartype: 1D
# 	28 155 76 76 | 0.18 -> 1.00
# 	Infant prev: 0.01 | HMP prev: -0.50 | Mother prev: 0.00
# Site: 435590.9.peg.3037,NC_009614,3742405	| Vartype: 1D
# 	0 146 45 53 | 0.00 -> 0.85
# 	Infant prev: 0.31 | HMP prev: 0.43 | Mother prev: 0.22
# Site: 435590.9.peg.3172,NC_009614,3888045	| Vartype: 1D
# 	20 105 57 57 | 0.19 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.1932,NC_009614,2435682	| Vartype: 2D
# 	25 147 51 51 | 0.17 -> 1.00
# 	Infant prev: 0.39 | HMP prev: 0.15 | Mother prev: 0.28
#
# II Day 7 to day 21
# NO CHANGE
#
# II Day 7 to day 289
# Site: 435590.9.peg.3037,NC_009614,3742405	| Vartype: 1D
# 	0 58 45 53 | 0.00 -> 0.85
# 	Infant prev: 0.31 | HMP prev: 0.43 | Mother prev: 0.22
#
# II Day 21 to day 289
# Site: 435590.9.peg.3037,NC_009614,3742405	| Vartype: 1D
# 	0 20 45 53 | 0.00 -> 0.85
# 	Infant prev: 0.31 | HMP prev: 0.43 | Mother prev: 0.22
#
# =============================================================================
# Subject: 20, Species: Bacteroides_vulgatus_57955
#
# MI Day 2 to day 3
# NO CHANGE
#
# MI Day 2 to day 366
# Site: 435590.9.peg.1738,NC_009614,2160159	| Vartype: 2D
# 	0 63 138 138 | 0.00 -> 1.00
# 	Infant prev: 0.13 | HMP prev: 0.14 | Mother prev: 0.12
#
# MI Day 2 to day 122
# Site: 435590.9.peg.1738,NC_009614,2160159	| Vartype: 2D
# 	0 63 42 42 | 0.00 -> 1.00
# 	Infant prev: 0.13 | HMP prev: 0.14 | Mother prev: 0.12
#
# II Day 3 to day 366
# Site: 435590.9.peg.1738,NC_009614,2160159	| Vartype: 2D
# 	0 88 138 138 | 0.00 -> 1.00
# 	Infant prev: 0.13 | HMP prev: 0.14 | Mother prev: 0.12
#
# II Day 3 to day 122
# Site: 435590.9.peg.1738,NC_009614,2160159	| Vartype: 2D
# 	0 88 42 42 | 0.00 -> 1.00
# 	Infant prev: 0.13 | HMP prev: 0.14 | Mother prev: 0.12
# Site: 435590.9.peg.1906,NC_009614,2388971	| Vartype: 4D
# 	53 58 4 28 | 0.91 -> 0.14
# 	Infant prev: 0.79 | HMP prev: 0.77 | Mother prev: 0.71
#
# II Day 122 to day 366
# NO CHANGE
#
# =============================================================================
# Subject: 10, Species: Bacteroides_xylanisolvens_57185
#
# MI Day 2 to day 3
# NO CHANGE
#
# MI Day 2 to day 366
# Site: 556258.5.peg.4082,NZ_EQ973261,14239	| Vartype: 1D
# 	0 25 130 130 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# II Day 3 to day 366
# Site: 556258.5.peg.4082,NZ_EQ973261,14239	| Vartype: 1D
# 	0 95 130 130 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# =============================================================================
# Subject: 1, Species: Bacteroides_fragilis_54507
#
# MI Day 2 to day 3
# NO CHANGE
#
# MI Day 2 to day 366
# NO CHANGE
#
# MI Day 2 to day 122
# Site: 1339327.3.peg.2283,JGDJ01000171,5687	| Vartype: 1D
# 	3 53 373 377 | 0.06 -> 0.99
# 	Infant prev: 0.01 | HMP prev: 0.01 | Mother prev: 0.02
#
# II Day 3 to day 366
# NO CHANGE
#
# II Day 3 to day 122
# Site: 1339327.3.peg.2283,JGDJ01000171,5687	| Vartype: 1D
# 	23 402 373 377 | 0.06 -> 0.99
# 	Infant prev: 0.01 | HMP prev: 0.01 | Mother prev: 0.02
#
# II Day 122 to day 366
# Site: 1339327.3.peg.2283,JGDJ01000171,5687	| Vartype: 1D
# 	373 377 1 19 | 0.99 -> 0.05
# 	Infant prev: 0.99 | HMP prev: 0.99 | Mother prev: 0.98
#
# =============================================================================
# Subject: 59, Species: Bifidobacterium_adolescentis_56815
#
# MI Day 2 to day 3
# REPLACEMENT
#
# MI Day 2 to day 366
# Site: 592977.3.peg.642,JGZQ01000005,14361	| Vartype: 1D
# 	3 38 37 37 | 0.08 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 592977.3.peg.860,JGZQ01000006,69020	| Vartype: 1D
# 	7 44 66 66 | 0.16 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 592977.3.peg.1216,JGZQ01000008,284119	| Vartype: 2D
# 	0 21 46 46 | 0.00 -> 1.00
# 	Infant prev: 0.01 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 592977.3.peg.1129,JGZQ01000008,186577	| Vartype: 4D
# 	23 28 0 38 | 0.82 -> 0.00
# 	Infant prev: 1.00 | HMP prev: 1.50 | Mother prev: 0.99
#
# MI Day 2 to day 122
# Site: 592977.3.peg.39,JGZQ01000001,53358	| Vartype: 1D
# 	0 42 272 288 | 0.00 -> 0.94
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 592977.3.peg.1732,JGZQ01000009,58203	| Vartype: 4D
# 	0 33 186 192 | 0.00 -> 0.97
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# II Day 3 to day 366
# REPLACEMENT
#
# II Day 3 to day 122
# REPLACEMENT
#
# II Day 122 to day 366
# Site: 592977.3.peg.1705,JGZQ01000009,29026	| Vartype: 4D
# 	0 209 58 58 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 592977.3.peg.642,JGZQ01000005,14361	| Vartype: 1D
# 	0 296 37 37 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 592977.3.peg.860,JGZQ01000006,69020	| Vartype: 1D
# 	0 302 66 66 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 592977.3.peg.1216,JGZQ01000008,284119	| Vartype: 2D
# 	0 176 46 46 | 0.00 -> 1.00
# 	Infant prev: 0.01 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 592977.3.peg.39,JGZQ01000001,53358	| Vartype: 1D
# 	272 288 0 46 | 0.94 -> 0.00
# 	Infant prev: 1.50 | HMP prev: 1.50 | Mother prev: 1.50
# Site: 592977.3.peg.1129,JGZQ01000008,186577	| Vartype: 4D
# 	225 230 0 38 | 0.98 -> 0.00
# 	Infant prev: 1.00 | HMP prev: 1.50 | Mother prev: 0.99
# Site: 592977.3.peg.1732,JGZQ01000009,58203	| Vartype: 4D
# 	186 192 0 48 | 0.97 -> 0.00
# 	Infant prev: 1.50 | HMP prev: 1.50 | Mother prev: 1.50
#
# =============================================================================
# Subject: M0808, Species: Bacteroides_vulgatus_57955
#
# MI Day -92 to day 14
# NO CHANGE
#
# MI Day -92 to day 61
# Site: 435590.9.peg.2142,NC_009614,2683430	| Vartype: 2D
# 	1 89 27 28 | 0.01 -> 0.96
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.1738,NC_009614,2159955	| Vartype: 1D
# 	0 84 32 34 | 0.00 -> 0.94
# 	Infant prev: 0.00 | HMP prev: 0.00 | Mother prev: 0.01
# Site: 435590.9.peg.2509,NC_009614,3117210	| Vartype: 4D
# 	0 71 34 37 | 0.00 -> 0.92
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.47,NC_009614,64759	| Vartype: 4D
# 	0 96 46 52 | 0.00 -> 0.88
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.2142,NC_009614,2683119	| Vartype: 4D
# 	55 55 2 21 | 1.00 -> 0.10
# 	Infant prev: 1.00 | HMP prev: 1.50 | Mother prev: 0.99
# Site: 435590.9.peg.2119,NC_009614,2654453	| Vartype: 4D
# 	58 58 1 38 | 1.00 -> 0.03
# 	Infant prev: 0.82 | HMP prev: 0.97 | Mother prev: 0.85
# Site: 435590.9.peg.4057,NC_009614,4863932	| Vartype: 1D
# 	72 72 0 12 | 1.00 -> 0.00
# 	Infant prev: 0.99 | HMP prev: 1.50 | Mother prev: 0.99
#
# MI Day 0 to day 14
# NO CHANGE
#
# MI Day 0 to day 61
# Site: 435590.9.peg.2142,NC_009614,2683430	| Vartype: 2D
# 	0 53 27 28 | 0.00 -> 0.96
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.1738,NC_009614,2159955	| Vartype: 1D
# 	0 47 32 34 | 0.00 -> 0.94
# 	Infant prev: 0.00 | HMP prev: 0.00 | Mother prev: 0.01
# Site: 435590.9.peg.2509,NC_009614,3117210	| Vartype: 4D
# 	1 52 34 37 | 0.02 -> 0.92
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.47,NC_009614,64759	| Vartype: 4D
# 	0 46 46 52 | 0.00 -> 0.88
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.2142,NC_009614,2683119	| Vartype: 4D
# 	50 51 2 21 | 0.98 -> 0.10
# 	Infant prev: 1.00 | HMP prev: 1.50 | Mother prev: 0.99
# Site: 435590.9.peg.2119,NC_009614,2654453	| Vartype: 4D
# 	45 45 1 38 | 1.00 -> 0.03
# 	Infant prev: 0.82 | HMP prev: 0.97 | Mother prev: 0.85
# Site: 435590.9.peg.4057,NC_009614,4863932	| Vartype: 1D
# 	46 46 0 12 | 1.00 -> 0.00
# 	Infant prev: 0.99 | HMP prev: 1.50 | Mother prev: 0.99
#
# II Day 14 to day 61
# Site: 435590.9.peg.2142,NC_009614,2683430	| Vartype: 2D
# 	0 222 27 28 | 0.00 -> 0.96
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.1738,NC_009614,2159955	| Vartype: 1D
# 	0 272 32 34 | 0.00 -> 0.94
# 	Infant prev: 0.00 | HMP prev: 0.00 | Mother prev: 0.01
# Site: 435590.9.peg.2509,NC_009614,3117210	| Vartype: 4D
# 	0 294 34 37 | 0.00 -> 0.92
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.47,NC_009614,64759	| Vartype: 4D
# 	0 400 46 52 | 0.00 -> 0.88
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.2142,NC_009614,2683119	| Vartype: 4D
# 	233 233 2 21 | 1.00 -> 0.10
# 	Infant prev: 1.00 | HMP prev: 1.50 | Mother prev: 0.99
# Site: 435590.9.peg.2119,NC_009614,2654453	| Vartype: 4D
# 	269 270 1 38 | 1.00 -> 0.03
# 	Infant prev: 0.82 | HMP prev: 0.97 | Mother prev: 0.85
# Site: 435590.9.peg.4057,NC_009614,4863932	| Vartype: 1D
# 	213 213 0 12 | 1.00 -> 0.00
# 	Infant prev: 0.99 | HMP prev: 1.50 | Mother prev: 0.99
#
# MI Day 92 to day 61
# Site: 435590.9.peg.2142,NC_009614,2683430	| Vartype: 2D
# 	1 45 27 28 | 0.02 -> 0.96
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.1738,NC_009614,2159955	| Vartype: 1D
# 	1 49 32 34 | 0.02 -> 0.94
# 	Infant prev: 0.00 | HMP prev: 0.00 | Mother prev: 0.01
# Site: 435590.9.peg.2509,NC_009614,3117210	| Vartype: 4D
# 	0 50 34 37 | 0.00 -> 0.92
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 435590.9.peg.47,NC_009614,64759	| Vartype: 4D
# 	5 53 46 52 | 0.09 -> 0.88
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# MI Day 92 to day 14
# NO CHANGE
#
# =============================================================================
# Subject: 5, Species: Bacteroides_fragilis_54507
#
# MI Day 2 to day 3
# Site: 1339327.3.peg.4212,JGDJ01000260,9849	| Vartype: 1D
# 	1 26 385 385 | 0.04 -> 1.00
# 	Infant prev: 0.03 | HMP prev: -0.50 | Mother prev: 0.03
#
# MI Day 2 to day 122
# Site: 1339327.3.peg.4212,JGDJ01000260,9849	| Vartype: 1D
# 	1 26 105 105 | 0.04 -> 1.00
# 	Infant prev: 0.03 | HMP prev: -0.50 | Mother prev: 0.03
# Site: 1339327.3.peg.2899,JGDJ01000204,3609	| Vartype: 4D
# 	0 30 144 144 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
#
# MI Day 2 to day 366
# Site: 1339327.3.peg.4212,JGDJ01000260,9849	| Vartype: 1D
# 	1 26 47 47 | 0.04 -> 1.00
# 	Infant prev: 0.03 | HMP prev: -0.50 | Mother prev: 0.03
# Site: 1339327.3.peg.3412,JGDJ01000232,16279	| Vartype: 1D
# 	0 32 55 55 | 0.00 -> 1.00
# 	Infant prev: 0.01 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 1339327.3.peg.2899,JGDJ01000204,3609	| Vartype: 4D
# 	0 30 34 34 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 1339327.3.peg.3553,JGDJ01000241,5833	| Vartype: 1D
# 	0 44 64 64 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 1339327.3.peg.887,JGDJ01000131,22145	| Vartype: 1D
# 	0 22 52 52 | 0.00 -> 1.00
# 	Infant prev: 0.01 | HMP prev: -0.50 | Mother prev: -0.50
#
# II Day 3 to day 122
# NO CHANGE
#
# II Day 3 to day 366
# Site: 1339327.3.peg.3412,JGDJ01000232,16279	| Vartype: 1D
# 	0 382 55 55 | 0.00 -> 1.00
# 	Infant prev: 0.01 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 1339327.3.peg.3553,JGDJ01000241,5833	| Vartype: 1D
# 	0 367 64 64 | 0.00 -> 1.00
# 	Infant prev: -0.50 | HMP prev: -0.50 | Mother prev: -0.50
# Site: 1339327.3.peg.887,JGDJ01000131,22145	| Vartype: 1D
# 	1 527 52 52 | 0.00 -> 1.00
# 	Infant prev: 0.01 | HMP prev: -0.50 | Mother prev: -0.50
#
# =============================================================================

# %%
print(num_host_species_pairs)
print(num_host_species_pairs_by_cohort)
print(num_host_species_pairs_by_species)
# Out:
# 10
# defaultdict(<type 'int'>, {'yassour': 1, 'shao': 2, 'backhed': 7})
# defaultdict(<type 'int'>, {'Bacteroides_fragilis_54507': 2, 'Bifidobacterium_adolescentis_56815': 1, 'Bacteroides_xylanisolvens_57185': 1, 'Parabacteroides_distasonis_56985': 1, 'Bifidobacterium_bifidum_55065': 1, 'Bacteroides_vulgatus_57955': 4})

# %%
# Parallelism

custom_cohorts_ordered = ['MI', 'Day 0-Week 1', 'Week 1-Month 1', 'Month 1-Year 1', 'II(other)', 'MM', 'AA']
variant_types = ['1D', '2D', '3D', '4D']

def custom_cohort_of_sample_pair(custom_cohort_tests, sample_i, sample_j):
    for cohort in custom_cohort_tests:
        if custom_cohort_tests[cohort](sample_i, sample_j):
            return cohort

custom_cohort_tests = {}
custom_cohort_tests['MI'] = lambda sample_i, sample_j: (sample_i in mother_samples and sample_j in infant_samples_no_olm)
# custom_cohort_tests['MI'] = lambda sample_i, sample_j: ((sample_i in mother_samples and sample_j in infant_samples_no_olm) and mi_sample_day_dict[sample_i] >= 0 and mi_sample_day_dict[sample_j] <= 7)
custom_cohort_tests['Day 0-Week 1'] = lambda sample_i, sample_j: ((sample_i in infant_samples_no_olm and sample_j in infant_samples_no_olm) and (mi_sample_day_dict[sample_i] >= 0 and mi_sample_day_dict[sample_j] <= 7))
custom_cohort_tests['Week 1-Month 1'] = lambda sample_i, sample_j: ((sample_i in infant_samples_no_olm and sample_j in infant_samples_no_olm) and (mi_sample_day_dict[sample_i] >= 7 and mi_sample_day_dict[sample_j] <= 31))
custom_cohort_tests['Month 1-Year 1'] = lambda sample_i, sample_j: ((sample_i in infant_samples_no_olm and sample_j in infant_samples_no_olm) and (mi_sample_day_dict[sample_i] >= 31 and mi_sample_day_dict[sample_j] <= 370))
custom_cohort_tests['II(other)'] = lambda sample_i, sample_j: ((sample_i in infant_samples_no_olm and sample_j in infant_samples_no_olm))
custom_cohort_tests['MM'] = lambda sample_i, sample_j: (sample_i in mother_samples and sample_j in mother_samples)
custom_cohort_tests['AA'] = lambda sample_i, sample_j: (sample_i in hmp_samples and sample_j in hmp_samples)

# cohort -> gene -> variant type -> count of SNP changes
genes_by_cohort = {cohort: {} for cohort in custom_cohorts_ordered}
genes_by_cohort_present_null = {cohort: defaultdict(int) for cohort in custom_cohorts_ordered}
genes_by_cohort_between_null = {cohort: defaultdict(int) for cohort in custom_cohorts_ordered}
genes_by_cohort_pangenome_null = {cohort: defaultdict(int) for cohort in custom_cohorts_ordered}

# cohort -> gene -> count of unique hosts
num_host_genes_by_cohort = {cohort: defaultdict(set) for cohort in custom_cohorts_ordered}

for species in snp_changes_consecutive:
    print("Working on %s...." % species)
    genome_ids = midas_db_utils.get_ref_genome_ids(species)
    # load the gene descriptions for all genomes coresponding to this speceis:
    gene_descriptions=parse_patric.load_patric_gene_descriptions(genome_ids)
    
    for sample_i, sample_j in snp_changes_consecutive[species]:
        val = snp_changes_consecutive[species][(sample_i, sample_j)]
        subject_tuple = (sample_subject_map[sample_i], sample_subject_map[sample_j])
        custom_cohort = custom_cohort_of_sample_pair(custom_cohort_tests, sample_i, sample_j)
        if type(val) == type([]): # not a replacement
            
            # Store actual changed genes
            for gene_id, contig, position, variant_type, A1, D1, A2, D2 in val:
                try:
                    desc = gene_descriptions[gene_id]
                    if desc not in genes_by_cohort[custom_cohort]:
                        genes_by_cohort[custom_cohort][desc] = {vartype: 0 for vartype in variant_types}
                    genes_by_cohort[custom_cohort][desc][variant_type] += 1
                    num_host_genes_by_cohort[custom_cohort][desc].add(subject_tuple)
                except:
                    print("Weird")
                    continue
            
            # Store present gene null
            for gene_id in snp_change_present_gene_null[species][(sample_i, sample_j)]:
                try:
                    desc = gene_descriptions[gene_id]
                    count = snp_change_present_gene_null[species][(sample_i, sample_j)][gene_id]
                    genes_by_cohort_present_null[custom_cohort][desc] += count
                except:
                    print("Weird - present")
                    continue
            
            # Store between host null
            for gene_id in snp_change_between_host_null[species][(sample_i, sample_j)]:
                try:
                    desc = gene_descriptions[gene_id]
                    count = snp_change_between_host_null[species][(sample_i, sample_j)][gene_id]
                    genes_by_cohort_between_null[custom_cohort][desc] += count
                except:
                    print("Weird - between")
                    continue
            
            # Store pangenome null
            for gene_id in snp_change_pangenome_null[species][(sample_i, sample_j)]:
                try:
                    desc = gene_descriptions[gene_id]
                    count = snp_change_pangenome_null[species][(sample_i, sample_j)][gene_id]
                    genes_by_cohort_pangenome_null[custom_cohort][desc] += count
                except:
                    print("Weird - pangenome")
                    continue

# pickle.dump(genes_by_cohort, open('%s/genes_by_cohort.pkl' % config.analysis_directory, 'wb'))
# pickle.dump(num_host_genes_by_cohort, open('%s/num_host_genes_by_cohort.pkl' % config.analysis_directory, 'wb'))
# pickle.dump(genes_by_cohort_present_null, open('%s/genes_by_cohort_present_null.pkl' % config.analysis_directory, 'wb'))
# pickle.dump(genes_by_cohort_between_null, open('%s/genes_by_cohort_between_null.pkl' % config.analysis_directory, 'wb'))
# pickle.dump(genes_by_cohort_pangenome_null, open('%s/genes_by_cohort_pangenome_null.pkl' % config.analysis_directory, 'wb'))
# Out:
# Working on Lactobacillus_paracasei_55666....
# Working on Leclercia_adecarboxylata_62497....
# Working on Bacteroides_sartorii_54642....
# Working on Megamonas_hypermegale_57114....
# Working on Bacteroides_intestinalis_61596....
# Weird - present
# Working on Bacteroides_uniformis_57318....
# Weird - pangenome
# Weird - present
# Weird - present
# Working on Bifidobacterium_bifidum_55065....
# Working on Clostridium_bolteae_57158....
# Working on Streptococcus_gallolyticus_57748....
# Working on Clostridium_paraputrificum_59909....
# Working on Subdoligranulum_sp_62068....
# Working on Enterococcus_faecium_56710....
# Working on Streptococcus_lutetiensis_58501....
# Working on Phascolarctobacterium_succinatutens_61948....
# Working on Faecalibacterium_prausnitzii_62201....
# Working on Faecalibacterium_prausnitzii_61481....
# Working on Streptococcus_anginosus_58223....
# Working on Blautia_wexlerae_56130....
# Working on Dorea_longicatena_61473....
# Working on Staphylococcus_warneri_58053....
# Working on Enterococcus_faecalis_55915....
# Working on Streptococcus_salivarius_58037....
# Working on Alistipes_indistinctus_62207....
# Working on Clostridiales_bacterium_52743....
# Working on Streptococcus_thermophilus_54772....
# Working on Clostridium_butyricum_56361....
# Working on Oscillibacter_sp_60799....
# Working on Erysipelotrichaceae_bacterium_56596....
# Working on Ruminococcus_torques_62045....
# Working on Roseburia_intestinalis_56239....
# Working on Lactobacillus_gasseri_55553....
# Working on Clostridiales_bacterium_56470....
# Working on Lachnospiraceae_bacterium_51870....
# Working on Collinsella_aerofaciens_61484....
# Working on Bacteroides_stercoris_56735....
# Working on Bifidobacterium_scardovii_44511....
# Working on Staphylococcus_aureus_56630....
# Working on Propionibacterium_acnes_57367....
# Working on Bacteroides_clarus_62282....
# Working on Barnesiella_intestinihominis_62208....
# Working on Enterobacter_asburiae_58142....
# Working on Morganella_morganii_57363....
# Working on Oscillospiraceae_bacterium_54867....
# Working on Bacteroides_eggerthii_54457....
# Working on Ruminococcus_obeum_61472....
# Working on Eggerthella_lenta_56463....
# Working on Klebsiella_oxytoca_57801....
# Working on Bifidobacterium_longum_57796....
# Working on Collinsella_sp_62205....
# Working on Acidaminococcus_intestini_54097....
# Working on Lactobacillus_rhamnosus_57549....
# Working on Veillonella_atypica_58169....
# Working on Bacteroides_faecis_58503....
# Working on Eubacterium_rectale_56927....
# Working on Bacteroides_acidifaciens_59693....
# Working on Clostridium_sordellii_57678....
# Working on Anaerostipes_hadrus_55206....
# Working on Pantoea_sp_58264....
# Working on Clostridium_difficile_57608....
# Working on Ruminococcus_sp_55468....
# Working on Klebsiella_oxytoca_54123....
# Working on Alistipes_putredinis_61533....
# Weird - present
# Weird - present
# Working on Enterobacter_asburiae_57214....
# Working on Eubacterium_hallii_61477....
# Working on Citrobacter_freundii_56776....
# Working on Bacteroides_coprocola_61586....
# Working on Enterococcus_avium_44557....
# Working on Citrobacter_koseri_61132....
# Working on Burkholderiales_bacterium_56577....
# Working on Ruminococcus_bromii_62047....
# Working on Klebsiella_oxytoca_56762....
# Working on Enterococcus_faecalis_56297....
# Working on Bifidobacterium_adolescentis_56815....
# Working on Bacteroides_plebeius_61623....
# Working on Bacteroides_thetaiotaomicron_56941....
# Working on Bacteroides_ovatus_58035....
# Working on Paraprevotella_xylaniphila_62280....
# Working on Odoribacter_splanchnicus_62174....
# Working on Streptococcus_parasanguinis_58487....
# Working on Bacteroides_cellulosilyticus_58046....
# Working on Enterobacter_cloacae_57303....
# Working on Klebsiella_pneumoniae_54788....
# Working on Propionibacterium_avidum_56659....
# Working on Alistipes_sp_59510....
# Working on Finegoldia_magna_57293....
# Working on Veillonella_dispar_61763....
# Working on Escherichia_coli_58110....
# Working on Prevotella_buccae_56058....
# Working on Clostridium_sp_61556....
# Working on Clostridium_hathewayi_61827....
# Working on Propionibacterium_sp_59451....
# Working on Peptostreptococcus_anaerobius_55004....
# Working on Hafnia_alvei_56921....
# Working on Lactobacillus_crispatus_56887....
# Working on Enterobacter_cloacae_60571....
# Working on Clostridium_nexile_61654....
# Working on Bifidobacterium_dentium_55719....
# Working on Enterococcus_casseliflavus_56514....
# Working on Streptococcus_parasanguinis_62481....
# Working on Bifidobacterium_breve_57133....
# Working on Dialister_invisus_61905....
# Working on Veillonella_sp_62404....
# Working on Odoribacter_laneus_62216....
# Working on Bacteroides_caccae_53434....
# Working on Alistipes_shahii_62199....
# Working on Parabacteroides_johnsonii_55217....
# Working on Streptococcus_agalactiae_55593....
# Working on Streptococcus_salivarius_58024....
# Working on Roseburia_inulinivorans_61943....
# Working on Bacteroides_xylanisolvens_57185....
# Working on Veillonella_parvula_58184....
# Working on Haemophilus_parainfluenzae_57123....
# Working on Haemophilus_parainfluenzae_62356....
# Working on Enterococcus_gallinarum_52312....
# Working on Negativicoccus_succinicivorans_57482....
# Working on Ruminococcus_gnavus_57638....
# Working on Ruminococcus_lactaris_55568....
# Working on Akkermansia_muciniphila_55290....
# Working on Clostridium_perfringens_56840....
# Working on Peptoniphilus_rhinitidis_62391....
# Working on Bifidobacterium_pseudocatenulatum_57754....
# Weird - present
# Weird - pangenome
# Weird - pangenome
# Working on Paraprevotella_clara_33712....
# Working on Clostridium_hathewayi_55515....
# Working on Proteus_mirabilis_55046....
# Working on Escherichia_coli_57907....
# Working on Escherichia_coli_53492....
# Working on Butyrivibrio_crossotus_61674....
# Working on Bacteroidales_bacterium_58650....
# Working on Staphylococcus_haemolyticus_57278....
# Working on Faecalibacterium_prausnitzii_57453....
# Working on Klebsiella_pneumoniae_54688....
# Working on Enterobacter_hormaechei_50416....
# Working on Roseburia_hominis_61877....
# Working on Lactobacillus_gasseri_55805....
# Working on Staphylococcus_sp_59500....
# Working on Coprococcus_sp_62244....
# Working on Clostridium_sp_60465....
# Working on Haemophilus_parainfluenzae_62468....
# Working on Eubacterium_eligens_61678....
# Working on Neisseria_subflava_61760....
# Working on Alistipes_finegoldii_56071....
# Working on Clostridium_sp_61482....
# Working on Alistipes_sp_60764....
# Working on Veillonella_ratti_62429....
# Working on Clostridium_sp_57418....
# Working on Eubacterium_siraeum_57634....
# Weird - present
# Weird - pangenome
# Working on Faecalibacterium_cf_62236....
# Working on Alistipes_onderdonkii_55464....
# Working on Escherichia_albertii_56276....
# Working on Actinomyces_urogenitalis_53864....
# Working on Bacteroides_salyersiae_54873....
# Working on Corynebacterium_sp_48834....
# Working on Serratia_marcescens_58205....
# Working on Streptococcus_vestibularis_56030....
# Working on Guyana_massiliensis_60772....
# Working on Coprococcus_comes_61587....
# Working on Enterococcus_faecium_56947....
# Working on Butyricimonas_virosa_58742....
# Working on Enterobacter_cloacae_58148....
# Working on Clostridium_bartlettii_61535....
# Working on Ruminococcus_bicirculans_59300....
# Working on Raoultella_planticola_57814....
# Weird - pangenome
# Working on Pseudomonas_aeruginosa_57148....
# Working on Lactobacillus_fermentum_54035....
# Working on Lactobacillus_plantarum_54610....
# Working on Parabacteroides_goldsteinii_56831....
# Working on Rothia_mucilaginosa_58144....
# Working on Eubacterium_biforme_61684....
# Working on Serratia_liquefaciens_58210....
# Working on Clostridium_baratii_60475....
# Working on Bacteroides_fragilis_56548....
# Working on Citrobacter_freundii_56148....
# Working on Clostridiales_bacterium_59663....
# Working on Staphylococcus_epidermidis_57523....
# Working on Bacteroides_vulgatus_57955....
# Working on Klebsiella_pneumoniae_57337....
# Working on Phascolarctobacterium_sp_59817....
# Working on Prevotella_melaninogenica_58075....
# Working on Bacteroides_fragilis_54507....
# Weird - present
# Weird - between
# Working on Bifidobacterium_animalis_58116....
# Working on Prevotella_copri_61740....
# Working on Staphylococcus_hominis_57055....
# Working on Enterococcus_hirae_55131....
# Working on Enterobacter_aerogenes_55704....
# Working on Bacteroides_massiliensis_44749....
# Working on Streptococcus_salivarius_58022....
# Working on Sutterella_wadsworthensis_56828....
# Working on Streptococcus_sp_60086....
# Working on Escherichia_hermannii_58626....
# Working on Bifidobacterium_catenulatum_58257....
# Working on Rothia_mucilaginosa_62109....
# Working on Varibaculum_cambriense_60384....
# Working on Bacteroides_finegoldii_57739....
# Working on Parabacteroides_merdae_56972....
# Working on Bradyrhizobium_sp_61126....
# Working on Enterobacter_cloacae_55612....
# Working on Streptococcus_parasanguinis_62442....
# Working on Bacteroides_coprophilus_61767....
# Working on Enterococcus_durans_52177....
# Working on Veillonella_sp_62611....
# Working on Pantoea_sp_60700....
# Working on Citrobacter_braakii_56022....
# Working on Eubacterium_ventriosum_61474....
# Working on Finegoldia_magna_61710....
# Working on Coprobacter_fastidiosus_56550....
# Working on Streptococcus_parasanguinis_58126....
# Working on Bacteroides_nordii_55557....
# Working on Streptococcus_sp_62701....
# Working on Enterobacter_sp_59869....
# Working on Enterobacter_cloacae_55011....
# Working on Veillonella_parvula_57794....
# Working on Staphylococcus_lugdunensis_54043....
# Working on Sutterella_wadsworthensis_62218....
# Working on Clostridium_leptum_61499....
# Working on Parabacteroides_distasonis_56985....
# Working on Actinomyces_sp_62581....
# Working on Anaerococcus_obesiensis_58051....

# %%
pickle.dump(genes_by_cohort, open('%s/genes_by_cohort_with_vartype.pkl' % config.analysis_directory, 'wb'))

# %%
genes_by_cohort = pickle.load(open('%s/genes_by_cohort.pkl' % config.analysis_directory, 'rb'))
num_host_genes_by_cohort = pickle.load(open('%s/num_host_genes_by_cohort.pkl' % config.analysis_directory, 'rb'))
genes_by_cohort_present_null = pickle.load(open('%s/genes_by_cohort_present_null.pkl' % config.analysis_directory, 'rb'))
genes_by_cohort_between_null = pickle.load(open('%s/genes_by_cohort_between_null.pkl' % config.analysis_directory, 'rb'))
genes_by_cohort_pangenome_null = pickle.load(open('%s/genes_by_cohort_pangenome_null.pkl' % config.analysis_directory, 'rb'))

# %%
for cat in custom_cohorts_ordered:
    f = open('%s/%s_snp_change_gene_annotation_v2.tsv' % (config.analysis_directory, cat.replace(' ', '_')), 'w')
    f.write('\t'.join(['count', 'count_by_vartype', 'num_unique_hosts', 'present_null', 'between_null', 'pangenome_null', 'gene']) + '\n')
    for gene, count_dict in sorted(genes_by_cohort[cat].items(), key=lambda x: sum(x[1].values()), reverse=True):
        total_count = sum(count_dict.values())
        vartype_str = '|'.join([str(genes_by_cohort[cat][gene][vt]) for vt in variant_types])
        present_null_count = genes_by_cohort_present_null[cat][gene]
        between_null_count = genes_by_cohort_between_null[cat][gene]
        pangenome_null_count = genes_by_cohort_pangenome_null[cat][gene]
        num_unique_hosts = len(num_host_genes_by_cohort[cat][gene])
        if num_unique_hosts > total_count:
            print("Huh???")
            print(gene)
        f.write('\t'.join([str(x) for x in [total_count, vartype_str, num_unique_hosts, present_null_count, between_null_count, pangenome_null_count, gene]]) + '\n')
    f.close()

# %%
genes_by_cohort['AA']['1,4-alpha-glucan (glycogen) branching enzyme, GH-13-type (EC 2.4.1.18)']
# Out:
# {'1D': 0, '2D': 1, '3D': 0, '4D': 0}

# %%
# Parallelism - ok just make one big II category

custom_cohorts_ordered = ['II']
variant_types = ['1D', '2D', '3D', '4D']

def custom_cohort_of_sample_pair(custom_cohort_tests, sample_i, sample_j):
    for cohort in custom_cohort_tests:
        if custom_cohort_tests[cohort](sample_i, sample_j):
            return cohort

custom_cohort_tests = {}
custom_cohort_tests['II'] = lambda sample_i, sample_j: ((sample_i in infant_samples_no_olm and sample_j in infant_samples_no_olm))

# cohort -> gene -> variant type -> count of SNP changes
genes_by_cohort = {cohort: {} for cohort in custom_cohorts_ordered}
genes_by_cohort_present_null = {cohort: defaultdict(int) for cohort in custom_cohorts_ordered}
genes_by_cohort_between_null = {cohort: defaultdict(int) for cohort in custom_cohorts_ordered}
genes_by_cohort_pangenome_null = {cohort: defaultdict(int) for cohort in custom_cohorts_ordered}

# cohort -> gene -> count of unique hosts
num_host_genes_by_cohort = {cohort: defaultdict(set) for cohort in custom_cohorts_ordered}

for species in snp_changes_consecutive:
    print("Working on %s...." % species)
    genome_ids = midas_db_utils.get_ref_genome_ids(species)
    # load the gene descriptions for all genomes coresponding to this speceis:
    gene_descriptions=parse_patric.load_patric_gene_descriptions(genome_ids)
    
    for sample_i, sample_j in snp_changes_consecutive[species]:
        val = snp_changes_consecutive[species][(sample_i, sample_j)]
        subject_tuple = (sample_subject_map[sample_i], sample_subject_map[sample_j])
        if not ((sample_i in infant_samples_no_olm and sample_j in infant_samples_no_olm)):
            continue
        else:
            custom_cohort = 'II'
        if type(val) == type([]): # not a replacement
            
            # Store actual changed genes
            for gene_id, contig, position, variant_type, A1, D1, A2, D2 in val:
                try:
                    desc = gene_descriptions[gene_id]
                    if desc not in genes_by_cohort[custom_cohort]:
                        genes_by_cohort[custom_cohort][desc] = {vartype: 0 for vartype in variant_types}
                    genes_by_cohort[custom_cohort][desc][variant_type] += 1
                    num_host_genes_by_cohort[custom_cohort][desc].add(subject_tuple)
                except:
                    print("Weird")
                    continue
            
            # Store present gene null
            for gene_id in snp_change_present_gene_null[species][(sample_i, sample_j)]:
                try:
                    desc = gene_descriptions[gene_id]
                    count = snp_change_present_gene_null[species][(sample_i, sample_j)][gene_id]
                    genes_by_cohort_present_null[custom_cohort][desc] += count
                except:
                    print("Weird - present")
                    continue
            
            # Store between host null
            for gene_id in snp_change_between_host_null[species][(sample_i, sample_j)]:
                try:
                    desc = gene_descriptions[gene_id]
                    count = snp_change_between_host_null[species][(sample_i, sample_j)][gene_id]
                    genes_by_cohort_between_null[custom_cohort][desc] += count
                except:
                    print("Weird - between")
                    continue
            
            # Store pangenome null
            for gene_id in snp_change_pangenome_null[species][(sample_i, sample_j)]:
                try:
                    desc = gene_descriptions[gene_id]
                    count = snp_change_pangenome_null[species][(sample_i, sample_j)][gene_id]
                    genes_by_cohort_pangenome_null[custom_cohort][desc] += count
                except:
                    print("Weird - pangenome")
                    continue
# Out:
# Working on Lactobacillus_paracasei_55666....
# Working on Leclercia_adecarboxylata_62497....
# Working on Bacteroides_sartorii_54642....
# Working on Megamonas_hypermegale_57114....
# Working on Bacteroides_intestinalis_61596....
# Working on Bacteroides_uniformis_57318....
# Weird - pangenome
# Working on Bifidobacterium_bifidum_55065....
# Working on Clostridium_bolteae_57158....
# Working on Streptococcus_gallolyticus_57748....
# Working on Clostridium_paraputrificum_59909....
# Working on Subdoligranulum_sp_62068....
# Working on Enterococcus_faecium_56710....
# Working on Streptococcus_lutetiensis_58501....
# Working on Phascolarctobacterium_succinatutens_61948....
# Working on Faecalibacterium_prausnitzii_62201....
# Working on Faecalibacterium_prausnitzii_61481....
# Working on Streptococcus_anginosus_58223....
# Working on Blautia_wexlerae_56130....
# Working on Dorea_longicatena_61473....
# Working on Staphylococcus_warneri_58053....
# Working on Enterococcus_faecalis_55915....
# Working on Streptococcus_salivarius_58037....
# Working on Alistipes_indistinctus_62207....
# Working on Clostridiales_bacterium_52743....
# Working on Streptococcus_thermophilus_54772....
# Working on Clostridium_butyricum_56361....
# Working on Oscillibacter_sp_60799....
# Working on Erysipelotrichaceae_bacterium_56596....
# Working on Ruminococcus_torques_62045....
# Working on Roseburia_intestinalis_56239....
# Working on Lactobacillus_gasseri_55553....
# Working on Clostridiales_bacterium_56470....
# Working on Lachnospiraceae_bacterium_51870....
# Working on Collinsella_aerofaciens_61484....
# Working on Bacteroides_stercoris_56735....
# Working on Bifidobacterium_scardovii_44511....
# Working on Staphylococcus_aureus_56630....
# Working on Propionibacterium_acnes_57367....
# Working on Bacteroides_clarus_62282....
# Working on Barnesiella_intestinihominis_62208....
# Working on Enterobacter_asburiae_58142....
# Working on Morganella_morganii_57363....
# Working on Oscillospiraceae_bacterium_54867....
# Working on Bacteroides_eggerthii_54457....
# Working on Ruminococcus_obeum_61472....
# Working on Eggerthella_lenta_56463....
# Working on Klebsiella_oxytoca_57801....
# Working on Bifidobacterium_longum_57796....
# Working on Collinsella_sp_62205....
# Working on Acidaminococcus_intestini_54097....
# Working on Lactobacillus_rhamnosus_57549....
# Working on Veillonella_atypica_58169....
# Working on Bacteroides_faecis_58503....
# Working on Eubacterium_rectale_56927....
# Working on Bacteroides_acidifaciens_59693....
# Working on Clostridium_sordellii_57678....
# Working on Anaerostipes_hadrus_55206....
# Working on Pantoea_sp_58264....
# Working on Clostridium_difficile_57608....
# Working on Ruminococcus_sp_55468....
# Working on Klebsiella_oxytoca_54123....
# Working on Alistipes_putredinis_61533....
# Working on Enterobacter_asburiae_57214....
# Working on Eubacterium_hallii_61477....
# Working on Citrobacter_freundii_56776....
# Working on Bacteroides_coprocola_61586....
# Working on Enterococcus_avium_44557....
# Working on Citrobacter_koseri_61132....
# Working on Burkholderiales_bacterium_56577....
# Working on Ruminococcus_bromii_62047....
# Working on Klebsiella_oxytoca_56762....
# Working on Enterococcus_faecalis_56297....
# Working on Bifidobacterium_adolescentis_56815....
# Working on Bacteroides_plebeius_61623....
# Working on Bacteroides_thetaiotaomicron_56941....
# Working on Bacteroides_ovatus_58035....
# Working on Paraprevotella_xylaniphila_62280....
# Working on Odoribacter_splanchnicus_62174....
# Working on Streptococcus_parasanguinis_58487....
# Working on Bacteroides_cellulosilyticus_58046....
# Working on Enterobacter_cloacae_57303....
# Working on Klebsiella_pneumoniae_54788....
# Working on Propionibacterium_avidum_56659....
# Working on Alistipes_sp_59510....
# Working on Finegoldia_magna_57293....
# Working on Veillonella_dispar_61763....
# Working on Escherichia_coli_58110....
# Working on Prevotella_buccae_56058....
# Working on Clostridium_sp_61556....
# Working on Clostridium_hathewayi_61827....
# Working on Propionibacterium_sp_59451....
# Working on Peptostreptococcus_anaerobius_55004....
# Working on Hafnia_alvei_56921....
# Working on Lactobacillus_crispatus_56887....
# Working on Enterobacter_cloacae_60571....
# Working on Clostridium_nexile_61654....
# Working on Bifidobacterium_dentium_55719....
# Working on Enterococcus_casseliflavus_56514....
# Working on Streptococcus_parasanguinis_62481....
# Working on Bifidobacterium_breve_57133....
# Working on Dialister_invisus_61905....
# Working on Veillonella_sp_62404....
# Working on Odoribacter_laneus_62216....
# Working on Bacteroides_caccae_53434....
# Working on Alistipes_shahii_62199....
# Working on Parabacteroides_johnsonii_55217....
# Working on Streptococcus_agalactiae_55593....
# Working on Streptococcus_salivarius_58024....
# Working on Roseburia_inulinivorans_61943....
# Working on Bacteroides_xylanisolvens_57185....
# Working on Veillonella_parvula_58184....
# Working on Haemophilus_parainfluenzae_57123....
# Working on Haemophilus_parainfluenzae_62356....
# Working on Enterococcus_gallinarum_52312....
# Working on Negativicoccus_succinicivorans_57482....
# Working on Ruminococcus_gnavus_57638....
# Working on Ruminococcus_lactaris_55568....
# Working on Akkermansia_muciniphila_55290....
# Working on Clostridium_perfringens_56840....
# Working on Peptoniphilus_rhinitidis_62391....
# Working on Bifidobacterium_pseudocatenulatum_57754....
# Weird - present
# Weird - pangenome
# Weird - pangenome
# Working on Paraprevotella_clara_33712....
# Working on Clostridium_hathewayi_55515....
# Working on Proteus_mirabilis_55046....
# Working on Escherichia_coli_57907....
# Working on Escherichia_coli_53492....
# Working on Butyrivibrio_crossotus_61674....
# Working on Bacteroidales_bacterium_58650....
# Working on Staphylococcus_haemolyticus_57278....
# Working on Faecalibacterium_prausnitzii_57453....
# Working on Klebsiella_pneumoniae_54688....
# Working on Enterobacter_hormaechei_50416....
# Working on Roseburia_hominis_61877....
# Working on Lactobacillus_gasseri_55805....
# Working on Staphylococcus_sp_59500....
# Working on Coprococcus_sp_62244....
# Working on Clostridium_sp_60465....
# Working on Haemophilus_parainfluenzae_62468....
# Working on Eubacterium_eligens_61678....
# Working on Neisseria_subflava_61760....
# Working on Alistipes_finegoldii_56071....
# Working on Clostridium_sp_61482....
# Working on Alistipes_sp_60764....
# Working on Veillonella_ratti_62429....
# Working on Clostridium_sp_57418....
# Working on Eubacterium_siraeum_57634....
# Working on Faecalibacterium_cf_62236....
# Working on Alistipes_onderdonkii_55464....
# Working on Escherichia_albertii_56276....
# Working on Actinomyces_urogenitalis_53864....
# Working on Bacteroides_salyersiae_54873....
# Working on Corynebacterium_sp_48834....
# Working on Serratia_marcescens_58205....
# Working on Streptococcus_vestibularis_56030....
# Working on Guyana_massiliensis_60772....
# Working on Coprococcus_comes_61587....
# Working on Enterococcus_faecium_56947....
# Working on Butyricimonas_virosa_58742....
# Working on Enterobacter_cloacae_58148....
# Working on Clostridium_bartlettii_61535....
# Working on Ruminococcus_bicirculans_59300....
# Working on Raoultella_planticola_57814....
# Weird - pangenome
# Working on Pseudomonas_aeruginosa_57148....
# Working on Lactobacillus_fermentum_54035....
# Working on Lactobacillus_plantarum_54610....
# Working on Parabacteroides_goldsteinii_56831....
# Working on Rothia_mucilaginosa_58144....
# Working on Eubacterium_biforme_61684....
# Working on Serratia_liquefaciens_58210....
# Working on Clostridium_baratii_60475....
# Working on Bacteroides_fragilis_56548....
# Working on Citrobacter_freundii_56148....
# Working on Clostridiales_bacterium_59663....
# Working on Staphylococcus_epidermidis_57523....
# Working on Bacteroides_vulgatus_57955....
# Working on Klebsiella_pneumoniae_57337....
# Working on Phascolarctobacterium_sp_59817....
# Working on Prevotella_melaninogenica_58075....
# Working on Bacteroides_fragilis_54507....
# Weird - present
# Working on Bifidobacterium_animalis_58116....
# Working on Prevotella_copri_61740....
# Working on Staphylococcus_hominis_57055....
# Working on Enterococcus_hirae_55131....
# Working on Enterobacter_aerogenes_55704....
# Working on Bacteroides_massiliensis_44749....
# Working on Streptococcus_salivarius_58022....
# Working on Sutterella_wadsworthensis_56828....
# Working on Streptococcus_sp_60086....
# Working on Escherichia_hermannii_58626....
# Working on Bifidobacterium_catenulatum_58257....
# Working on Rothia_mucilaginosa_62109....
# Working on Varibaculum_cambriense_60384....
# Working on Bacteroides_finegoldii_57739....
# Working on Parabacteroides_merdae_56972....
# Working on Bradyrhizobium_sp_61126....
# Working on Enterobacter_cloacae_55612....
# Working on Streptococcus_parasanguinis_62442....
# Working on Bacteroides_coprophilus_61767....
# Working on Enterococcus_durans_52177....
# Working on Veillonella_sp_62611....
# Working on Pantoea_sp_60700....
# Working on Citrobacter_braakii_56022....
# Working on Eubacterium_ventriosum_61474....
# Working on Finegoldia_magna_61710....
# Working on Coprobacter_fastidiosus_56550....
# Working on Streptococcus_parasanguinis_58126....
# Working on Bacteroides_nordii_55557....
# Working on Streptococcus_sp_62701....
# Working on Enterobacter_sp_59869....
# Working on Enterobacter_cloacae_55011....
# Working on Veillonella_parvula_57794....
# Working on Staphylococcus_lugdunensis_54043....
# Working on Sutterella_wadsworthensis_62218....
# Working on Clostridium_leptum_61499....
# Working on Parabacteroides_distasonis_56985....
# Working on Actinomyces_sp_62581....
# Working on Anaerococcus_obesiensis_58051....

# %%
genes_by_cohort = pickle.load(open('%s/genes_by_cohort_with_vartype.pkl' % config.analysis_directory, 'rb'))

# %%
# Also include number of unique hosts
    
for cat in custom_cohorts_ordered:
    f = open('%s/%s_snp_change_gene_annotation_v2.tsv' % (config.analysis_directory, cat.replace(' ', '_')), 'w')
    f.write('\t'.join(['count', 'count_by_vartype', 'num_unique_hosts', 'present_null', 'between_null', 'pangenome_null', 'gene']) + '\n')
    for gene, count_dict in sorted(genes_by_cohort[cat].items(), key=lambda x: sum(x[1].values()), reverse=True):
        total_count = sum(count_dict.values())
        vartype_str = '|'.join([str(genes_by_cohort[cat][gene][vt]) for vt in variant_types])
        present_null_count = genes_by_cohort_present_null[cat][gene]
        between_null_count = genes_by_cohort_between_null[cat][gene]
        pangenome_null_count = genes_by_cohort_pangenome_null[cat][gene]
        num_unique_hosts = len(num_host_genes_by_cohort[cat][gene])
        if num_unique_hosts > total_count:
            print("Huh???")
            print(gene)
        f.write('\t'.join([str(x) for x in [total_count, vartype_str, num_unique_hosts, present_null_count, between_null_count, pangenome_null_count, gene]]) + '\n')
    f.close()

# %%
# Here's what imma plot:
# For every gene that changes in at least two unique hosts in infants,
# and which changes a greater number of times than all three null expectations,
# get proportion increase in occurrence from present null as
# (actual - present_null) / (present_null)
# and order by proportion increase..?

gene_prop_increase = {}

for gene, count in genes_by_cohort[cat].items():
    present_null_count = genes_by_cohort_present_null[cat][gene]
    between_null_count = genes_by_cohort_between_null[cat][gene]
    pangenome_null_count = genes_by_cohort_pangenome_null[cat][gene]
    num_unique_hosts = len(num_host_genes_by_cohort[cat][gene])
    if num_unique_hosts >= 2 and count > present_null_count and count > between_null_count and count > pangenome_null_count:
        gene_prop_increase[gene] = float(count - present_null_count)/float(present_null_count)

# %%
for gene, prop_increase in sorted(gene_prop_increase.items(), key=lambda x: x[1], reverse=True):
    print(gene)
    present_null_count = genes_by_cohort_present_null[cat][gene]
    count = genes_by_cohort[cat][gene]
    print('Present null: %.02f\t| Actual: %i\t| Num hosts: %i\t| Increase: %.02fx' % (present_null_count, count, prop_increase) + '\n')
