# %%
# Basically replicate pickle_everything but track info about how many QP pairs are considered

# %%
from utils import sample_utils as su, parse_midas_data, substitution_rates_utils, config, temporal_changes_utils, snps_utils, core_gene_utils, gene_diversity_utils
import numpy as np
from numpy.random import choice, random as np_random, randint
import random
from collections import defaultdict
import pickle
import os, sys

# ======================================================
# Examines all consecutive timepoint pairs within hosts
# across all cohorts, and pickles SNP/gene change info
# ======================================================

# Parameters
sweep_type = 'full' # assume full for now
pp_prev_cohort = 'all'
min_coverage = 0
thresholds = {'full': (0.2, 0.8), 'partial': (0.35, 0.65)}
lower_threshold, upper_threshold = thresholds[sweep_type]

clade_divergence_threshold = 3e-02 # TODO: change to top level clade definition later

min_sample_size = 3
variant_types = ['1D','4D']
within_host_type = 'nonconsecutive' # consecutive timepoints
min_snp_change_sample_size = 5

# For partitioning SNVs according to prevalence
derived_freq_bins = np.array([-1,0,0.01,0.1,0.5,0.9,0.99,1,2])
derived_virtual_freqs = np.arange(0,len(derived_freq_bins)-1)
derived_virtual_xticks = list(derived_virtual_freqs[:-1]+0.5)
derived_virtual_xticklabels = ['0','.01','.1','.5','.9','.99','1']

# For partitioning genes into different prevalence classes
gene_freq_bins = np.array([-1,0.1,0.5,0.9,2])
gene_freq_xticks			= [-4, -3,	-2,		-1,		0,	 1,		 2,		3, 4]
gene_freq_xticklabels = ['0','0.1','0.5', '0.9','1','0.9','0.5', '0.1','0']
gene_gain_virtual_freqs = np.array([3.5,2.5,1.5,0.5])
gene_loss_virtual_freqs = np.array([-3.5,-2.5,-1.5,-0.5])

# Sample-subject-order maps
sys.stderr.write("Loading sample metadata...\n")
subject_sample_map = su.parse_subject_sample_map()
sample_order_map = su.parse_sample_order_map()
sample_subject_map = su.parse_sample_subject_map()
sys.stderr.write("Done!\n")

# Timepoint pair types
tp_pair_names = ['MM', 'MI', 'II', 'AA']

# Cohorts
cohorts = ['backhed', 'ferretti', 'yassour', 'shao', 'hmp']
mi_cohorts = ['backhed', 'ferretti', 'yassour', 'shao']

# Prevalence cohorts
prev_cohorts = ['all', 'hmp', 'infant', 'nonpremie', 'mother']

# Samples for each cohort
samples = {cohort: su.get_sample_names(cohort) for cohort in cohorts}
hmp_samples = su.get_sample_names('hmp')
olm_samples = su.get_sample_names('olm')
mother_samples = [sample for sample in su.get_sample_names('mother') if sample not in olm_samples]
infant_samples = [sample for sample in su.get_sample_names('infant') if sample not in olm_samples]

# Species list
good_species_list = parse_midas_data.load_pickled_good_species_list()
# Out:
# Loading sample metadata...
# Done!

# %%
mi_sample_day_dict = su.get_mi_sample_day_dict()

# %%
species_cohort_qp_pair_count = defaultdict(dict)
species_qp_pair_dict = defaultdict(list)
num_species_enough_haploid = 0

for species_name in good_species_list[::-1]:
	
	sys.stderr.write("\nProcessing %s...\n" % species_name)
	
	# Grab QP samples for this species
	qp_sample_lists = {}
	for cohort in cohorts:
		qp_sample_lists[cohort] = sorted(su.load_qp_samples(samples[cohort], species_name, prev_cohort=pp_prev_cohort)['qp'])
	
	combined_qp_samples = sorted(su.flatten([qp_sample_lists[cohort] for cohort in cohorts]))
	combined_sample_name_idx_map = {combined_qp_samples[i] : i for i in range(len(combined_qp_samples))}
	
	# Using all QP samples to threshold on sample size
	if len(combined_qp_samples) < min_sample_size:
		sys.stderr.write("Not enough haploid samples!\n")
		continue
	
	num_species_enough_haploid += 1
	
	# Loop over different cohorts
	for cohort in cohorts:		
		desired_samples = qp_sample_lists[cohort]
		
		# These indices are w.r.t. desired_samples
		same_subject_idxs = su.calculate_mi_ordered_same_subject_pairs(sample_order_map, desired_samples, within_host_type=within_host_type, one_per_mi_pair=False)
		for i, j in zip(same_subject_idxs[0], same_subject_idxs[1]):
			sample_i = desired_samples[i]
			sample_j = desired_samples[j]
			species_qp_pair_dict[species_name].append((sample_i, sample_j))
		species_cohort_qp_pair_count[species_name][cohort] = len(same_subject_idxs[0])
# Out:
# Processing Peptoniphilus_rhinitidis_62391...
# Not enough haploid samples!
#
# Processing Actinomyces_sp_62581...
# Not enough haploid samples!
#
# Processing Clostridium_sordellii_57678...
# Not enough haploid samples!
#
# Processing Eubacterium_biforme_61684...
#
# Processing Clostridium_baratii_60475...
#
# Processing Finegoldia_magna_57293...
# Not enough haploid samples!
#
# Processing Lactobacillus_crispatus_56887...
# Not enough haploid samples!
#
# Processing Escherichia_hermannii_58626...
# Not enough haploid samples!
#
# Processing Phascolarctobacterium_succinatutens_61948...
# Not enough haploid samples!
#
# Processing Enterococcus_faecalis_55915...
#
# Processing Paraprevotella_xylaniphila_62280...
#
# Processing Parabacteroides_goldsteinii_56831...
#
# Processing Bacteroides_coprophilus_61767...
#
# Processing Clostridium_hathewayi_61827...
#
# Processing Odoribacter_laneus_62216...
#
# Processing Enterococcus_gallinarum_52312...
#
# Processing Prevotella_buccae_56058...
#
# Processing Clostridium_leptum_61499...
#
# Processing Corynebacterium_sp_48834...
# Not enough haploid samples!
#
# Processing Enterococcus_durans_52177...
#
# Processing Clostridiales_bacterium_59663...
#
# Processing Varibaculum_cambriense_60384...
#
# Processing Veillonella_sp_62611...
#
# Processing Propionibacterium_acnes_57367...
# Not enough haploid samples!
#
# Processing Clostridium_sp_60465...
#
# Processing Coprobacter_fastidiosus_56550...
#
# Processing Clostridium_sp_57418...
#
# Processing Streptococcus_sp_62701...
# Not enough haploid samples!
#
# Processing Bacteroides_nordii_55557...
#
# Processing Neisseria_subflava_61760...
# Not enough haploid samples!
#
# Processing Lactobacillus_plantarum_54610...
#
# Processing Peptostreptococcus_anaerobius_55004...
# Not enough haploid samples!
#
# Processing Eubacterium_ventriosum_61474...
#
# Processing Rothia_mucilaginosa_58144...
# Not enough haploid samples!
#
# Processing Rothia_mucilaginosa_62109...
# Not enough haploid samples!
#
# Processing Acidaminococcus_intestini_54097...
#
# Processing Finegoldia_magna_61710...
#
# Processing Clostridium_sp_61482...
#
# Processing Guyana_massiliensis_60772...
#
# Processing Enterobacter_cloacae_55612...
#
# Processing Enterobacter_sp_59869...
#
# Processing Bacteroides_clarus_62282...
#
# Processing Ruminococcus_obeum_61472...
# Not enough haploid samples!
#
# Processing Negativicoccus_succinicivorans_57482...
# Not enough haploid samples!
#
# Processing Bacteroides_salyersiae_54873...
#
# Processing Anaerococcus_obesiensis_58051...
# Not enough haploid samples!
#
# Processing Alistipes_indistinctus_62207...
#
# Processing Enterococcus_avium_44557...
#
# Processing Lactobacillus_gasseri_55805...
#
# Processing Raoultella_planticola_57814...
#
# Processing Megamonas_hypermegale_57114...
#
# Processing Clostridium_bartlettii_61535...
#
# Processing Enterobacter_asburiae_57214...
# Not enough haploid samples!
#
# Processing Butyricimonas_virosa_58742...
#
# Processing Bradyrhizobium_sp_61126...
# Not enough haploid samples!
#
# Processing Alistipes_sp_59510...
#
# Processing Coprococcus_comes_61587...
#
# Processing Escherichia_coli_53492...
#
# Processing Ruminococcus_lactaris_55568...
#
# Processing Leclercia_adecarboxylata_62497...
#
# Processing Bacteroides_acidifaciens_59693...
# Not enough haploid samples!
#
# Processing Enterococcus_casseliflavus_56514...
#
# Processing Eggerthella_lenta_56463...
# Not enough haploid samples!
#
# Processing Serratia_liquefaciens_58210...
# Not enough haploid samples!
#
# Processing Parabacteroides_johnsonii_55217...
#
# Processing Staphylococcus_warneri_58053...
#
# Processing Prevotella_melaninogenica_58075...
# Not enough haploid samples!
#
# Processing Coprococcus_sp_62244...
#
# Processing Sutterella_wadsworthensis_62218...
#
# Processing Dorea_longicatena_61473...
#
# Processing Clostridium_bolteae_57158...
#
# Processing Eubacterium_hallii_61477...
#
# Processing Enterobacter_cloacae_55011...
#
# Processing Bacteroides_sartorii_54642...
# Not enough haploid samples!
#
# Processing Streptococcus_parasanguinis_58126...
#
# Processing Clostridium_nexile_61654...
#
# Processing Lactobacillus_gasseri_55553...
#
# Processing Lactobacillus_fermentum_54035...
#
# Processing Bifidobacterium_animalis_58116...
#
# Processing Bacteroides_fragilis_56548...
#
# Processing Citrobacter_freundii_56776...
#
# Processing Streptococcus_parasanguinis_62481...
# Not enough haploid samples!
#
# Processing Staphylococcus_lugdunensis_54043...
#
# Processing Proteus_mirabilis_55046...
#
# Processing Clostridium_hathewayi_55515...
#
# Processing Streptococcus_sp_60086...
# Not enough haploid samples!
#
# Processing Subdoligranulum_sp_62068...
#
# Processing Bifidobacterium_scardovii_44511...
#
# Processing Propionibacterium_sp_59451...
#
# Processing Ruminococcus_sp_55468...
#
# Processing Bacteroides_intestinalis_61596...
#
# Processing Ruminococcus_torques_62045...
#
# Processing Hafnia_alvei_56921...
# Not enough haploid samples!
#
# Processing Paraprevotella_clara_33712...
#
# Processing Alistipes_sp_60764...
#
# Processing Enterococcus_hirae_55131...
# Not enough haploid samples!
#
# Processing Oscillospiraceae_bacterium_54867...
#
# Processing Burkholderiales_bacterium_56577...
#
# Processing Erysipelotrichaceae_bacterium_56596...
#
# Processing Streptococcus_parasanguinis_58487...
# Not enough haploid samples!
#
# Processing Roseburia_hominis_61877...
#
# Processing Streptococcus_anginosus_58223...
#
# Processing Eubacterium_siraeum_57634...
#
# Processing Streptococcus_parasanguinis_62442...
# Not enough haploid samples!
#
# Processing Lachnospiraceae_bacterium_51870...
#
# Processing Roseburia_intestinalis_56239...
#
# Processing Collinsella_aerofaciens_61484...
# Not enough haploid samples!
#
# Processing Propionibacterium_avidum_56659...
#
# Processing Pantoea_sp_58264...
#
# Processing Serratia_marcescens_58205...
#
# Processing Roseburia_inulinivorans_61943...
#
# Processing Lactobacillus_paracasei_55666...
#
# Processing Butyrivibrio_crossotus_61674...
#
# Processing Streptococcus_thermophilus_54772...
#
# Processing Morganella_morganii_57363...
#
# Processing Citrobacter_braakii_56022...
#
# Processing Clostridium_sp_61556...
#
# Processing Sutterella_wadsworthensis_56828...
#
# Processing Staphylococcus_hominis_57055...
# Not enough haploid samples!
#
# Processing Enterobacter_cloacae_60571...
# Not enough haploid samples!
#
# Processing Collinsella_sp_62205...
#
# Processing Bacteroidales_bacterium_58650...
#
# Processing Streptococcus_lutetiensis_58501...
#
# Processing Pantoea_sp_60700...
# Not enough haploid samples!
#
# Processing Enterococcus_faecium_56710...
#
# Processing Clostridiales_bacterium_56470...
#
# Processing Anaerostipes_hadrus_55206...
#
# Processing Staphylococcus_haemolyticus_57278...
#
# Processing Streptococcus_gallolyticus_57748...
#
# Processing Bacteroides_eggerthii_54457...
#
# Processing Faecalibacterium_prausnitzii_61481...
#
# Processing Eubacterium_eligens_61678...
#
# Processing Phascolarctobacterium_sp_59817...
#
# Processing Escherichia_albertii_56276...
# Not enough haploid samples!
#
# Processing Enterococcus_faecium_56947...
#
# Processing Lactobacillus_rhamnosus_57549...
#
# Processing Bacteroides_coprocola_61586...
#
# Processing Bacteroides_finegoldii_57739...
#
# Processing Odoribacter_splanchnicus_62174...
#
# Processing Oscillibacter_sp_60799...
#
# Processing Citrobacter_koseri_61132...
#
# Processing Bacteroides_plebeius_61623...
#
# Processing Pseudomonas_aeruginosa_57148...
#
# Processing Enterobacter_hormaechei_50416...
# Not enough haploid samples!
#
# Processing Faecalibacterium_prausnitzii_57453...
#
# Processing Haemophilus_parainfluenzae_57123...
#
# Processing Veillonella_ratti_62429...
#
# Processing Dialister_invisus_61905...
#
# Processing Faecalibacterium_cf_62236...
#
# Processing Streptococcus_agalactiae_55593...
#
# Processing Staphylococcus_aureus_56630...
#
# Processing Staphylococcus_sp_59500...
#
# Processing Haemophilus_parainfluenzae_62356...
# Not enough haploid samples!
#
# Processing Faecalibacterium_prausnitzii_62201...
#
# Processing Enterobacter_cloacae_57303...
#
# Processing Alistipes_finegoldii_56071...
#
# Processing Streptococcus_salivarius_58024...
#
# Processing Bifidobacterium_catenulatum_58257...
#
# Processing Clostridiales_bacterium_52743...
#
# Processing Barnesiella_intestinihominis_62208...
#
# Processing Akkermansia_muciniphila_55290...
#
# Processing Enterobacter_asburiae_58142...
# Not enough haploid samples!
#
# Processing Ruminococcus_bromii_62047...
#
# Processing Actinomyces_urogenitalis_53864...
#
# Processing Klebsiella_pneumoniae_54688...
#
# Processing Bacteroides_faecis_58503...
#
# Processing Bacteroides_cellulosilyticus_58046...
#
# Processing Alistipes_shahii_62199...
#
# Processing Escherichia_coli_57907...
# Not enough haploid samples!
#
# Processing Blautia_wexlerae_56130...
#
# Processing Klebsiella_oxytoca_54123...
#
# Processing Bifidobacterium_pseudocatenulatum_57754...
#
# Processing Bifidobacterium_dentium_55719...
#
# Processing Haemophilus_parainfluenzae_62468...
#
# Processing Bacteroides_massiliensis_44749...
#
# Processing Alistipes_onderdonkii_55464...
#
# Processing Veillonella_dispar_61763...
#
# Processing Veillonella_sp_62404...
#
# Processing Ruminococcus_gnavus_57638...
#
# Processing Clostridium_difficile_57608...
# Not enough haploid samples!
#
# Processing Bifidobacterium_adolescentis_56815...
#
# Processing Ruminococcus_bicirculans_59300...
#
# Processing Parabacteroides_merdae_56972...
#
# Processing Streptococcus_salivarius_58022...
#
# Processing Streptococcus_vestibularis_56030...
#
# Processing Klebsiella_pneumoniae_57337...
# Not enough haploid samples!
#
# Processing Bacteroides_thetaiotaomicron_56941...
#
# Processing Eubacterium_rectale_56927...
#
# Processing Clostridium_butyricum_56361...
#
# Processing Bacteroides_xylanisolvens_57185...
#
# Processing Bacteroides_caccae_53434...
#
# Processing Enterobacter_aerogenes_55704...
#
# Processing Clostridium_paraputrificum_59909...
#
# Processing Streptococcus_salivarius_58037...
#
# Processing Klebsiella_oxytoca_57801...
#
# Processing Citrobacter_freundii_56148...
#
# Processing Veillonella_atypica_58169...
#
# Processing Parabacteroides_distasonis_56985...
#
# Processing Klebsiella_oxytoca_56762...
#
# Processing Veillonella_parvula_58184...
#
# Processing Bacteroides_stercoris_56735...
#
# Processing Enterobacter_cloacae_58148...
#
# Processing Clostridium_perfringens_56840...
#
# Processing Prevotella_copri_61740...
#
# Processing Bacteroides_fragilis_54507...
#
# Processing Alistipes_putredinis_61533...
#
# Processing Veillonella_parvula_57794...
#
# Processing Bacteroides_ovatus_58035...
#
# Processing Bifidobacterium_bifidum_55065...
#
# Processing Bacteroides_uniformis_57318...
#
# Processing Staphylococcus_epidermidis_57523...
#
# Processing Klebsiella_pneumoniae_54788...
#
# Processing Bifidobacterium_breve_57133...
#
# Processing Bifidobacterium_longum_57796...
#
# Processing Enterococcus_faecalis_56297...
#
# Processing Bacteroides_vulgatus_57955...
#
# Processing Escherichia_coli_58110...

# %%
cohort_qp_pair_counts = defaultdict(int)
for species in species_cohort_qp_pair_count:
    for cohort in species_cohort_qp_pair_count[species]:
        qp_count = species_cohort_qp_pair_count[species][cohort]
        cohort_qp_pair_counts[cohort] += qp_count

# %%
print("Number of QP sample pairs per cohort:")
print(cohort_qp_pair_counts)
# Out:
# Number of QP sample pairs per cohort:
# defaultdict(<type 'int'>, {'ferretti': 84, 'backhed': 426, 'hmp': 1296, 'shao': 1572, 'yassour': 481})

# %%
mi_qp_pair_count = 0
for cohort in mi_cohorts:
    mi_qp_pair_count += cohort_qp_pair_counts[cohort]

print("Number of QP sample pairs for all mother-infant: %i" % mi_qp_pair_count)
# Out:
# Number of QP sample pairs for all mother-infant: 2563

# %%
cohort_qp_pair_counts
# Out:
# defaultdict(int,
#             {'backhed': 426,
#              'ferretti': 84,
#              'hmp': 1296,
#              'shao': 1572,
#              'yassour': 481})

# %%
print("There are %i out of %i 'good' species which additionally have at least %i haploid samples" % (num_species_enough_haploid,
                                                                                                     len(good_species_list),
                                                                                                     min_sample_size))
print("Recall definition of good species: must have at least 10 samples with marker gene coverage >= 10")
# Out:
# There are 176 out of 217 'good' species which additionally have at least 3 haploid samples
# Recall definition of good species: must have at least 10 samples with marker gene coverage >= 10

# %%
mi_tt_qp_pair_count = 0
mi_deliv_tt_qp_pair_count = 0
ii_tt_qp_pair_count = 0

for species in species_qp_pair_dict:
    for sample_i, sample_j in species_qp_pair_dict[species]:
        if sample_i in mother_samples and sample_j in infant_samples:
            mi_tt_qp_pair_count += 1
            if mi_sample_day_dict[sample_i] >= -1 and mi_sample_day_dict[sample_i] < 6:
                mi_deliv_tt_qp_pair_count += 1
        if sample_i in infant_samples and sample_j in infant_samples:
            ii_tt_qp_pair_count += 1
        if sample_i in infant_samples and sample_j in mother_samples:
            print("Weird")
# Out:
# Weird
# Weird
# Weird
# Weird
# Weird

# %%
print("Number of QP sample pairs for all mother-infant: %i" % mi_tt_qp_pair_count)
print("Number of QP sample pairs for all mother-infant (mother at delivery only): %i" % mi_deliv_tt_qp_pair_count)
print("Number of QP sample pairs for all infant-infant: %i" % ii_tt_qp_pair_count)
# Out:
# Number of QP sample pairs for all mother-infant: 281
# Number of QP sample pairs for all mother-infant (mother at delivery only): 241
# Number of QP sample pairs for all infant-infant: 2184

# %%
# Plot QP pairs per species
# Plot infants first

from matplotlib.patches import Patch

cohort = 'hmp'

for species in species_cohort_qp_pair_count:

ordered_species_list = []
for species, count in sorted(num_qp_agg_tps[cat].items(), key=lambda x: x[1], reverse=True):
    ordered_species_list.append(species)

ordered_species_list_subset = ordered_species_list[:40][::-1]

all_num_qp = [species_cohort_qp_pair_count[cat][species] for species in ordered_species_list_subset]
all_num_non = [num_non_agg_tps[cat][species] for species in ordered_species_list_subset]
all_num_lowcov = [num_lowcov_agg_tps[cat][species] for species in ordered_species_list_subset]

fig, ax = plt.subplots(figsize=(8,12))

yticks = np.arange(len(all_num_qp))

ax.barh(np.array(yticks) + 0.5, all_num_qp, color='orange')
ax.barh(np.array(yticks) + 0.5, all_num_non, left=all_num_qp, color='#77acff')
# ax.barh(np.array(yticks) + 0.5, all_num_lowcov, left=np.array(all_num_qp)+np.array(all_num_non), color='#396651')

ax.set_yticks(np.array(yticks) + 0.5)
ax.set_yticklabels(ordered_species_list_subset)
ax.set_title("Number of QP samples per species")

legend_elements = [Patch(facecolor='orange', label='QP'), Patch(facecolor='#77acff', label='non-QP')]
ax.legend(handles=legend_elements, loc='center right', frameon=False)

plt.show()
fig.savefig("%s/count_qp_by_species_barh.pdf" % config.analysis_directory, bbox_inches='tight')
fig.savefig("%s/count_qp_by_species_barh.png" % config.analysis_directory, bbox_inches='tight', dpi=500)
